# %%
import pandas as pd
import numpy as np
import random
from datetime import timedelta, datetime

def generate_dataset(num_subjects=10, min_timesteps=10, max_timesteps=20, seed=37):
    random.seed(seed)
    np.random.seed(seed)
    all_rows = []                     
    true_changepoints = {} 
    # Define CPTs (Conditional Probability Tables)
    
    # Segment 1: Mapping from blood_pressure_t-1 to pain_level
    pain_cpt_seg1 = {
        0: [0.8, 0.1, 0.1],  # low BP → no pain
        1: [0.1, 0.8, 0.1],  # normal BP → mild pain
        2: [0.1, 0.1, 0.8],  # high BP → severe pain
    }

    # Segment 2: Noisier mapping from blood_pressure_t-1 to pain_level
    pain_cpt_seg2 = {
        0: [0.4, 0.3, 0.3],
        1: [0.3, 0.4, 0.3],
        2: [0.3, 0.3, 0.4],
    }

    # Segment 1: pain_level_t-1 predicts mobility
    mobility_cpt_seg1 = {
        0: [0.9, 0.1],  # no pain → walking
        1: [0.4, 0.6],  # mild pain → mostly walking
        2: [0.2, 0.8],  # severe pain → mostly bedridden
    }

    # Segment 2: Noisier mapping between pain_level_t-1 and mobility
    mobility_cpt_seg2 = {
        0: [0.6, 0.4],
        1: [0.5, 0.5],
        2: [0.8, 0.2],
    }

    # Generate data per subject
    for subject_id in range(1, num_subjects + 1):
        # Random number of time steps per subject
        num_timesteps = random.randint(min_timesteps, max_timesteps)

        # Define the changepoint (midpoint of time steps)
        changepoint = num_timesteps // 2
        true_changepoints[subject_id] = changepoint

        # Generate time series dates for the subject
        start_date = datetime(2023, random.randint(1, 12), random.randint(1, 28))
        timestamps = [start_date + timedelta(days=2 * i) for i in range(num_timesteps)]

        # Initialize first values randomly
        bp = [random.choice([0, 1, 2])]  # blood_pressure
        pain = [random.choice([0, 1, 2])]
        mobility = [random.choice([0, 1])]
        hr = [random.choice([0, 1, 2])]
        ox = [random.choice([0, 1])]

        # Generate remaining values using CPTs
        for t in range(1, num_timesteps):
            bp.append(random.choice([0, 1, 2]))

            # Use CPTs depending on segment (before/after changepoint)
            if t < changepoint:
                pain_probs = pain_cpt_seg1[bp[t - 1]]
                mobility_probs = mobility_cpt_seg1[pain[t - 1]]
            else:
                pain_probs = pain_cpt_seg2[bp[t - 1]]
                mobility_probs = mobility_cpt_seg2[pain[t - 1]]

            # Sample next values using the CPTs
            pain.append(np.random.choice([0, 1, 2], p=pain_probs))
            mobility.append(np.random.choice([0, 1], p=mobility_probs))
            hr.append(random.choice([0, 1, 2]))   
            ox.append(random.choice([0, 1]))      

        # Collect all rows for this subject
        for t in range(num_timesteps):
            all_rows.append({
                'subject_id': subject_id,
                'timestamp': timestamps[t].date(),
                'blood_pressure': bp[t],
                'pain_level': pain[t],
                'mobility': mobility[t],
                'heart_rate': hr[t],
                'oxygen_level': ox[t],
            })

    # Create a DataFrame and sort for proper ordering
    df = pd.DataFrame(all_rows)
    df = df.sort_values(by=['subject_id', 'timestamp']).reset_index(drop=True)

    return df, true_changepoints

# Generate the dataset and print the head
df_health, ground_truth_cp = generate_dataset()
subject_lengths = df_health.groupby("subject_id").size().to_dict()
df_health.head()
# Out:
#    subject_id   timestamp  blood_pressure  pain_level  mobility  heart_rate  \
# 0           1  2023-10-03               2           2         0           2
# 1           1  2023-10-05               1           2         1           2
# 2           1  2023-10-07               2           1         1           1
# 3           1  2023-10-09               1           2         1           2
# 4           1  2023-10-11               1           1         1           0
#
#    oxygen_level
# 0             1
# 1             0
# 2             1
# 3             1
# 4             0

# %%
# Group by subject_id and count rows
subject_lengths = df_health.groupby("subject_id").size()
print("Number of rows per subject:")
for sid, length in subject_lengths.items():
    print(f"Subject {sid}: {length} time steps")
# Out:
# Number of rows per subject:
# Subject 1: 20 time steps
# Subject 2: 14 time steps
# Subject 3: 19 time steps
# Subject 4: 12 time steps
# Subject 5: 17 time steps
# Subject 6: 15 time steps
# Subject 7: 20 time steps
# Subject 8: 11 time steps
# Subject 9: 14 time steps
# Subject 10: 13 time steps

# %%
# Preprocessing Step: Add Lagged Variables and Encode Categories
# Function to create lagged (t-1) variables per subject
from sklearn.preprocessing import LabelEncoder
def create_lagged_df(df, id_col='subject_id', time_col='timestamp'):
    """
    For each subject:
    - Sorts data by timestamp
    - Adds lagged (t-1) versions of all feature columns
    - Returns a combined dataframe with current and lagged variables
    """
    all_lagged_rows = []

    for subject_id, group in df.groupby(id_col):
        group = group.sort_values(by=time_col).reset_index(drop=True)

        # Create lagged version (shift down by 1)
        lagged = group.shift(1)

        # Rename lagged columns to include "_t-1", except id and timestamp
        lagged.columns = [f"{col}_t-1" if col not in [id_col, time_col] else col for col in lagged.columns]

        # Combine original and lagged data side-by-side
        combined = pd.concat([group, lagged], axis=1).dropna().reset_index(drop=True)

        # Drop duplicate columns like subject_id and timestamp if they exist twice
        combined = combined.loc[:, ~combined.columns.duplicated()]

        all_lagged_rows.append(combined)

    return pd.concat(all_lagged_rows).reset_index(drop=True)

# Function to encode categorical columns using LabelEncoder

def encode_categorical_columns(df, exclude_cols=['subject_id', 'timestamp']):
    
    df_encoded = df.copy()
    encoders = {}

    for col in df.columns:
        if col in exclude_cols:
            continue
        le = LabelEncoder()
        df_encoded[col] = le.fit_transform(df[col])
        encoders[col] = le

    return df_encoded, encoders

# Run Preprocessing

df_lagged = create_lagged_df(df_health)
df_encoded, encoders = encode_categorical_columns(df_lagged)
print("Original (lagged) columns:", df_lagged.columns.tolist())
print("Encoded data sample:")
print(df_encoded.head())
# Out:
# Original (lagged) columns: ['subject_id', 'timestamp', 'blood_pressure', 'pain_level', 'mobility', 'heart_rate', 'oxygen_level', 'blood_pressure_t-1', 'pain_level_t-1', 'mobility_t-1', 'heart_rate_t-1', 'oxygen_level_t-1']
# Encoded data sample:
#    subject_id   timestamp  blood_pressure  pain_level  mobility  heart_rate  \
# 0           1  2023-10-05               1           2         1           2
# 1           1  2023-10-07               2           1         1           1
# 2           1  2023-10-09               1           2         1           2
# 3           1  2023-10-11               1           1         1           0
# 4           1  2023-10-13               0           1         1           1
#
#    oxygen_level  blood_pressure_t-1  pain_level_t-1  mobility_t-1  \
# 0             0                   2               2             0
# 1             1                   1               2             1
# 2             1                   2               1             1
# 3             0                   1               2             1
# 4             0                   1               1             1
#
#    heart_rate_t-1  oxygen_level_t-1
# 0               2                 1
# 1               2                 0
# 2               1                 1
# 3               2                 1
# 4               0                 0

# %%
import numpy as np
from scipy.special import gammaln

# Calculates BDe score for one variable given its parent set
def bde_node_score(data, target, parents, alpha=1.0):
    state_count = data[target].nunique()
    prior = alpha / state_count
    score = 0.0

    if parents:
        grouped = data.groupby(parents)
    else:
        grouped = [(None, data)]

    for _, group in grouped:
        counts = group[target].value_counts().to_dict()
        total = sum(counts.values())

        part = gammaln(alpha) - gammaln(alpha + total)
        for k in range(state_count):
            part += gammaln(prior + counts.get(k, 0)) - gammaln(prior)
        score += part

    return score

# Computes total BDe score for a graph (dict of {child: [parents]})
def bde_graph_score(data, graph, alpha=1.0):
    return sum(bde_node_score(data, child, parents, alpha) for child, parents in graph.items())

# Define the actual (true) dependency structure
true_graph = {
    'pain_level': ['blood_pressure_t-1'],
    'mobility': ['pain_level_t-1'],
    'blood_pressure': [],
    'heart_rate': [],
    'oxygen_level': [],
    'blood_pressure_t-1': [],
    'pain_level_t-1': [],
    'mobility_t-1': [],
    'heart_rate_t-1': [],
    'oxygen_level_t-1': []
}

# Compare with the null (empty) graph
empty_graph = {
    col: [] for col in df_encoded.columns if col not in ['subject_id', 'timestamp']
}

# Score both structures
score_real = bde_graph_score(df_encoded, true_graph)
score_null = bde_graph_score(df_encoded, empty_graph)

# Print comparison
print("BDe Score Comparison:")
print("  True graph score :", score_real)
print("  Empty graph score:", score_null)
print("  Difference        :", score_real - score_null)
# Out:
# BDe Score Comparison:
#   True graph score : -1372.4736720260603
#   Empty graph score: -1394.4686811783158
#   Difference        : 21.995009152255534

# %%
# RJMCMC per subjec

import numpy as np
import pandas as pd
import random
from collections import Counter, defaultdict
from scipy.special import gammaln
import copy

# BDe score for a single variable given its parent set
def node_bde(data, target, parents, alpha=1.0):
    r = data[target].nunique()
    prior = alpha / r
    score = 0.0

    grouped = data.groupby(parents) if parents else [(None, data)]

    for _, group in grouped:
        counts = group[target].value_counts().to_dict()
        total = sum(counts.values())
        term = gammaln(alpha) - gammaln(alpha + total)
        for val in range(r):
            term += gammaln(prior + counts.get(val, 0)) - gammaln(prior)
        score += term
    return score

# Score across segments (changepoint-aware)
def segmented_score(data, segments, child, parents, alpha=1.0):
    result = 0.0
    for seg in np.unique(segments):
        subset = data.iloc[np.where(segments == seg)[0]]
        if not subset.empty:
            result += node_bde(subset, child, parents, alpha)
    return result

# Log-prior on changepoint configurations
def cp_prior_penalty(segments, lam=1.0):
    return -lam * np.sum(segments[1:] != segments[:-1])

# Suggest graph neighbors by adding/removing edges
def suggest_neighbors(graph, nodes, limit=3):
    proposals = []

    for child in nodes:
        parents = set(graph.get(child, []))
        for other in nodes:
            if other == child or other in parents:
                continue
            if len(parents) >= limit or "_t-1" not in other:
                continue
            new_graph = copy.deepcopy(graph)
            new_graph[child] = list(parents | {other})
            proposals.append(new_graph)

        for p in parents:
            new_graph = copy.deepcopy(graph)
            new_graph[child] = list(parents - {p})
            proposals.append(new_graph)

    return proposals

# Changepoint vector initialization
def init_segments(data, variables):
    return {var: np.zeros(len(data), dtype=int) for var in variables}

# Segment birth
def propose_birth(seg):
    points = [t for t in range(1, len(seg) - 1) if seg[t] == seg[t - 1]]
    if not points:
        return seg, False
    pos = random.choice(points)
    new_seg = seg.copy()
    current = seg[pos]
    new_id = max(seg) + 1
    for i in range(pos, len(seg)):
        if seg[i] == current:
            new_seg[i] = new_id
        else:
            break
    return new_seg, True

# Segment death
def propose_death(seg):
    unique = np.unique(seg)
    if len(unique) <= 1:
        return seg, False
    merge = random.choice(unique[1:])
    old = merge - 1
    new_seg = seg.copy()
    new_seg[seg == merge] = old
    _, reindexed = np.unique(new_seg, return_inverse=True)
    return reindexed, True

# Segment shift
def propose_shift(seg):
    points = [i for i in range(1, len(seg)) if seg[i] != seg[i - 1]]
    if not points:
        return seg, False
    move = random.choice(points)
    new_idx = move + random.choice([-1, 1])
    if not (0 < new_idx < len(seg)):
        return seg, False
    new_seg = seg.copy()
    before, after = seg[move - 1], seg[move]
    if new_idx < move:
        new_seg[new_idx:move] = after
        new_seg[new_idx] = before
    else:
        new_seg[move:new_idx] = before
        new_seg[move] = after
    return new_seg, True

# Main RJMCMC per-subject runner with BMA
def run_rjmcmc(df, features, **kwargs):
    all_segments = {feat: np.zeros(len(df), dtype=int) for feat in features}
    edge_log = Counter()
    sample_total = 0

    for subj_id, data in df.groupby("subject_id"):
        print(f"Processing subject {subj_id}")
        data = data.reset_index(drop=True)
        nodes = [f for f in data.columns if f not in ['subject_id', 'timestamp']]
        segs = init_segments(data, nodes)
        graph = {n: [] for n in nodes}

        def total_logscore(G, V):
            return sum(
                segmented_score(data, V[n], n, G[n], kwargs['alpha']) + cp_prior_penalty(V[n], kwargs['lambda_cp'])
                for n in nodes
            )

        score = total_logscore(graph, segs)
        best = copy.deepcopy(segs)
        best_val = score

        for i in range(kwargs['num_iters']):
            print(f"  Step {i}", end='')

            if random.random() < kwargs['p_structure']:
                choices = suggest_neighbors(graph, nodes, kwargs['max_parents'])
                new_graph = random.choice(choices)
                new_score = total_logscore(new_graph, segs)
                accept = np.exp(new_score - score)
                print(f" | structure move | Δ={new_score - score:.2f}, p={accept:.2f}")
                if random.random() < min(1.0, accept):
                    graph = new_graph
                    score = new_score
                    if score > best_val:
                        best_val = score
                        best = copy.deepcopy(segs)
            else:
                node = random.choice(nodes)
                move_type = random.choice(['birth', 'death', 'shift'])
                move_fn = {'birth': propose_birth, 'death': propose_death, 'shift': propose_shift}[move_type]
                trial, ok = move_fn(segs[node])
                if not ok:
                    continue
                new_score = segmented_score(data, trial, node, graph[node], kwargs['alpha']) + cp_prior_penalty(trial, kwargs['lambda_cp'])
                old_score = segmented_score(data, segs[node], node, graph[node], kwargs['alpha']) + cp_prior_penalty(segs[node], kwargs['lambda_cp'])
                delta = new_score - old_score
                accept = np.exp(delta)
                print(f" | changepoint {move_type} on {node} | Δ={delta:.2f}, p={accept:.2f}")
                if random.random() < min(1.0, accept):
                    segs[node] = trial
                    score = total_logscore(graph, segs)
                    if score > best_val:
                        best_val = score
                        best = copy.deepcopy(segs)

            if i % 50 == 0:
                for tgt, srcs in graph.items():
                    for src in srcs:
                        edge_log[(tgt, src)] += 1
                sample_total += 1

        for node in nodes:
            all_segments[node][data.index] = best[node]

        print(f"Subject {subj_id} done | best score = {best_val:.2f}")

    final = defaultdict(list)
    for (child, parent), count in edge_log.items():
        if count / sample_total >= 0.3:
            final[child].append(parent)

    return final, all_segments

# Example usage
cols = [c for c in df_encoded.columns if c not in ['subject_id', 'timestamp']]
learned_graph, segment_map = run_rjmcmc(
    df_encoded,
    features=cols,
    num_iters=4000,
    alpha=1.0,
    lambda_cp=4.0,
    max_parents=3,
    p_structure=0.5
)

print("Final Graph Structure:")
for tgt, srcs in learned_graph.items():
    print(f"{tgt} <- {srcs}")
# Out:
# Processing subject 1
#   Step 0 | structure move | Δ=-0.44, p=0.65
#   Step 1 | structure move | Δ=-1.76, p=0.17
#   Step 2 | changepoint birth on blood_pressure_t-1 | Δ=-2.70, p=0.07
#   Step 3 | structure move | Δ=-0.91, p=0.40
#   Step 4 | structure move | Δ=-1.24, p=0.29
#   Step 5 | structure move | Δ=-1.57, p=0.21
#   Step 6 | structure move | Δ=-1.31, p=0.27
#   Step 7 | changepoint birth on pain_level_t-1 | Δ=-4.56, p=0.01
#   Step 8 | changepoint birth on oxygen_level | Δ=-5.97, p=0.00
#   Step 9 | structure move | Δ=0.55, p=1.73
#   Step 10 | changepoint birth on heart_rate | Δ=-6.72, p=0.00
#   Step 11 | structure move | Δ=-1.77, p=0.17
#   Step 12 | structure move | Δ=-0.72, p=0.49
#   Step 13  Step 14 | structure move | Δ=-0.25, p=0.78
#   Step 15  Step 16  Step 17 | changepoint birth on blood_pressure_t-1 | Δ=-3.88, p=0.02
#   Step 18  Step 19  Step 20 | structure move | Δ=-1.57, p=0.21
#   Step 21  Step 22  Step 23  Step 24 | structure move | Δ=-1.77, p=0.17
#   Step 25 | structure move | Δ=-1.29, p=0.27
#   Step 26  Step 27 | structure move | Δ=-1.92, p=0.15
#   Step 28 | changepoint birth on blood_pressure | Δ=-11.57, p=0.00
#   Step 29  Step 30 | structure move | Δ=-1.83, p=0.16
#   Step 31 | structure move | Δ=-0.55, p=0.58
#   Step 32 | structure move | Δ=-0.34, p=0.71
#   Step 33 | structure move | Δ=-1.71, p=0.18
#   Step 34 | structure move | Δ=-0.34, p=0.71
#   Step 35 | changepoint birth on heart_rate_t-1 | Δ=-1.75, p=0.17
#   Step 36  Step 37 | structure move | Δ=0.44, p=1.55
#   Step 38  Step 39  Step 40 | structure move | Δ=0.77, p=2.16
#   Step 41  Step 42 | changepoint birth on mobility_t-1 | Δ=-5.22, p=0.01
#   Step 43  Step 44 | structure move | Δ=0.53, p=1.69
#   Step 45 | structure move | Δ=-1.68, p=0.19
#   Step 46  Step 47 | structure move | Δ=-1.78, p=0.17
#   Step 48 | structure move | Δ=-1.83, p=0.16
#   Step 49 | structure move | Δ=0.32, p=1.37
#   Step 50 | structure move | Δ=-1.24, p=0.29
#   Step 51  Step 52  Step 53  Step 54 | structure move | Δ=-1.39, p=0.25
#   Step 55 | structure move | Δ=-1.12, p=0.33
#   Step 56 | structure move | Δ=-1.39, p=0.25
#   Step 57 | structure move | Δ=4.21, p=67.50
#   Step 58 | changepoint birth on blood_pressure | Δ=-11.57, p=0.00
#   Step 59 | structure move | Δ=0.90, p=2.45
#   Step 60 | changepoint birth on pain_level | Δ=-4.75, p=0.01
#   Step 61 | structure move | Δ=0.46, p=1.58
#   Step 62  Step 63 | structure move | Δ=-1.68, p=0.19
#   Step 64 | structure move | Δ=0.47, p=1.60
#   Step 65 | structure move | Δ=-0.27, p=0.77
#   Step 66 | structure move | Δ=-0.80, p=0.45
#   Step 67  Step 68  Step 69 | changepoint birth on mobility_t-1 | Δ=-5.92, p=0.00
#   Step 70 | structure move | Δ=-0.53, p=0.59
#   Step 71 | structure move | Δ=-0.36, p=0.70
#   Step 72 | structure move | Δ=-1.86, p=0.16
#   Step 73  Step 74 | structure move | Δ=-0.72, p=0.49
#   Step 75 | structure move | Δ=2.84, p=17.14
#   Step 76 | structure move | Δ=-1.69, p=0.19
#   Step 77 | structure move | Δ=-2.24, p=0.11
#   Step 78  Step 79 | structure move | Δ=-0.44, p=0.65
#   Step 80  Step 81 | structure move | Δ=-0.72, p=0.49
#   Step 82 | structure move | Δ=-2.84, p=0.06
#   Step 83 | changepoint birth on heart_rate_t-1 | Δ=-2.96, p=0.05
#   Step 84  Step 85 | changepoint birth on pain_level_t-1 | Δ=-3.50, p=0.03
#   Step 86 | structure move | Δ=7.54, p=1885.71
#   Step 87  Step 88 | structure move | Δ=0.36, p=1.44
#   Step 89 | structure move | Δ=2.37, p=10.72
#   Step 90 | structure move | Δ=-0.69, p=0.50
#   Step 91  Step 92  Step 93 | structure move | Δ=-1.24, p=0.29
#   Step 94  Step 95 | structure move | Δ=-0.36, p=0.70
#   Step 96 | structure move | Δ=1.75, p=5.76
#   Step 97 | structure move | Δ=1.24, p=3.47
#   Step 98  Step 99  Step 100  Step 101 | structure move | Δ=-0.70, p=0.49
#   Step 102 | structure move | Δ=0.81, p=2.24
#   Step 103 | structure move | Δ=-1.82, p=0.16
#   Step 104 | changepoint birth on heart_rate | Δ=-6.13, p=0.00
#   Step 105 | structure move | Δ=-1.10, p=0.33
#   Step 106 | structure move | Δ=-0.12, p=0.89
#   Step 107 | structure move | Δ=-1.78, p=0.17
#   Step 108 | changepoint birth on mobility | Δ=-1.65, p=0.19
#   Step 109 | structure move | Δ=-1.78, p=0.17
#   Step 110  Step 111 | structure move | Δ=-2.84, p=0.06
#   Step 112 | changepoint birth on heart_rate | Δ=-4.52, p=0.01
#   Step 113  Step 114 | changepoint birth on blood_pressure | Δ=-5.90, p=0.00
#   Step 115 | structure move | Δ=-1.69, p=0.19
#   Step 116 | structure move | Δ=-0.77, p=0.46
#   Step 117 | changepoint birth on oxygen_level_t-1 | Δ=-5.51, p=0.00
#   Step 118 | structure move | Δ=-7.54, p=0.00
#   Step 119  Step 120  Step 121  Step 122 | structure move | Δ=-0.28, p=0.76
#   Step 123  Step 124 | structure move | Δ=0.40, p=1.49
#   Step 125  Step 126 | structure move | Δ=-0.25, p=0.78
#   Step 127  Step 128 | structure move | Δ=-1.69, p=0.19
#   Step 129  Step 130 | structure move | Δ=-1.69, p=0.19
#   Step 131 | changepoint birth on mobility_t-1 | Δ=-5.43, p=0.00
#   Step 132 | structure move | Δ=0.15, p=1.16
#   Step 133 | structure move | Δ=-1.93, p=0.15
#   Step 134 | changepoint birth on mobility_t-1 | Δ=-5.82, p=0.00
#   Step 135  Step 136 | structure move | Δ=-1.75, p=0.17
#   Step 137  Step 138 | changepoint birth on mobility | Δ=-5.63, p=0.00
#   Step 139  Step 140 | structure move | Δ=-0.99, p=0.37
#   Step 141 | changepoint birth on blood_pressure_t-1 | Δ=-3.83, p=0.02
#   Step 142 | structure move | Δ=0.01, p=1.01
#   Step 143  Step 144 | structure move | Δ=0.66, p=1.93
#   Step 145 | structure move | Δ=-0.25, p=0.78
#   Step 146  Step 147 | structure move | Δ=-0.08, p=0.92
#   Step 148 | structure move | Δ=-1.19, p=0.30
#   Step 149  Step 150 | structure move | Δ=-1.82, p=0.16
#   Step 151 | structure move | Δ=1.03, p=2.80
#   Step 152  Step 153 | structure move | Δ=0.32, p=1.37
#   Step 154 | structure move | Δ=-0.53, p=0.59
#   Step 155  Step 156 | structure move | Δ=0.08, p=1.08
#   Step 157 | structure move | Δ=1.39, p=4.00
#   Step 158 | structure move | Δ=0.44, p=1.55
#   Step 159 | structure move | Δ=0.87, p=2.40
#   Step 160 | structure move | Δ=-2.55, p=0.08
#   Step 161 | structure move | Δ=-0.05, p=0.95
#   Step 162  Step 163 | changepoint birth on heart_rate_t-1 | Δ=-4.07, p=0.02
#   Step 164 | structure move | Δ=-0.92, p=0.40
#   Step 165  Step 166  Step 167 | structure move | Δ=-1.39, p=0.25
#   Step 168 | changepoint birth on pain_level_t-1 | Δ=-1.99, p=0.14
#   Step 169 | structure move | Δ=-0.07, p=0.93
#   Step 170  Step 171 | structure move | Δ=-2.04, p=0.13
#   Step 172 | changepoint birth on pain_level | Δ=-4.30, p=0.01
#   Step 173 | structure move | Δ=0.05, p=1.05
#   Step 174 | changepoint birth on blood_pressure | Δ=-4.11, p=0.02
#   Step 175  Step 176  Step 177 | structure move | Δ=-1.01, p=0.36
#   Step 178 | changepoint birth on oxygen_level | Δ=-4.71, p=0.01
#   Step 179 | structure move | Δ=-0.32, p=0.73
#   Step 180  Step 181 | structure move | Δ=-0.56, p=0.57
#   Step 182 | structure move | Δ=-0.35, p=0.71
#   Step 183  Step 184 | structure move | Δ=-0.58, p=0.56
#   Step 185 | structure move | Δ=-0.44, p=0.65
#   Step 186 | structure move | Δ=-0.77, p=0.46
#   Step 187 | structure move | Δ=-2.04, p=0.13
#   Step 188 | structure move | Δ=-1.01, p=0.37
#   Step 189 | changepoint birth on pain_level_t-1 | Δ=-2.11, p=0.12
#   Step 190  Step 191 | structure move | Δ=-1.56, p=0.21
#   Step 192 | structure move | Δ=-1.94, p=0.14
#   Step 193 | changepoint birth on pain_level | Δ=-4.99, p=0.01
#   Step 194 | structure move | Δ=-1.01, p=0.37
#   Step 195  Step 196 | structure move | Δ=-6.18, p=0.00
#   Step 197  Step 198 | structure move | Δ=0.37, p=1.45
#   Step 199 | structure move | Δ=-1.10, p=0.33
#   Step 200  Step 201 | structure move | Δ=0.58, p=1.78
#   Step 202  Step 203 | structure move | Δ=-0.33, p=0.72
#   Step 204  Step 205 | changepoint birth on mobility | Δ=-5.41, p=0.00
#   Step 206 | changepoint birth on blood_pressure_t-1 | Δ=-4.43, p=0.01
#   Step 207  Step 208 | structure move | Δ=-2.84, p=0.06
#   Step 209 | structure move | Δ=-2.55, p=0.08
#   Step 210 | structure move | Δ=-1.27, p=0.28
#   Step 211 | structure move | Δ=0.62, p=1.87
#   Step 212 | changepoint birth on oxygen_level | Δ=-5.81, p=0.00
#   Step 213  Step 214 | structure move | Δ=-0.37, p=0.69
#   Step 215 | structure move | Δ=-0.91, p=0.40
#   Step 216 | structure move | Δ=-1.01, p=0.36
#   Step 217 | structure move | Δ=-1.78, p=0.17
#   Step 218 | structure move | Δ=2.64, p=14.06
#   Step 219  Step 220 | structure move | Δ=-0.65, p=0.52
#   Step 221 | structure move | Δ=-1.93, p=0.15
#   Step 222 | changepoint birth on blood_pressure | Δ=-13.18, p=0.00
#   Step 223 | changepoint birth on oxygen_level | Δ=-4.02, p=0.02
#   Step 224  Step 225 | structure move | Δ=-0.37, p=0.69
#   Step 226 | structure move | Δ=-1.93, p=0.15
#   Step 227 | structure move | Δ=-1.97, p=0.14
#   Step 228  Step 229 | structure move | Δ=-2.11, p=0.12
#   Step 230 | changepoint birth on heart_rate | Δ=-4.46, p=0.01
#   Step 231 | structure move | Δ=-1.94, p=0.14
#   Step 232 | structure move | Δ=0.91, p=2.49
#   Step 233 | structure move | Δ=-1.97, p=0.14
#   Step 234 | structure move | Δ=0.56, p=1.74
#   Step 235  Step 236  Step 237  Step 238 | structure move | Δ=-1.45, p=0.23
#   Step 239 | changepoint birth on mobility | Δ=-1.65, p=0.19
#   Step 240  Step 241 | structure move | Δ=-0.52, p=0.59
#   Step 242  Step 243 | structure move | Δ=0.92, p=2.51
#   Step 244  Step 245 | structure move | Δ=-1.03, p=0.36
#   Step 246 | structure move | Δ=-0.87, p=0.42
#   Step 247  Step 248 | structure move | Δ=-2.11, p=0.12
#   Step 249 | structure move | Δ=-1.69, p=0.19
#   Step 250 | structure move | Δ=-3.60, p=0.03
#   Step 251 | changepoint birth on heart_rate | Δ=-2.17, p=0.11
#   Step 252 | structure move | Δ=-3.60, p=0.03
#   Step 253 | structure move | Δ=-2.99, p=0.05
#   Step 254 | structure move | Δ=-1.78, p=0.17
#   Step 255 | structure move | Δ=-2.64, p=0.07
#   Step 256  Step 257  Step 258 | structure move | Δ=-2.84, p=0.06
#   Step 259  Step 260 | structure move | Δ=-2.84, p=0.06
#   Step 261 | structure move | Δ=-1.69, p=0.19
#   Step 262 | structure move | Δ=-0.91, p=0.40
#   Step 263 | structure move | Δ=1.02, p=2.77
#   Step 264 | structure move | Δ=1.06, p=2.88
#   Step 265 | structure move | Δ=-1.00, p=0.37
#   Step 266 | structure move | Δ=0.52, p=1.69
#   Step 267 | changepoint birth on mobility | Δ=-2.80, p=0.06
#   Step 268 | structure move | Δ=1.35, p=3.85
#   Step 269 | structure move | Δ=-1.94, p=0.14
#   Step 270 | structure move | Δ=-0.58, p=0.56
#   Step 271 | structure move | Δ=-1.06, p=0.35
#   Step 272 | changepoint birth on heart_rate_t-1 | Δ=-4.05, p=0.02
#   Step 273 | structure move | Δ=-0.52, p=0.59
#   Step 274 | changepoint birth on blood_pressure_t-1 | Δ=-6.25, p=0.00
#   Step 275 | structure move | Δ=-7.54, p=0.00
#   Step 276 | structure move | Δ=-1.01, p=0.37
#   Step 277 | changepoint birth on mobility | Δ=-3.25, p=0.04
#   Step 278  Step 279  Step 280  Step 281 | structure move | Δ=1.02, p=2.77
#   Step 282  Step 283  Step 284  Step 285 | structure move | Δ=-1.78, p=0.17
#   Step 286 | changepoint birth on mobility | Δ=-3.90, p=0.02
#   Step 287  Step 288 | structure move | Δ=1.00, p=2.71
#   Step 289 | changepoint birth on heart_rate | Δ=-6.25, p=0.00
#   Step 290  Step 291 | changepoint birth on mobility_t-1 | Δ=-4.31, p=0.01
#   Step 292  Step 293 | structure move | Δ=1.18, p=3.24
#   Step 294 | structure move | Δ=-0.62, p=0.54
#   Step 295 | structure move | Δ=-1.00, p=0.37
#   Step 296 | structure move | Δ=-1.02, p=0.36
#   Step 297 | structure move | Δ=-1.26, p=0.28
#   Step 298  Step 299  Step 300 | structure move | Δ=-3.60, p=0.03
#   Step 301  Step 302 | structure move | Δ=0.58, p=1.78
#   Step 303 | structure move | Δ=-1.18, p=0.31
#   Step 304 | structure move | Δ=-1.35, p=0.26
#   Step 305  Step 306 | structure move | Δ=0.52, p=1.69
#   Step 307 | changepoint birth on pain_level | Δ=-4.87, p=0.01
#   Step 308 | structure move | Δ=1.01, p=2.74
#   Step 309 | structure move | Δ=-1.02, p=0.36
#   Step 310 | structure move | Δ=-1.93, p=0.15
#   Step 311  Step 312 | structure move | Δ=-0.58, p=0.56
#   Step 313 | structure move | Δ=1.87, p=6.50
#   Step 314 | changepoint birth on heart_rate | Δ=-4.75, p=0.01
#   Step 315 | changepoint birth on pain_level_t-1 | Δ=-2.45, p=0.09
#   Step 316 | changepoint birth on blood_pressure | Δ=0.17, p=1.18
#   Step 317  Step 318 | changepoint birth on mobility | Δ=-4.31, p=0.01
#   Step 319 | changepoint birth on heart_rate_t-1 | Δ=-6.82, p=0.00
#   Step 320 | structure move | Δ=-3.53, p=0.03
#   Step 321 | structure move | Δ=-1.93, p=0.15
#   Step 322 | structure move | Δ=-3.02, p=0.05
#   Step 323  Step 324 | structure move | Δ=-3.02, p=0.05
#   Step 325 | changepoint birth on pain_level | Δ=-4.19, p=0.02
#   Step 326 | structure move | Δ=-0.37, p=0.69
#   Step 327 | changepoint birth on oxygen_level | Δ=-3.51, p=0.03
#   Step 328 | structure move | Δ=-0.69, p=0.50
#   Step 329 | changepoint death on blood_pressure | Δ=-2.44, p=0.09
#   Step 330 | structure move | Δ=-7.54, p=0.00
#   Step 331 | changepoint birth on heart_rate | Δ=-1.99, p=0.14
#   Step 332 | changepoint birth on mobility_t-1 | Δ=-5.00, p=0.01
#   Step 333 | changepoint birth on pain_level_t-1 | Δ=-3.94, p=0.02
#   Step 334 | changepoint birth on oxygen_level_t-1 | Δ=-5.85, p=0.00
#   Step 335 | structure move | Δ=-1.26, p=0.28
#   Step 336 | structure move | Δ=-1.78, p=0.17
#   Step 337 | structure move | Δ=-0.62, p=0.54
#   Step 338 | structure move | Δ=-7.54, p=0.00
#   Step 339 | structure move | Δ=0.49, p=1.64
#   Step 340  Step 341 | changepoint birth on pain_level | Δ=-5.00, p=0.01
#   Step 342 | structure move | Δ=-0.44, p=0.65
#   Step 343  Step 344 | structure move | Δ=-0.65, p=0.52
#   Step 345 | changepoint birth on mobility | Δ=-4.42, p=0.01
#   Step 346 | structure move | Δ=-0.27, p=0.76
#   Step 347 | structure move | Δ=-3.30, p=0.04
#   Step 348 | structure move | Δ=-0.49, p=0.61
#   Step 349 | structure move | Δ=-1.68, p=0.19
#   Step 350 | structure move | Δ=-1.56, p=0.21
#   Step 351 | structure move | Δ=-1.18, p=0.31
#   Step 352  Step 353  Step 354 | changepoint birth on pain_level | Δ=-4.19, p=0.02
#   Step 355 | structure move | Δ=0.58, p=1.78
#   Step 356 | structure move | Δ=-3.14, p=0.04
#   Step 357 | structure move | Δ=0.13, p=1.14
#   Step 358 | structure move | Δ=-1.57, p=0.21
#   Step 359 | structure move | Δ=0.27, p=1.31
#   Step 360 | structure move | Δ=-1.57, p=0.21
#   Step 361 | structure move | Δ=1.18, p=3.24
#   Step 362  Step 363 | structure move | Δ=-1.18, p=0.31
#   Step 364  Step 365  Step 366 | structure move | Δ=1.48, p=4.38
#   Step 367  Step 368  Step 369 | structure move | Δ=-1.11, p=0.33
#   Step 370 | structure move | Δ=1.93, p=6.86
#   Step 371 | changepoint shift on blood_pressure | Δ=0.00, p=1.00
#   Step 372 | changepoint birth on oxygen_level_t-1 | Δ=-5.51, p=0.00
#   Step 373 | changepoint birth on mobility_t-1 | Δ=-5.22, p=0.01
#   Step 374  Step 375  Step 376 | structure move | Δ=-7.54, p=0.00
#   Step 377  Step 378 | structure move | Δ=-2.22, p=0.11
#   Step 379 | structure move | Δ=0.46, p=1.58
#   Step 380 | changepoint birth on blood_pressure_t-1 | Δ=-9.91, p=0.00
#   Step 381 | structure move | Δ=-1.00, p=0.37
#   Step 382 | changepoint birth on heart_rate | Δ=-1.99, p=0.14
#   Step 383 | structure move | Δ=-4.14, p=0.02
#   Step 384 | changepoint birth on blood_pressure_t-1 | Δ=-4.43, p=0.01
#   Step 385 | structure move | Δ=-0.52, p=0.59
#   Step 386 | structure move | Δ=-1.87, p=0.15
#   Step 387 | changepoint birth on blood_pressure_t-1 | Δ=-9.91, p=0.00
#   Step 388 | structure move | Δ=0.58, p=1.78
#   Step 389 | changepoint birth on mobility_t-1 | Δ=-5.63, p=0.00
#   Step 390  Step 391 | changepoint birth on heart_rate_t-1 | Δ=-5.50, p=0.00
#   Step 392  Step 393  Step 394 | structure move | Δ=-2.77, p=0.06
#   Step 395 | structure move | Δ=-3.02, p=0.05
#   Step 396 | structure move | Δ=-2.77, p=0.06
#   Step 397  Step 398 | structure move | Δ=-1.00, p=0.37
#   Step 399 | structure move | Δ=-1.57, p=0.21
#   Step 400 | structure move | Δ=-0.56, p=0.57
#   Step 401 | structure move | Δ=0.69, p=2.00
#   Step 402  Step 403  Step 404  Step 405 | structure move | Δ=-1.08, p=0.34
#   Step 406 | changepoint birth on heart_rate_t-1 | Δ=-2.28, p=0.10
#   Step 407 | structure move | Δ=-1.13, p=0.32
#   Step 408 | changepoint birth on pain_level | Δ=-2.97, p=0.05
#   Step 409 | changepoint birth on heart_rate | Δ=-5.09, p=0.01
#   Step 410  Step 411 | structure move | Δ=-0.52, p=0.59
#   Step 412  Step 413  Step 414  Step 415  Step 416 | structure move | Δ=-1.56, p=0.21
#   Step 417 | changepoint birth on blood_pressure_t-1 | Δ=-13.18, p=0.00
#   Step 418 | structure move | Δ=1.03, p=2.80
#   Step 419 | structure move | Δ=-0.58, p=0.56
#   Step 420 | changepoint birth on blood_pressure_t-1 | Δ=-8.23, p=0.00
#   Step 421  Step 422  Step 423 | structure move | Δ=-1.08, p=0.34
#   Step 424  Step 425 | changepoint birth on mobility_t-1 | Δ=-4.53, p=0.01
#   Step 426 | changepoint birth on mobility | Δ=-5.08, p=0.01
#   Step 427  Step 428 | changepoint shift on blood_pressure | Δ=0.00, p=1.00
#   Step 429 | changepoint birth on heart_rate | Δ=-1.19, p=0.30
#   Step 430  Step 431  Step 432  Step 433 | structure move | Δ=-0.92, p=0.40
#   Step 434 | structure move | Δ=-7.54, p=0.00
#   Step 435 | structure move | Δ=2.99, p=19.94
#   Step 436 | changepoint birth on pain_level | Δ=-6.02, p=0.00
#   Step 437  Step 438 | changepoint birth on pain_level | Δ=-5.95, p=0.00
#   Step 439 | structure move | Δ=-1.78, p=0.17
#   Step 440 | changepoint birth on oxygen_level | Δ=-5.81, p=0.00
#   Step 441 | structure move | Δ=-5.19, p=0.01
#   Step 442 | structure move | Δ=-2.11, p=0.12
#   Step 443 | structure move | Δ=-0.58, p=0.56
#   Step 444 | structure move | Δ=0.49, p=1.64
#   Step 445  Step 446  Step 447 | structure move | Δ=-1.26, p=0.28
#   Step 448 | structure move | Δ=-0.91, p=0.40
#   Step 449 | changepoint birth on oxygen_level | Δ=-5.41, p=0.00
#   Step 450 | changepoint shift on blood_pressure | Δ=0.00, p=1.00
#   Step 451 | changepoint birth on oxygen_level_t-1 | Δ=-4.41, p=0.01
#   Step 452 | changepoint birth on oxygen_level | Δ=-4.56, p=0.01
#   Step 453 | changepoint birth on mobility | Δ=-4.20, p=0.01
#   Step 454  Step 455 | structure move | Δ=0.58, p=1.78
#   Step 456  Step 457 | changepoint death on blood_pressure | Δ=-0.17, p=0.84
#   Step 458  Step 459 | structure move | Δ=-2.99, p=0.05
#   Step 460 | structure move | Δ=-0.36, p=0.70
#   Step 461 | structure move | Δ=-1.13, p=0.32
#   Step 462 | structure move | Δ=-0.38, p=0.69
#   Step 463  Step 464 | changepoint birth on mobility | Δ=-3.04, p=0.05
#   Step 465 | structure move | Δ=0.38, p=1.46
#   Step 466 | changepoint birth on mobility | Δ=-3.04, p=0.05
#   Step 467 | structure move | Δ=-1.78, p=0.17
#   Step 468 | structure move | Δ=-0.44, p=0.65
#   Step 469  Step 470  Step 471  Step 472 | structure move | Δ=-2.11, p=0.12
#   Step 473  Step 474  Step 475 | structure move | Δ=-0.56, p=0.57
#   Step 476 | structure move | Δ=-1.48, p=0.23
#   Step 477 | structure move | Δ=-0.56, p=0.57
#   Step 478 | structure move | Δ=-2.11, p=0.12
#   Step 479  Step 480 | changepoint birth on heart_rate_t-1 | Δ=-3.09, p=0.05
#   Step 481  Step 482  Step 483  Step 484 | structure move | Δ=-1.11, p=0.33
#   Step 485  Step 486 | structure move | Δ=-0.91, p=0.40
#   Step 487 | structure move | Δ=1.13, p=3.09
#   Step 488 | structure move | Δ=-1.11, p=0.33
#   Step 489 | structure move | Δ=-0.56, p=0.57
#   Step 490 | structure move | Δ=-0.07, p=0.93
#   Step 491 | structure move | Δ=-7.39, p=0.00
#   Step 492 | structure move | Δ=-2.04, p=0.13
#   Step 493 | structure move | Δ=0.52, p=1.69
#   Step 494  Step 495  Step 496 | structure move | Δ=-1.24, p=0.29
#   Step 497 | structure move | Δ=-1.27, p=0.28
#   Step 498 | changepoint birth on blood_pressure_t-1 | Δ=-3.19, p=0.04
#   Step 499 | structure move | Δ=-0.36, p=0.70
#   Step 500 | changepoint birth on heart_rate | Δ=-4.87, p=0.01
#   Step 501  Step 502 | structure move | Δ=0.25, p=1.28
#   Step 503 | structure move | Δ=2.11, p=8.28
#   Step 504  Step 505 | structure move | Δ=-2.04, p=0.13
#   Step 506 | changepoint birth on mobility | Δ=-4.53, p=0.01
#   Step 507 | structure move | Δ=-0.33, p=0.72
#   Step 508 | structure move | Δ=0.91, p=2.49
#   Step 509 | structure move | Δ=-1.94, p=0.14
#   Step 510 | structure move | Δ=-2.99, p=0.05
#   Step 511  Step 512 | changepoint birth on heart_rate | Δ=-2.60, p=0.07
#   Step 513 | changepoint birth on blood_pressure_t-1 | Δ=-4.62, p=0.01
#   Step 514  Step 515 | changepoint birth on oxygen_level | Δ=-5.12, p=0.01
#   Step 516 | structure move | Δ=-0.34, p=0.71
#   Step 517 | changepoint birth on blood_pressure_t-1 | Δ=-6.65, p=0.00
#   Step 518 | structure move | Δ=-2.77, p=0.06
#   Step 519 | structure move | Δ=-0.34, p=0.71
#   Step 520 | structure move | Δ=-3.34, p=0.04
#   Step 521 | structure move | Δ=-1.78, p=0.17
#   Step 522 | changepoint birth on oxygen_level_t-1 | Δ=-2.80, p=0.06
#   Step 523  Step 524 | structure move | Δ=-0.91, p=0.40
#   Step 525 | changepoint birth on heart_rate | Δ=-4.46, p=0.01
#   Step 526  Step 527 | structure move | Δ=-2.77, p=0.06
#   Step 528 | structure move | Δ=-0.62, p=0.54
#   Step 529 | structure move | Δ=-0.13, p=0.88
#   Step 530 | changepoint birth on heart_rate_t-1 | Δ=-2.80, p=0.06
#   Step 531  Step 532 | structure move | Δ=-0.44, p=0.65
#   Step 533  Step 534 | changepoint birth on heart_rate | Δ=-2.60, p=0.07
#   Step 535 | changepoint birth on heart_rate_t-1 | Δ=-3.50, p=0.03
#   Step 536 | structure move | Δ=-1.22, p=0.30
#   Step 537  Step 538  Step 539 | structure move | Δ=-1.45, p=0.23
#   Step 540  Step 541 | structure move | Δ=0.34, p=1.41
#   Step 542 | structure move | Δ=0.65, p=1.92
#   Step 543  Step 544 | structure move | Δ=0.08, p=1.08
#   Step 545  Step 546 | structure move | Δ=-1.03, p=0.36
#   Step 547 | changepoint birth on blood_pressure | Δ=0.49, p=1.64
#   Step 548  Step 549  Step 550  Step 551 | structure move | Δ=-0.32, p=0.73
#   Step 552 | changepoint death on heart_rate_t-1 | Δ=2.52, p=12.37
#   Step 553 | structure move | Δ=-1.97, p=0.14
#   Step 554  Step 555  Step 556 | structure move | Δ=-0.66, p=0.52
#   Step 557  Step 558 | structure move | Δ=-2.50, p=0.08
#   Step 559 | changepoint birth on heart_rate_t-1 | Δ=-4.79, p=0.01
#   Step 560  Step 561 | structure move | Δ=-2.50, p=0.08
#   Step 562  Step 563 | structure move | Δ=-0.33, p=0.72
#   Step 564 | structure move | Δ=-0.70, p=0.50
#   Step 565  Step 566  Step 567 | structure move | Δ=0.56, p=1.75
#   Step 568 | structure move | Δ=-0.70, p=0.50
#   Step 569 | structure move | Δ=-2.50, p=0.08
#   Step 570  Step 571 | structure move | Δ=-2.50, p=0.08
#   Step 572 | structure move | Δ=-2.03, p=0.13
#   Step 573 | structure move | Δ=-0.62, p=0.54
#   Step 574  Step 575 | structure move | Δ=1.98, p=7.22
#   Step 576 | structure move | Δ=-0.70, p=0.50
#   Step 577 | structure move | Δ=-7.39, p=0.00
#   Step 578 | structure move | Δ=-1.11, p=0.33
#   Step 579 | structure move | Δ=-1.37, p=0.25
#   Step 580 | changepoint birth on oxygen_level_t-1 | Δ=-4.68, p=0.01
#   Step 581  Step 582 | changepoint death on blood_pressure | Δ=-0.49, p=0.61
#   Step 583 | structure move | Δ=0.32, p=1.37
#   Step 584 | structure move | Δ=-1.48, p=0.23
#   Step 585 | structure move | Δ=-1.68, p=0.19
#   Step 586  Step 587  Step 588 | structure move | Δ=-0.32, p=0.73
#   Step 589 | changepoint birth on mobility_t-1 | Δ=-4.82, p=0.01
#   Step 590  Step 591 | structure move | Δ=-0.52, p=0.59
#   Step 592 | changepoint birth on pain_level_t-1 | Δ=-4.19, p=0.02
#   Step 593 | structure move | Δ=-1.02, p=0.36
#   Step 594  Step 595 | changepoint birth on oxygen_level | Δ=-4.71, p=0.01
#   Step 596 | structure move | Δ=0.32, p=1.37
#   Step 597 | structure move | Δ=-0.15, p=0.86
#   Step 598 | structure move | Δ=-2.96, p=0.05
#   Step 599 | changepoint birth on heart_rate | Δ=-3.42, p=0.03
#   Step 600 | structure move | Δ=-5.21, p=0.01
#   Step 601 | structure move | Δ=1.97, p=7.20
#   Step 602 | structure move | Δ=-1.18, p=0.31
#   Step 603 | structure move | Δ=-1.35, p=0.26
#   Step 604 | structure move | Δ=0.45, p=1.56
#   Step 605 | structure move | Δ=0.15, p=1.16
#   Step 606 | changepoint birth on heart_rate_t-1 | Δ=1.37, p=3.95
#   Step 607 | changepoint birth on mobility_t-1 | Δ=-4.49, p=0.01
#   Step 608 | structure move | Δ=-0.52, p=0.59
#   Step 609  Step 610  Step 611  Step 612 | structure move | Δ=-0.28, p=0.76
#   Step 613 | structure move | Δ=-0.16, p=0.85
#   Step 614 | structure move | Δ=-1.88, p=0.15
#   Step 615 | structure move | Δ=-0.54, p=0.58
#   Step 616 | changepoint birth on mobility_t-1 | Δ=-5.00, p=0.01
#   Step 617 | structure move | Δ=-2.83, p=0.06
#   Step 618 | changepoint birth on heart_rate | Δ=0.39, p=1.48
#   Step 619  Step 620 | structure move | Δ=0.00, p=1.00
#   Step 621  Step 622 | structure move | Δ=-1.02, p=0.36
#   Step 623 | changepoint birth on pain_level | Δ=-5.02, p=0.01
#   Step 624  Step 625 | structure move | Δ=1.38, p=3.96
#   Step 626 | structure move | Δ=-2.87, p=0.06
#   Step 627  Step 628  Step 629 | changepoint birth on oxygen_level_t-1 | Δ=-4.31, p=0.01
#   Step 630 | structure move | Δ=-0.32, p=0.73
#   Step 631 | structure move | Δ=-2.87, p=0.06
#   Step 632 | structure move | Δ=-0.58, p=0.56
#   Step 633 | structure move | Δ=-1.56, p=0.21
#   Step 634  Step 635 | changepoint shift on heart_rate | Δ=0.00, p=1.00
#   Step 636  Step 637 | structure move | Δ=-3.38, p=0.03
#   Step 638 | structure move | Δ=-1.02, p=0.36
#   Step 639 | changepoint birth on mobility_t-1 | Δ=-4.89, p=0.01
#   Step 640 | structure move | Δ=-0.40, p=0.67
#   Step 641  Step 642 | structure move | Δ=-1.57, p=0.21
#   Step 643 | structure move | Δ=-1.56, p=0.21
#   Step 644 | structure move | Δ=0.58, p=1.78
#   Step 645 | structure move | Δ=0.40, p=1.49
#   Step 646  Step 647  Step 648  Step 649  Step 650  Step 651 | changepoint birth on pain_level_t-1 | Δ=-4.75, p=0.01
#   Step 652  Step 653 | structure move | Δ=0.32, p=1.37
#   Step 654 | changepoint birth on pain_level_t-1 | Δ=-2.28, p=0.10
#   Step 655 | structure move | Δ=1.35, p=3.85
#   Step 656 | changepoint birth on heart_rate_t-1 | Δ=-6.17, p=0.00
#   Step 657 | structure move | Δ=-1.66, p=0.19
#   Step 658 | changepoint birth on mobility | Δ=-5.52, p=0.00
#   Step 659 | changepoint birth on heart_rate_t-1 | Δ=-4.02, p=0.02
#   Step 660  Step 661 | structure move | Δ=-2.74, p=0.06
#   Step 662  Step 663 | changepoint death on heart_rate_t-1 | Δ=-1.37, p=0.25
#   Step 664  Step 665  Step 666 | structure move | Δ=-1.38, p=0.25
#   Step 667 | structure move | Δ=-0.00, p=1.00
#   Step 668 | changepoint shift on heart_rate | Δ=0.00, p=1.00
#   Step 669 | structure move | Δ=0.27, p=1.31
#   Step 670 | changepoint birth on heart_rate | Δ=-5.31, p=0.00
#   Step 671 | changepoint birth on pain_level_t-1 | Δ=-3.95, p=0.02
#   Step 672 | structure move | Δ=-2.55, p=0.08
#   Step 673 | changepoint birth on blood_pressure_t-1 | Δ=-0.99, p=0.37
#   Step 674  Step 675 | structure move | Δ=-0.45, p=0.64
#   Step 676 | structure move | Δ=0.36, p=1.43
#   Step 677  Step 678  Step 679  Step 680  Step 681 | structure move | Δ=-0.24, p=0.78
#   Step 682 | structure move | Δ=-0.08, p=0.92
#   Step 683 | structure move | Δ=0.52, p=1.68
#   Step 684 | changepoint birth on oxygen_level_t-1 | Δ=-5.00, p=0.01
#   Step 685 | structure move | Δ=-0.24, p=0.78
#   Step 686 | structure move | Δ=-0.37, p=0.69
#   Step 687 | changepoint death on heart_rate | Δ=0.55, p=1.74
#   Step 688  Step 689 | structure move | Δ=-3.98, p=0.02
#   Step 690  Step 691 | structure move | Δ=0.56, p=1.75
#   Step 692 | structure move | Δ=-0.54, p=0.58
#   Step 693 | changepoint birth on heart_rate_t-1 | Δ=-5.25, p=0.01
#   Step 694 | structure move | Δ=-2.55, p=0.08
#   Step 695 | structure move | Δ=-1.98, p=0.14
#   Step 696 | structure move | Δ=-0.91, p=0.40
#   Step 697 | structure move | Δ=0.00, p=1.00
#   Step 698 | changepoint birth on pain_level | Δ=-4.12, p=0.02
#   Step 699 | changepoint birth on heart_rate | Δ=-2.17, p=0.11
#   Step 700 | changepoint birth on blood_pressure | Δ=1.39, p=4.00
#   Step 701 | structure move | Δ=-2.55, p=0.08
#   Step 702 | structure move | Δ=-0.56, p=0.57
#   Step 703 | structure move | Δ=0.35, p=1.41
#   Step 704  Step 705  Step 706 | structure move | Δ=-2.99, p=0.05
#   Step 707 | structure move | Δ=-0.62, p=0.54
#   Step 708 | changepoint birth on oxygen_level | Δ=-5.81, p=0.00
#   Step 709 | structure move | Δ=-0.62, p=0.54
#   Step 710  Step 711  Step 712 | structure move | Δ=0.27, p=1.31
#   Step 713 | structure move | Δ=-0.54, p=0.58
#   Step 714 | structure move | Δ=-0.58, p=0.56
#   Step 715  Step 716 | structure move | Δ=-0.36, p=0.70
#   Step 717 | changepoint birth on heart_rate_t-1 | Δ=-3.95, p=0.02
#   Step 718 | changepoint shift on blood_pressure | Δ=0.00, p=1.00
#   Step 719 | structure move | Δ=-1.82, p=0.16
#   Step 720 | changepoint birth on heart_rate | Δ=-5.15, p=0.01
#   Step 721 | structure move | Δ=-0.54, p=0.58
#   Step 722 | structure move | Δ=-0.01, p=0.99
#   Step 723 | structure move | Δ=0.33, p=1.39
#   Step 724 | changepoint birth on heart_rate | Δ=-4.91, p=0.01
#   Step 725 | structure move | Δ=-7.59, p=0.00
#   Step 726  Step 727 | structure move | Δ=-0.00, p=1.00
#   Step 728 | structure move | Δ=-0.35, p=0.71
#   Step 729 | structure move | Δ=0.66, p=1.93
#   Step 730 | changepoint birth on pain_level | Δ=-3.68, p=0.03
#   Step 731 | structure move | Δ=1.82, p=6.16
#   Step 732 | structure move | Δ=-1.24, p=0.29
#   Step 733 | structure move | Δ=-0.45, p=0.64
#   Step 734 | structure move | Δ=-1.24, p=0.29
#   Step 735 | structure move | Δ=0.07, p=1.08
#   Step 736  Step 737 | changepoint birth on heart_rate | Δ=-0.11, p=0.90
#   Step 738 | structure move | Δ=-0.32, p=0.73
#   Step 739 | structure move | Δ=-6.05, p=0.00
#   Step 740 | changepoint birth on heart_rate | Δ=-4.02, p=0.02
#   Step 741  Step 742 | structure move | Δ=-7.39, p=0.00
#   Step 743  Step 744  Step 745 | structure move | Δ=3.66, p=38.89
#   Step 746 | structure move | Δ=-0.07, p=0.93
#   Step 747  Step 748 | structure move | Δ=-1.24, p=0.29
#   Step 749  Step 750 | changepoint birth on pain_level_t-1 | Δ=-3.78, p=0.02
#   Step 751  Step 752 | structure move | Δ=-4.25, p=0.01
#   Step 753  Step 754  Step 755  Step 756  Step 757  Step 758  Step 759 | structure move | Δ=1.24, p=3.47
#   Step 760  Step 761  Step 762 | structure move | Δ=-1.57, p=0.21
#   Step 763 | structure move | Δ=0.63, p=1.87
#   Step 764  Step 765 | changepoint shift on heart_rate | Δ=0.00, p=1.00
#   Step 766 | changepoint birth on heart_rate_t-1 | Δ=-3.78, p=0.02
#   Step 767 | structure move | Δ=-0.70, p=0.49
#   Step 768  Step 769  Step 770 | changepoint birth on oxygen_level_t-1 | Δ=-4.31, p=0.01
#   Step 771 | structure move | Δ=-7.54, p=0.00
#   Step 772  Step 773 | structure move | Δ=-0.57, p=0.57
#   Step 774 | structure move | Δ=-6.18, p=0.00
#   Step 775 | structure move | Δ=-1.58, p=0.21
#   Step 776 | changepoint birth on blood_pressure_t-1 | Δ=-7.53, p=0.00
#   Step 777 | structure move | Δ=-0.69, p=0.50
#   Step 778 | structure move | Δ=-1.57, p=0.21
#   Step 779  Step 780 | changepoint birth on heart_rate | Δ=-6.65, p=0.00
#   Step 781 | structure move | Δ=-2.89, p=0.06
#   Step 782 | changepoint birth on heart_rate | Δ=-5.66, p=0.00
#   Step 783  Step 784  Step 785 | structure move | Δ=-1.18, p=0.31
#   Step 786 | structure move | Δ=-1.34, p=0.26
#   Step 787  Step 788 | structure move | Δ=-1.34, p=0.26
#   Step 789 | changepoint death on heart_rate | Δ=1.01, p=2.75
#   Step 790  Step 791 | structure move | Δ=0.07, p=1.08
#   Step 792 | structure move | Δ=-0.06, p=0.94
#   Step 793 | structure move | Δ=-0.85, p=0.43
#   Step 794 | structure move | Δ=-7.39, p=0.00
#   Step 795  Step 796 | changepoint birth on pain_level | Δ=-4.34, p=0.01
#   Step 797 | structure move | Δ=-1.24, p=0.29
#   Step 798 | changepoint death on blood_pressure | Δ=-1.39, p=0.25
#   Step 799 | structure move | Δ=1.24, p=3.46
#   Step 800 | structure move | Δ=-0.12, p=0.89
#   Step 801 | changepoint birth on mobility | Δ=-6.84, p=0.00
#   Step 802 | structure move | Δ=1.03, p=2.81
#   Step 803 | structure move | Δ=-0.82, p=0.44
#   Step 804 | structure move | Δ=-3.53, p=0.03
#   Step 805  Step 806  Step 807 | structure move | Δ=0.35, p=1.41
#   Step 808 | structure move | Δ=-0.92, p=0.40
#   Step 809  Step 810 | structure move | Δ=-2.89, p=0.06
#   Step 811 | structure move | Δ=-1.03, p=0.36
#   Step 812 | structure move | Δ=-4.25, p=0.01
#   Step 813 | changepoint birth on blood_pressure | Δ=-5.00, p=0.01
#   Step 814 | structure move | Δ=-7.54, p=0.00
#   Step 815 | changepoint birth on oxygen_level_t-1 | Δ=-2.12, p=0.12
#   Step 816  Step 817  Step 818  Step 819 | changepoint birth on heart_rate_t-1 | Δ=-4.50, p=0.01
#   Step 820 | structure move | Δ=-3.53, p=0.03
#   Step 821 | structure move | Δ=1.94, p=6.96
#   Step 822  Step 823 | changepoint shift on blood_pressure | Δ=0.00, p=1.00
#   Step 824  Step 825 | changepoint birth on blood_pressure_t-1 | Δ=-5.12, p=0.01
#   Step 826  Step 827 | structure move | Δ=-3.18, p=0.04
#   Step 828 | structure move | Δ=-2.04, p=0.13
#   Step 829  Step 830 | structure move | Δ=-1.78, p=0.17
#   Step 831  Step 832 | structure move | Δ=-2.18, p=0.11
#   Step 833  Step 834  Step 835 | changepoint shift on oxygen_level_t-1 | Δ=0.00, p=1.00
#   Step 836 | structure move | Δ=1.78, p=5.91
#   Step 837 | structure move | Δ=-0.92, p=0.40
#   Step 838 | changepoint birth on blood_pressure_t-1 | Δ=-3.83, p=0.02
#   Step 839 | structure move | Δ=-3.53, p=0.03
#   Step 840 | structure move | Δ=-1.18, p=0.31
#   Step 841  Step 842 | structure move | Δ=-2.60, p=0.07
#   Step 843 | changepoint birth on mobility | Δ=-4.32, p=0.01
#   Step 844 | structure move | Δ=-4.50, p=0.01
#   Step 845 | structure move | Δ=-2.18, p=0.11
#   Step 846 | structure move | Δ=0.27, p=1.30
#   Step 847 | changepoint birth on heart_rate | Δ=-1.01, p=0.36
#   Step 848 | changepoint death on blood_pressure | Δ=-1.39, p=0.25
#   Step 849 | changepoint birth on heart_rate_t-1 | Δ=-4.07, p=0.02
#   Step 850 | structure move | Δ=-1.02, p=0.36
#   Step 851 | structure move | Δ=-0.07, p=0.93
#   Step 852 | structure move | Δ=-0.27, p=0.76
#   Step 853  Step 854 | structure move | Δ=-1.28, p=0.28
#   Step 855 | structure move | Δ=-1.28, p=0.28
#   Step 856  Step 857 | structure move | Δ=-1.01, p=0.37
#   Step 858 | structure move | Δ=0.07, p=1.08
#   Step 859 | structure move | Δ=-7.39, p=0.00
#   Step 860 | structure move | Δ=-1.28, p=0.28
#   Step 861  Step 862 | structure move | Δ=-2.11, p=0.12
#   Step 863  Step 864 | structure move | Δ=-7.39, p=0.00
#   Step 865  Step 866  Step 867 | structure move | Δ=-0.56, p=0.57
#   Step 868 | structure move | Δ=-3.25, p=0.04
#   Step 869  Step 870  Step 871 | changepoint birth on blood_pressure | Δ=1.39, p=4.00
#   Step 872 | structure move | Δ=0.56, p=1.74
#   Step 873 | changepoint birth on oxygen_level_t-1 | Δ=-3.33, p=0.04
#   Step 874 | structure move | Δ=-0.35, p=0.71
#   Step 875 | changepoint birth on pain_level_t-1 | Δ=-2.11, p=0.12
#   Step 876  Step 877 | structure move | Δ=-3.18, p=0.04
#   Step 878  Step 879 | structure move | Δ=-1.82, p=0.16
#   Step 880 | structure move | Δ=-1.50, p=0.22
#   Step 881  Step 882 | structure move | Δ=-1.50, p=0.22
#   Step 883  Step 884  Step 885  Step 886 | structure move | Δ=-4.55, p=0.01
#   Step 887  Step 888 | changepoint shift on oxygen_level_t-1 | Δ=0.00, p=1.00
#   Step 889 | structure move | Δ=0.08, p=1.08
#   Step 890 | structure move | Δ=0.37, p=1.45
#   Step 891  Step 892  Step 893 | changepoint birth on pain_level | Δ=-5.09, p=0.01
#   Step 894  Step 895  Step 896 | changepoint shift on heart_rate | Δ=0.00, p=1.00
#   Step 897 | changepoint birth on mobility_t-1 | Δ=-5.00, p=0.01
#   Step 898 | structure move | Δ=-7.43, p=0.00
#   Step 899 | changepoint birth on blood_pressure | Δ=-2.11, p=0.12
#   Step 900 | structure move | Δ=-4.50, p=0.01
#   Step 901 | structure move | Δ=-3.53, p=0.03
#   Step 902 | structure move | Δ=1.82, p=6.16
#   Step 903  Step 904 | structure move | Δ=-1.97, p=0.14
#   Step 905  Step 906  Step 907 | structure move | Δ=-3.66, p=0.03
#   Step 908 | structure move | Δ=-2.89, p=0.06
#   Step 909 | structure move | Δ=-0.28, p=0.76
#   Step 910 | changepoint birth on heart_rate | Δ=-6.54, p=0.00
#   Step 911 | structure move | Δ=1.18, p=3.25
#   Step 912 | structure move | Δ=-3.25, p=0.04
#   Step 913 | structure move | Δ=-4.50, p=0.01
#   Step 914 | structure move | Δ=0.22, p=1.25
#   Step 915 | structure move | Δ=-1.87, p=0.15
#   Step 916  Step 917 | structure move | Δ=-0.94, p=0.39
#   Step 918 | changepoint birth on pain_level | Δ=-6.02, p=0.00
#   Step 919 | structure move | Δ=-1.87, p=0.15
#   Step 920 | structure move | Δ=-7.43, p=0.00
#   Step 921  Step 922 | changepoint birth on oxygen_level_t-1 | Δ=-5.00, p=0.01
#   Step 923 | structure move | Δ=-1.79, p=0.17
#   Step 924 | structure move | Δ=-0.37, p=0.69
#   Step 925 | structure move | Δ=1.01, p=2.74
#   Step 926 | changepoint death on heart_rate | Δ=3.73, p=41.68
#   Step 927 | structure move | Δ=-1.35, p=0.26
#   Step 928 | structure move | Δ=-4.55, p=0.01
#   Step 929 | changepoint birth on oxygen_level_t-1 | Δ=-4.31, p=0.01
#   Step 930 | changepoint birth on blood_pressure | Δ=1.71, p=5.53
#   Step 931 | structure move | Δ=-4.55, p=0.01
#   Step 932 | changepoint shift on oxygen_level_t-1 | Δ=0.00, p=1.00
#   Step 933 | structure move | Δ=-4.25, p=0.01
#   Step 934 | changepoint death on blood_pressure | Δ=3.61, p=37.10
#   Step 935 | structure move | Δ=-0.49, p=0.61
#   Step 936  Step 937 | structure move | Δ=0.46, p=1.58
#   Step 938 | structure move | Δ=-1.01, p=0.37
#   Step 939 | changepoint birth on pain_level | Δ=-4.95, p=0.01
#   Step 940  Step 941  Step 942  Step 943  Step 944 | structure move | Δ=-0.27, p=0.76
#   Step 945  Step 946 | changepoint birth on blood_pressure | Δ=-2.52, p=0.08
#   Step 947 | structure move | Δ=-3.47, p=0.03
#   Step 948 | changepoint death on oxygen_level_t-1 | Δ=3.14, p=23.19
#   Step 949 | changepoint birth on blood_pressure_t-1 | Δ=-2.50, p=0.08
#   Step 950  Step 951  Step 952  Step 953 | structure move | Δ=-3.25, p=0.04
#   Step 954 | changepoint birth on mobility | Δ=-4.56, p=0.01
#   Step 955 | structure move | Δ=-0.07, p=0.93
#   Step 956 | structure move | Δ=-3.30, p=0.04
#   Step 957  Step 958 | structure move | Δ=-5.99, p=0.00
#   Step 959 | structure move | Δ=-6.18, p=0.00
#   Step 960  Step 961 | structure move | Δ=2.11, p=8.28
#   Step 962 | structure move | Δ=-1.35, p=0.26
#   Step 963 | changepoint birth on oxygen_level | Δ=-2.79, p=0.06
#   Step 964  Step 965 | changepoint birth on pain_level | Δ=-4.99, p=0.01
#   Step 966  Step 967 | changepoint death on blood_pressure | Δ=-6.71, p=0.00
#   Step 968 | changepoint birth on pain_level_t-1 | Δ=-2.80, p=0.06
#   Step 969 | structure move | Δ=-1.24, p=0.29
#   Step 970  Step 971 | structure move | Δ=-0.49, p=0.61
#   Step 972 | changepoint birth on pain_level_t-1 | Δ=-4.05, p=0.02
#   Step 973 | changepoint birth on oxygen_level | Δ=-3.07, p=0.05
#   Step 974 | changepoint birth on mobility | Δ=-4.04, p=0.02
#   Step 975 | structure move | Δ=-0.46, p=0.63
#   Step 976 | changepoint death on oxygen_level | Δ=3.07, p=21.64
#   Step 977  Step 978 | structure move | Δ=-1.57, p=0.21
#   Step 979 | structure move | Δ=0.57, p=1.76
#   Step 980 | structure move | Δ=-0.44, p=0.65
#   Step 981 | changepoint death on oxygen_level_t-1 | Δ=3.10, p=22.26
#   Step 982 | structure move | Δ=1.27, p=3.56
#   Step 983 | changepoint birth on heart_rate | Δ=-3.58, p=0.03
#   Step 984 | structure move | Δ=-1.93, p=0.15
#   Step 985 | structure move | Δ=-1.93, p=0.15
#   Step 986  Step 987  Step 988 | structure move | Δ=-1.68, p=0.19
#   Step 989 | structure move | Δ=-3.66, p=0.03
#   Step 990  Step 991  Step 992  Step 993  Step 994  Step 995 | changepoint birth on oxygen_level_t-1 | Δ=-3.43, p=0.03
#   Step 996  Step 997 | structure move | Δ=-0.66, p=0.52
#   Step 998 | structure move | Δ=-1.68, p=0.19
#   Step 999 | structure move | Δ=-2.32, p=0.10
# Subject 1 done | best score = -164.60
# Processing subject 2
#   Step 0 | structure move | Δ=-0.86, p=0.42
#   Step 1 | structure move | Δ=-1.25, p=0.29
#   Step 2  Step 3 | structure move | Δ=0.68, p=1.98
#   Step 4  Step 5 | structure move | Δ=0.37, p=1.44
#   Step 6 | structure move | Δ=1.68, p=5.36
#   Step 7 | changepoint birth on heart_rate_t-1 | Δ=-0.20, p=0.82
#   Step 8  Step 9  Step 10 | structure move | Δ=-0.37, p=0.69
#   Step 11 | structure move | Δ=-1.13, p=0.32
#   Step 12 | structure move | Δ=0.82, p=2.26
#   Step 13  Step 14 | changepoint birth on blood_pressure_t-1 | Δ=-4.70, p=0.01
#   Step 15 | structure move | Δ=1.29, p=3.64
#   Step 16 | structure move | Δ=-1.08, p=0.34
#   Step 17 | structure move | Δ=-0.49, p=0.62
#   Step 18  Step 19 | changepoint birth on mobility_t-1 | Δ=-4.53, p=0.01
#   Step 20 | changepoint birth on mobility | Δ=-3.54, p=0.03
#   Step 21 | changepoint birth on heart_rate | Δ=-3.76, p=0.02
#   Step 22 | structure move | Δ=0.71, p=2.03
#   Step 23  Step 24 | structure move | Δ=-0.82, p=0.44
#   Step 25 | structure move | Δ=-1.35, p=0.26
#   Step 26  Step 27  Step 28  Step 29  Step 30 | structure move | Δ=0.82, p=2.26
#   Step 31 | structure move | Δ=-2.65, p=0.07
#   Step 32 | structure move | Δ=-0.49, p=0.62
#   Step 33  Step 34 | changepoint birth on mobility | Δ=-5.85, p=0.00
#   Step 35  Step 36 | changepoint birth on heart_rate | Δ=-3.76, p=0.02
#   Step 37 | structure move | Δ=-1.49, p=0.23
#   Step 38  Step 39 | structure move | Δ=-1.26, p=0.28
#   Step 40  Step 41 | changepoint birth on oxygen_level_t-1 | Δ=-4.88, p=0.01
#   Step 42 | changepoint birth on mobility | Δ=-3.03, p=0.05
#   Step 43 | structure move | Δ=-1.26, p=0.28
#   Step 44 | structure move | Δ=-2.43, p=0.09
#   Step 45 | structure move | Δ=-0.82, p=0.44
#   Step 46  Step 47 | structure move | Δ=-0.65, p=0.52
#   Step 48  Step 49 | structure move | Δ=-0.23, p=0.79
#   Step 50 | structure move | Δ=-0.69, p=0.50
#   Step 51  Step 52  Step 53 | structure move | Δ=0.98, p=2.67
#   Step 54  Step 55 | structure move | Δ=0.00, p=1.00
#   Step 56 | changepoint birth on blood_pressure | Δ=-2.45, p=0.09
#   Step 57 | structure move | Δ=-0.71, p=0.49
#   Step 58 | structure move | Δ=-0.82, p=0.44
#   Step 59 | structure move | Δ=3.65, p=38.57
#   Step 60 | structure move | Δ=-1.08, p=0.34
#   Step 61 | changepoint birth on blood_pressure | Δ=-4.20, p=0.02
#   Step 62 | structure move | Δ=-0.15, p=0.86
#   Step 63 | structure move | Δ=-1.79, p=0.17
#   Step 64 | structure move | Δ=-1.29, p=0.28
#   Step 65  Step 66 | changepoint birth on blood_pressure_t-1 | Δ=-1.77, p=0.17
#   Step 67 | structure move | Δ=-1.79, p=0.17
#   Step 68 | structure move | Δ=-0.65, p=0.52
#   Step 69 | structure move | Δ=-0.98, p=0.38
#   Step 70 | structure move | Δ=-1.66, p=0.19
#   Step 71  Step 72 | structure move | Δ=0.58, p=1.79
#   Step 73  Step 74 | structure move | Δ=-0.47, p=0.62
#   Step 75  Step 76  Step 77  Step 78 | changepoint death on heart_rate_t-1 | Δ=0.20, p=1.22
#   Step 79 | structure move | Δ=-1.14, p=0.32
#   Step 80 | structure move | Δ=1.14, p=3.12
#   Step 81  Step 82 | structure move | Δ=0.69, p=2.00
#   Step 83 | structure move | Δ=-0.98, p=0.38
#   Step 84  Step 85  Step 86 | changepoint birth on oxygen_level_t-1 | Δ=-4.35, p=0.01
#   Step 87  Step 88  Step 89 | structure move | Δ=-2.37, p=0.09
#   Step 90 | structure move | Δ=-2.42, p=0.09
#   Step 91 | structure move | Δ=0.71, p=2.04
#   Step 92 | structure move | Δ=-0.58, p=0.56
#   Step 93  Step 94 | structure move | Δ=-1.50, p=0.22
#   Step 95  Step 96  Step 97  Step 98 | changepoint birth on pain_level | Δ=-3.45, p=0.03
#   Step 99  Step 100 | changepoint birth on blood_pressure | Δ=-3.50, p=0.03
#   Step 101 | structure move | Δ=-0.07, p=0.93
#   Step 102  Step 103  Step 104  Step 105  Step 106  Step 107  Step 108  Step 109 | changepoint birth on pain_level | Δ=-3.78, p=0.02
#   Step 110  Step 111 | structure move | Δ=-0.51, p=0.60
#   Step 112  Step 113  Step 114 | structure move | Δ=1.25, p=3.48
#   Step 115 | structure move | Δ=-1.68, p=0.19
#   Step 116  Step 117  Step 118 | changepoint birth on mobility | Δ=-5.79, p=0.00
#   Step 119  Step 120 | structure move | Δ=1.26, p=3.54
#   Step 121 | changepoint birth on heart_rate_t-1 | Δ=-6.54, p=0.00
#   Step 122  Step 123 | structure move | Δ=-1.68, p=0.19
#   Step 124 | structure move | Δ=0.00, p=1.00
#   Step 125 | structure move | Δ=1.57, p=4.82
#   Step 126 | structure move | Δ=-0.18, p=0.83
#   Step 127  Step 128  Step 129 | structure move | Δ=3.25, p=25.71
#   Step 130  Step 131 | structure move | Δ=-1.08, p=0.34
#   Step 132  Step 133 | structure move | Δ=-1.57, p=0.21
#   Step 134  Step 135  Step 136 | structure move | Δ=-3.25, p=0.04
#   Step 137  Step 138  Step 139  Step 140 | structure move | Δ=1.29, p=3.64
#   Step 141 | structure move | Δ=0.94, p=2.57
#   Step 142 | structure move | Δ=-1.25, p=0.29
#   Step 143 | structure move | Δ=-1.73, p=0.18
#   Step 144 | structure move | Δ=0.18, p=1.20
#   Step 145  Step 146 | structure move | Δ=-0.69, p=0.50
#   Step 147 | structure move | Δ=-0.38, p=0.69
#   Step 148 | structure move | Δ=-1.32, p=0.27
#   Step 149  Step 150 | changepoint birth on pain_level | Δ=-3.78, p=0.02
#   Step 151 | structure move | Δ=-1.73, p=0.18
#   Step 152 | structure move | Δ=-0.86, p=0.42
#   Step 153 | changepoint birth on mobility | Δ=-5.81, p=0.00
#   Step 154 | structure move | Δ=-3.62, p=0.03
#   Step 155  Step 156 | structure move | Δ=0.86, p=2.36
#   Step 157 | structure move | Δ=-1.66, p=0.19
#   Step 158 | structure move | Δ=0.00, p=1.00
#   Step 159 | structure move | Δ=-1.14, p=0.32
#   Step 160 | structure move | Δ=0.00, p=1.00
#   Step 161 | structure move | Δ=-3.18, p=0.04
#   Step 162  Step 163 | structure move | Δ=-2.62, p=0.07
#   Step 164 | structure move | Δ=1.03, p=2.81
#   Step 165 | structure move | Δ=1.66, p=5.25
#   Step 166 | changepoint birth on pain_level | Δ=-4.79, p=0.01
#   Step 167 | structure move | Δ=-0.18, p=0.83
#   Step 168  Step 169 | structure move | Δ=0.05, p=1.05
#   Step 170 | structure move | Δ=-1.25, p=0.29
#   Step 171 | changepoint birth on mobility | Δ=-5.12, p=0.01
#   Step 172 | structure move | Δ=-1.03, p=0.36
#   Step 173  Step 174 | structure move | Δ=0.59, p=1.80
#   Step 175  Step 176 | structure move | Δ=-0.05, p=0.95
#   Step 177  Step 178 | structure move | Δ=1.39, p=4.00
#   Step 179 | structure move | Δ=-3.25, p=0.04
#   Step 180 | structure move | Δ=-2.08, p=0.13
#   Step 181 | structure move | Δ=0.00, p=1.00
#   Step 182 | structure move | Δ=-1.39, p=0.25
#   Step 183 | structure move | Δ=-1.39, p=0.25
#   Step 184 | changepoint birth on oxygen_level_t-1 | Δ=-4.43, p=0.01
#   Step 185  Step 186  Step 187  Step 188  Step 189 | structure move | Δ=-1.08, p=0.34
#   Step 190  Step 191  Step 192  Step 193  Step 194  Step 195 | structure move | Δ=1.08, p=2.95
#   Step 196 | structure move | Δ=-0.98, p=0.38
#   Step 197 | changepoint birth on mobility | Δ=-5.81, p=0.00
#   Step 198 | structure move | Δ=0.15, p=1.17
#   Step 199 | structure move | Δ=-3.58, p=0.03
#   Step 200 | changepoint birth on pain_level | Δ=-3.69, p=0.03
#   Step 201 | structure move | Δ=-0.98, p=0.38
#   Step 202 | changepoint birth on oxygen_level_t-1 | Δ=-4.60, p=0.01
#   Step 203 | structure move | Δ=-1.39, p=0.25
#   Step 204 | changepoint birth on mobility_t-1 | Δ=-3.61, p=0.03
#   Step 205 | structure move | Δ=-0.98, p=0.38
#   Step 206  Step 207 | structure move | Δ=-0.59, p=0.56
#   Step 208 | structure move | Δ=-1.08, p=0.34
#   Step 209 | structure move | Δ=-0.98, p=0.38
#   Step 210  Step 211 | structure move | Δ=-0.14, p=0.87
#   Step 212 | structure move | Δ=-1.10, p=0.33
#   Step 213 | changepoint birth on oxygen_level | Δ=-4.66, p=0.01
#   Step 214 | structure move | Δ=-1.32, p=0.27
#   Step 215 | changepoint birth on heart_rate_t-1 | Δ=-4.19, p=0.02
#   Step 216  Step 217 | structure move | Δ=0.59, p=1.80
#   Step 218  Step 219  Step 220  Step 221 | structure move | Δ=0.18, p=1.20
#   Step 222  Step 223 | structure move | Δ=-0.12, p=0.89
#   Step 224 | structure move | Δ=1.46, p=4.29
#   Step 225 | structure move | Δ=-2.02, p=0.13
#   Step 226  Step 227 | structure move | Δ=-3.58, p=0.03
#   Step 228  Step 229  Step 230  Step 231  Step 232 | structure move | Δ=-1.83, p=0.16
#   Step 233  Step 234 | structure move | Δ=0.00, p=1.00
#   Step 235 | structure move | Δ=0.69, p=2.00
#   Step 236  Step 237 | changepoint birth on blood_pressure_t-1 | Δ=-4.48, p=0.01
#   Step 238 | changepoint birth on mobility | Δ=-4.71, p=0.01
#   Step 239 | changepoint birth on heart_rate | Δ=-2.80, p=0.06
#   Step 240 | structure move | Δ=0.12, p=1.13
#   Step 241 | structure move | Δ=0.38, p=1.46
#   Step 242 | structure move | Δ=-1.29, p=0.28
#   Step 243 | structure move | Δ=-0.18, p=0.83
#   Step 244 | structure move | Δ=1.79, p=6.00
#   Step 245  Step 246  Step 247 | changepoint birth on blood_pressure_t-1 | Δ=-4.48, p=0.01
#   Step 248 | structure move | Δ=-2.89, p=0.06
#   Step 249  Step 250  Step 251  Step 252 | structure move | Δ=-2.20, p=0.11
#   Step 253  Step 254  Step 255  Step 256 | structure move | Δ=-0.45, p=0.64
#   Step 257 | structure move | Δ=-1.17, p=0.31
#   Step 258  Step 259 | structure move | Δ=-2.62, p=0.07
# ...
#   Step 626 | structure move | Δ=0.79, p=2.20
#   Step 627 | structure move | Δ=-1.86, p=0.16
#   Step 628 | structure move | Δ=0.00, p=1.00
#   Step 629 | structure move | Δ=-0.41, p=0.67
#   Step 630 | structure move | Δ=-2.48, p=0.08
#   Step 631  Step 632 | structure move | Δ=-3.58, p=0.03
#   Step 633 | structure move | Δ=-0.73, p=0.48
#   Step 634  Step 635 | changepoint birth on blood_pressure | Δ=-5.00, p=0.01
#   Step 636  Step 637 | structure move | Δ=-2.55, p=0.08
#   Step 638 | structure move | Δ=0.83, p=2.29
#   Step 639 | structure move | Δ=-0.69, p=0.50
#   Step 640 | structure move | Δ=-2.48, p=0.08
#   Step 641 | structure move | Δ=0.69, p=2.00
#   Step 642  Step 643 | structure move | Δ=1.10, p=3.00
#   Step 644  Step 645  Step 646 | structure move | Δ=-0.88, p=0.42
#   Step 647 | structure move | Δ=-0.17, p=0.84
#   Step 648 | structure move | Δ=-1.50, p=0.22
#   Step 649 | structure move | Δ=-0.88, p=0.42
#   Step 650 | changepoint birth on blood_pressure_t-1 | Δ=-4.31, p=0.01
#   Step 651 | changepoint birth on blood_pressure | Δ=-5.00, p=0.01
#   Step 652 | structure move | Δ=-1.10, p=0.33
#   Step 653 | changepoint shift on blood_pressure | Δ=0.00, p=1.00
#   Step 654 | structure move | Δ=-2.48, p=0.08
#   Step 655 | structure move | Δ=-0.88, p=0.42
#   Step 656 | structure move | Δ=0.88, p=2.40
#   Step 657 | structure move | Δ=-1.67, p=0.19
#   Step 658 | structure move | Δ=-0.13, p=0.88
#   Step 659 | structure move | Δ=0.89, p=2.44
#   Step 660 | structure move | Δ=-0.67, p=0.51
#   Step 661 | structure move | Δ=-2.48, p=0.08
#   Step 662 | structure move | Δ=0.13, p=1.14
#   Step 663 | structure move | Δ=-0.69, p=0.50
#   Step 664 | structure move | Δ=-0.89, p=0.41
#   Step 665 | structure move | Δ=1.39, p=4.00
#   Step 666  Step 667 | structure move | Δ=-0.94, p=0.39
#   Step 668 | structure move | Δ=0.29, p=1.33
#   Step 669 | structure move | Δ=2.16, p=8.70
#   Step 670 | changepoint birth on oxygen_level_t-1 | Δ=-5.41, p=0.00
#   Step 671  Step 672 | structure move | Δ=-2.89, p=0.06
#   Step 673  Step 674 | changepoint birth on mobility_t-1 | Δ=-1.76, p=0.17
#   Step 675  Step 676 | structure move | Δ=0.94, p=2.56
#   Step 677  Step 678 | structure move | Δ=0.58, p=1.78
#   Step 679 | structure move | Δ=-1.10, p=0.33
#   Step 680 | changepoint birth on pain_level_t-1 | Δ=-5.56, p=0.00
#   Step 681  Step 682  Step 683  Step 684 | changepoint birth on oxygen_level_t-1 | Δ=-4.31, p=0.01
#   Step 685 | structure move | Δ=-1.67, p=0.19
#   Step 686 | changepoint birth on pain_level_t-1 | Δ=-5.15, p=0.01
#   Step 687 | changepoint birth on heart_rate_t-1 | Δ=-4.31, p=0.01
#   Step 688 | changepoint death on blood_pressure | Δ=-2.64, p=0.07
#   Step 689  Step 690 | structure move | Δ=-1.50, p=0.22
#   Step 691 | structure move | Δ=-2.48, p=0.08
#   Step 692 | structure move | Δ=-2.89, p=0.06
#   Step 693 | structure move | Δ=-1.01, p=0.36
#   Step 694 | structure move | Δ=2.48, p=12.00
#   Step 695  Step 696 | changepoint birth on heart_rate_t-1 | Δ=-3.90, p=0.02
#   Step 697 | changepoint birth on blood_pressure_t-1 | Δ=-3.50, p=0.03
#   Step 698  Step 699 | structure move | Δ=-1.50, p=0.22
#   Step 700 | structure move | Δ=-0.94, p=0.39
#   Step 701 | structure move | Δ=-0.56, p=0.57
#   Step 702 | structure move | Δ=0.18, p=1.20
#   Step 703  Step 704 | structure move | Δ=-1.10, p=0.33
#   Step 705  Step 706  Step 707  Step 708  Step 709 | structure move | Δ=-1.10, p=0.33
#   Step 710 | structure move | Δ=-1.86, p=0.16
#   Step 711 | structure move | Δ=-0.69, p=0.50
#   Step 712 | structure move | Δ=-2.16, p=0.11
#   Step 713  Step 714  Step 715 | structure move | Δ=-2.16, p=0.11
#   Step 716 | changepoint birth on heart_rate | Δ=-4.59, p=0.01
#   Step 717 | structure move | Δ=0.12, p=1.13
#   Step 718 | structure move | Δ=-0.47, p=0.62
#   Step 719 | structure move | Δ=1.10, p=3.00
#   Step 720 | structure move | Δ=-0.41, p=0.67
#   Step 721 | structure move | Δ=0.56, p=1.75
#   Step 722  Step 723 | changepoint birth on pain_level | Δ=-5.62, p=0.00
#   Step 724 | structure move | Δ=0.25, p=1.28
#   Step 725  Step 726 | structure move | Δ=-2.48, p=0.08
#   Step 727 | structure move | Δ=-0.78, p=0.46
#   Step 728  Step 729 | structure move | Δ=1.01, p=2.76
#   Step 730 | structure move | Δ=-1.50, p=0.22
#   Step 731 | changepoint shift on blood_pressure | Δ=0.00, p=1.00
#   Step 732 | structure move | Δ=1.13, p=3.09
#   Step 733 | changepoint birth on pain_level | Δ=-5.00, p=0.01
#   Step 734  Step 735 | structure move | Δ=0.41, p=1.50
#   Step 736 | structure move | Δ=-0.29, p=0.75
#   Step 737  Step 738 | structure move | Δ=0.17, p=1.19
#   Step 739 | structure move | Δ=-2.77, p=0.06
#   Step 740  Step 741 | changepoint shift on blood_pressure | Δ=0.00, p=1.00
#   Step 742 | structure move | Δ=-0.06, p=0.94
#   Step 743 | structure move | Δ=-0.98, p=0.37
#   Step 744 | changepoint birth on oxygen_level_t-1 | Δ=-4.71, p=0.01
#   Step 745 | changepoint birth on heart_rate | Δ=-2.40, p=0.09
#   Step 746 | structure move | Δ=-2.64, p=0.07
#   Step 747  Step 748 | structure move | Δ=0.15, p=1.17
#   Step 749 | structure move | Δ=-2.16, p=0.11
#   Step 750  Step 751 | structure move | Δ=-1.10, p=0.33
#   Step 752 | changepoint death on blood_pressure | Δ=-3.45, p=0.03
#   Step 753 | structure move | Δ=0.29, p=1.33
#   Step 754 | structure move | Δ=-0.81, p=0.44
#   Step 755 | structure move | Δ=-2.48, p=0.08
#   Step 756 | changepoint birth on blood_pressure | Δ=-4.31, p=0.01
#   Step 757 | structure move | Δ=-1.04, p=0.35
#   Step 758  Step 759 | structure move | Δ=-1.86, p=0.16
#   Step 760 | structure move | Δ=1.39, p=4.00
#   Step 761  Step 762 | changepoint shift on blood_pressure | Δ=0.00, p=1.00
#   Step 763 | changepoint shift on blood_pressure | Δ=0.00, p=1.00
#   Step 764 | changepoint birth on mobility_t-1 | Δ=-2.92, p=0.05
#   Step 765 | structure move | Δ=-0.29, p=0.75
#   Step 766  Step 767 | changepoint death on blood_pressure | Δ=-3.45, p=0.03
#   Step 768 | changepoint birth on heart_rate | Δ=-3.90, p=0.02
#   Step 769 | structure move | Δ=0.98, p=2.67
#   Step 770  Step 771  Step 772 | structure move | Δ=-1.86, p=0.16
#   Step 773  Step 774  Step 775  Step 776 | structure move | Δ=1.03, p=2.81
#   Step 777  Step 778 | changepoint birth on oxygen_level | Δ=-5.41, p=0.00
#   Step 779 | structure move | Δ=-0.12, p=0.89
#   Step 780 | structure move | Δ=-2.16, p=0.11
#   Step 781 | structure move | Δ=-0.29, p=0.75
#   Step 782  Step 783  Step 784  Step 785 | changepoint death on blood_pressure | Δ=-2.64, p=0.07
#   Step 786 | structure move | Δ=-0.69, p=0.50
#   Step 787 | structure move | Δ=-0.22, p=0.80
#   Step 788  Step 789 | changepoint birth on blood_pressure | Δ=-4.31, p=0.01
#   Step 790 | changepoint birth on pain_level_t-1 | Δ=-1.01, p=0.36
#   Step 791 | changepoint birth on oxygen_level | Δ=-5.41, p=0.00
#   Step 792 | structure move | Δ=-0.29, p=0.75
#   Step 793 | changepoint death on pain_level_t-1 | Δ=1.01, p=2.75
#   Step 794  Step 795  Step 796  Step 797 | structure move | Δ=-2.48, p=0.08
#   Step 798 | structure move | Δ=-0.18, p=0.83
#   Step 799 | structure move | Δ=0.97, p=2.63
#   Step 800 | structure move | Δ=-1.10, p=0.33
#   Step 801 | structure move | Δ=0.22, p=1.25
#   Step 802 | changepoint birth on oxygen_level | Δ=-5.00, p=0.01
#   Step 803 | changepoint birth on pain_level_t-1 | Δ=-5.15, p=0.01
#   Step 804  Step 805  Step 806 | structure move | Δ=-0.15, p=0.86
#   Step 807 | structure move | Δ=-0.29, p=0.75
#   Step 808  Step 809  Step 810 | structure move | Δ=-0.69, p=0.50
#   Step 811  Step 812 | structure move | Δ=-0.06, p=0.94
#   Step 813 | structure move | Δ=-2.34, p=0.10
#   Step 814 | changepoint birth on pain_level | Δ=-3.90, p=0.02
#   Step 815 | structure move | Δ=-0.56, p=0.57
#   Step 816  Step 817 | changepoint birth on mobility_t-1 | Δ=-4.31, p=0.01
#   Step 818  Step 819  Step 820  Step 821  Step 822  Step 823 | changepoint birth on heart_rate | Δ=-5.00, p=0.01
#   Step 824 | structure move | Δ=0.06, p=1.07
#   Step 825 | structure move | Δ=-0.98, p=0.37
#   Step 826  Step 827 | structure move | Δ=-0.97, p=0.38
#   Step 828 | changepoint birth on mobility_t-1 | Δ=-2.92, p=0.05
#   Step 829  Step 830 | changepoint birth on mobility_t-1 | Δ=-2.92, p=0.05
#   Step 831 | structure move | Δ=0.18, p=1.20
#   Step 832  Step 833  Step 834 | changepoint birth on mobility_t-1 | Δ=-3.61, p=0.03
#   Step 835 | structure move | Δ=-2.12, p=0.12
#   Step 836 | changepoint birth on heart_rate | Δ=-3.78, p=0.02
#   Step 837 | changepoint birth on heart_rate_t-1 | Δ=-2.80, p=0.06
#   Step 838 | structure move | Δ=-2.48, p=0.08
#   Step 839 | structure move | Δ=0.69, p=2.00
#   Step 840 | structure move | Δ=-2.08, p=0.12
#   Step 841 | changepoint birth on oxygen_level_t-1 | Δ=-4.82, p=0.01
#   Step 842 | structure move | Δ=2.77, p=16.00
#   Step 843 | structure move | Δ=0.04, p=1.04
#   Step 844 | changepoint death on blood_pressure | Δ=-2.64, p=0.07
#   Step 845 | structure move | Δ=0.22, p=1.25
#   Step 846 | changepoint birth on blood_pressure_t-1 | Δ=-3.21, p=0.04
#   Step 847 | changepoint birth on mobility | Δ=-4.71, p=0.01
#   Step 848 | structure move | Δ=-0.98, p=0.37
#   Step 849  Step 850 | structure move | Δ=-0.17, p=0.84
#   Step 851 | structure move | Δ=-1.10, p=0.33
#   Step 852  Step 853 | changepoint birth on heart_rate_t-1 | Δ=-3.41, p=0.03
#   Step 854  Step 855  Step 856 | structure move | Δ=0.98, p=2.67
#   Step 857 | changepoint birth on oxygen_level_t-1 | Δ=-5.51, p=0.00
#   Step 858 | changepoint birth on oxygen_level_t-1 | Δ=-4.82, p=0.01
#   Step 859 | structure move | Δ=1.50, p=4.50
#   Step 860  Step 861 | structure move | Δ=0.56, p=1.75
#   Step 862 | structure move | Δ=-0.98, p=0.37
#   Step 863 | structure move | Δ=-1.39, p=0.25
#   Step 864 | structure move | Δ=-2.20, p=0.11
#   Step 865 | structure move | Δ=-2.22, p=0.11
#   Step 866 | structure move | Δ=-1.10, p=0.33
#   Step 867 | changepoint birth on pain_level | Δ=-1.59, p=0.20
#   Step 868 | changepoint birth on pain_level_t-1 | Δ=-5.15, p=0.01
#   Step 869 | structure move | Δ=-0.56, p=0.57
#   Step 870 | changepoint birth on pain_level_t-1 | Δ=-3.90, p=0.02
#   Step 871 | changepoint death on blood_pressure | Δ=-2.64, p=0.07
#   Step 872 | changepoint death on blood_pressure | Δ=-2.64, p=0.07
#   Step 873 | structure move | Δ=-1.50, p=0.22
#   Step 874  Step 875  Step 876  Step 877 | structure move | Δ=-1.10, p=0.33
#   Step 878 | structure move | Δ=0.98, p=2.67
#   Step 879 | changepoint birth on pain_level | Δ=-3.21, p=0.04
#   Step 880  Step 881  Step 882 | structure move | Δ=-0.04, p=0.96
#   Step 883  Step 884 | structure move | Δ=0.56, p=1.75
#   Step 885 | structure move | Δ=-0.56, p=0.57
#   Step 886  Step 887 | changepoint birth on oxygen_level | Δ=-5.00, p=0.01
#   Step 888 | structure move | Δ=-0.17, p=0.84
#   Step 889  Step 890  Step 891 | structure move | Δ=-0.69, p=0.50
#   Step 892  Step 893 | structure move | Δ=-0.97, p=0.38
#   Step 894 | structure move | Δ=-2.22, p=0.11
#   Step 895 | structure move | Δ=0.58, p=1.78
#   Step 896 | changepoint birth on oxygen_level | Δ=-4.02, p=0.02
#   Step 897  Step 898 | structure move | Δ=-1.35, p=0.26
#   Step 899 | structure move | Δ=0.00, p=1.00
#   Step 900 | structure move | Δ=-0.81, p=0.44
#   Step 901  Step 902 | changepoint birth on pain_level_t-1 | Δ=-5.86, p=0.00
#   Step 903 | structure move | Δ=-2.20, p=0.11
#   Step 904 | structure move | Δ=-0.56, p=0.57
#   Step 905  Step 906 | structure move | Δ=0.56, p=1.75
#   Step 907  Step 908  Step 909 | structure move | Δ=-0.81, p=0.44
#   Step 910 | structure move | Δ=-0.22, p=0.80
#   Step 911  Step 912 | changepoint birth on heart_rate | Δ=-3.09, p=0.05
#   Step 913  Step 914  Step 915 | structure move | Δ=1.10, p=3.00
#   Step 916 | structure move | Δ=-1.35, p=0.26
#   Step 917 | structure move | Δ=-0.56, p=0.57
#   Step 918 | changepoint birth on oxygen_level | Δ=-4.02, p=0.02
#   Step 919 | structure move | Δ=-0.18, p=0.83
#   Step 920 | structure move | Δ=-1.83, p=0.16
#   Step 921 | structure move | Δ=-0.52, p=0.59
#   Step 922 | changepoint shift on heart_rate | Δ=0.00, p=1.00
#   Step 923 | structure move | Δ=-0.56, p=0.57
#   Step 924  Step 925 | changepoint birth on blood_pressure | Δ=-2.57, p=0.08
#   Step 926  Step 927 | structure move | Δ=-2.48, p=0.08
#   Step 928 | structure move | Δ=-0.69, p=0.50
#   Step 929 | structure move | Δ=-2.60, p=0.07
#   Step 930 | structure move | Δ=-1.97, p=0.14
#   Step 931  Step 932 | changepoint birth on blood_pressure | Δ=-3.09, p=0.05
#   Step 933 | structure move | Δ=0.12, p=1.13
#   Step 934  Step 935 | changepoint birth on blood_pressure | Δ=-3.90, p=0.02
#   Step 936  Step 937 | structure move | Δ=-0.12, p=0.89
#   Step 938 | structure move | Δ=0.18, p=1.20
#   Step 939  Step 940 | structure move | Δ=-0.71, p=0.49
#   Step 941  Step 942 | structure move | Δ=-1.97, p=0.14
#   Step 943 | structure move | Δ=-0.52, p=0.59
#   Step 944 | structure move | Δ=-2.77, p=0.06
#   Step 945 | structure move | Δ=0.52, p=1.69
#   Step 946 | changepoint birth on blood_pressure_t-1 | Δ=-2.40, p=0.09
#   Step 947  Step 948  Step 949 | changepoint birth on blood_pressure_t-1 | Δ=-4.19, p=0.02
#   Step 950 | structure move | Δ=-0.22, p=0.80
#   Step 951 | structure move | Δ=-2.60, p=0.07
#   Step 952 | structure move | Δ=-2.77, p=0.06
#   Step 953 | changepoint birth on blood_pressure_t-1 | Δ=-3.90, p=0.02
#   Step 954 | changepoint birth on blood_pressure_t-1 | Δ=-4.31, p=0.01
#   Step 955 | changepoint death on heart_rate | Δ=3.09, p=21.99
#   Step 956  Step 957 | structure move | Δ=1.39, p=4.00
#   Step 958 | changepoint birth on oxygen_level_t-1 | Δ=-4.31, p=0.01
#   Step 959  Step 960  Step 961 | changepoint birth on heart_rate_t-1 | Δ=-2.40, p=0.09
#   Step 962 | changepoint birth on heart_rate | Δ=-3.38, p=0.03
#   Step 963 | structure move | Δ=-0.52, p=0.59
#   Step 964  Step 965 | changepoint birth on heart_rate | Δ=-5.00, p=0.01
#   Step 966 | structure move | Δ=-0.88, p=0.42
#   Step 967 | changepoint shift on blood_pressure | Δ=0.00, p=1.00
#   Step 968  Step 969 | changepoint death on blood_pressure | Δ=3.09, p=21.99
#   Step 970 | structure move | Δ=0.00, p=1.00
#   Step 971 | structure move | Δ=-2.20, p=0.11
#   Step 972 | structure move | Δ=0.22, p=1.25
#   Step 973 | structure move | Δ=0.12, p=1.13
#   Step 974  Step 975 | changepoint birth on mobility_t-1 | Δ=-4.31, p=0.01
#   Step 976 | structure move | Δ=-2.20, p=0.11
#   Step 977  Step 978 | structure move | Δ=-1.37, p=0.26
#   Step 979 | structure move | Δ=-2.48, p=0.08
#   Step 980 | structure move | Δ=-1.35, p=0.26
#   Step 981  Step 982 | structure move | Δ=-2.60, p=0.07
#   Step 983 | structure move | Δ=-2.60, p=0.07
#   Step 984 | structure move | Δ=0.14, p=1.15
#   Step 985  Step 986  Step 987 | changepoint shift on mobility_t-1 | Δ=0.00, p=1.00
#   Step 988 | structure move | Δ=-2.20, p=0.11
#   Step 989 | changepoint birth on blood_pressure | Δ=-1.06, p=0.35
#   Step 990  Step 991 | structure move | Δ=1.67, p=5.33
#   Step 992 | structure move | Δ=-0.18, p=0.83
#   Step 993  Step 994 | structure move | Δ=-0.92, p=0.40
#   Step 995 | changepoint death on mobility_t-1 | Δ=4.31, p=74.21
#   Step 996 | structure move | Δ=-1.50, p=0.22
#   Step 997 | structure move | Δ=1.22, p=3.37
#   Step 998 | changepoint birth on blood_pressure_t-1 | Δ=-1.70, p=0.18
#   Step 999 | structure move | Δ=-0.69, p=0.50
# Subject 10 done | best score = -112.58
# Final Graph Structure:
# blood_pressure_t-1 <- ['mobility_t-1', 'heart_rate_t-1', 'pain_level_t-1', 'oxygen_level_t-1']
# pain_level <- ['pain_level_t-1', 'blood_pressure_t-1', 'heart_rate_t-1', 'oxygen_level_t-1']
# mobility <- ['pain_level_t-1', 'heart_rate_t-1', 'oxygen_level_t-1', 'blood_pressure_t-1']
# heart_rate <- ['blood_pressure_t-1', 'pain_level_t-1', 'oxygen_level_t-1', 'mobility_t-1', 'heart_rate_t-1']
# mobility_t-1 <- ['blood_pressure_t-1', 'oxygen_level_t-1', 'heart_rate_t-1', 'pain_level_t-1']
# heart_rate_t-1 <- ['blood_pressure_t-1', 'pain_level_t-1', 'mobility_t-1', 'oxygen_level_t-1']
# oxygen_level_t-1 <- ['blood_pressure_t-1', 'heart_rate_t-1', 'mobility_t-1', 'pain_level_t-1']
# blood_pressure <- ['pain_level_t-1', 'blood_pressure_t-1', 'oxygen_level_t-1', 'heart_rate_t-1', 'mobility_t-1']
# oxygen_level <- ['pain_level_t-1', 'blood_pressure_t-1', 'oxygen_level_t-1', 'heart_rate_t-1', 'mobility_t-1']
# pain_level_t-1 <- ['blood_pressure_t-1', 'oxygen_level_t-1', 'heart_rate_t-1', 'mobility_t-1']

# %%
def print_changepoint_summary(segments, data):
    print("Changepoint Summary:\n")
    for var, seg_vec in segments.items():
        # Detect changepoints (where segment ID changes)
        breaks = [i for i in range(1, len(seg_vec)) if seg_vec[i] != seg_vec[i - 1]]
        times = data.loc[breaks, 'timestamp'].tolist() if 'timestamp' in data.columns else None
        num_segments = len(np.unique(seg_vec))

        print(f"{var}:")
        print(f"  • Segments: {num_segments}")
        print(f"  • Changepoints: {len(breaks)}")

        if breaks:
            print(f"  • Indices: {breaks}")
            if times:
                print(f"  • Timestamps: {times}")
        print()
print_changepoint_summary(segment_map, df_encoded)
# Out:
# 🔍 Changepoint Summary:
#
# blood_pressure:
#   • Segments: 2
#   • Changepoints: 2
#   • Indices: [7, 12]
#   • Timestamps: [datetime.date(2023, 10, 19), datetime.date(2023, 10, 29)]
#
# pain_level:
#   • Segments: 1
#   • Changepoints: 0
#
# mobility:
#   • Segments: 1
#   • Changepoints: 0
#
# heart_rate:
#   • Segments: 1
#   • Changepoints: 0
#
# oxygen_level:
#   • Segments: 1
#   • Changepoints: 0
#
# blood_pressure_t-1:
#   • Segments: 2
#   • Changepoints: 2
#   • Indices: [13, 19]
#   • Timestamps: [datetime.date(2023, 10, 31), datetime.date(2023, 12, 9)]
#
# pain_level_t-1:
#   • Segments: 1
#   • Changepoints: 0
#
# mobility_t-1:
#   • Segments: 1
#   • Changepoints: 0
#
# heart_rate_t-1:
#   • Segments: 3
#   • Changepoints: 3
#   • Indices: [13, 15, 19]
#   • Timestamps: [datetime.date(2023, 10, 31), datetime.date(2023, 11, 4), datetime.date(2023, 12, 9)]
#
# oxygen_level_t-1:
#   • Segments: 1
#   • Changepoints: 0
