# %%
import pandas as pd
import numpy as np
import random
from datetime import timedelta, datetime

def generate_dataset(num_subjects=10, min_timesteps=10, max_timesteps=20, seed=37):
    random.seed(seed)
    np.random.seed(seed)
    all_rows = []                     
    true_changepoints = {} 
    # Define CPTs (Conditional Probability Tables)
    
    # Segment 1: Mapping from blood_pressure_t-1 to pain_level
    pain_cpt_seg1 = {
        0: [0.8, 0.1, 0.1],  # low BP → no pain
        1: [0.1, 0.8, 0.1],  # normal BP → mild pain
        2: [0.1, 0.1, 0.8],  # high BP → severe pain
    }

    # Segment 2: Noisier mapping from blood_pressure_t-1 to pain_level
    pain_cpt_seg2 = {
        0: [0.4, 0.3, 0.3],
        1: [0.3, 0.4, 0.3],
        2: [0.3, 0.3, 0.4],
    }

    # Segment 1: pain_level_t-1 predicts mobility
    mobility_cpt_seg1 = {
        0: [0.9, 0.1],  # no pain → walking
        1: [0.4, 0.6],  # mild pain → mostly walking
        2: [0.2, 0.8],  # severe pain → mostly bedridden
    }

    # Segment 2: Noisier mapping between pain_level_t-1 and mobility
    mobility_cpt_seg2 = {
        0: [0.6, 0.4],
        1: [0.5, 0.5],
        2: [0.8, 0.2],
    }

    # Generate data per subject
    for subject_id in range(1, num_subjects + 1):
        # Random number of time steps per subject
        num_timesteps = random.randint(min_timesteps, max_timesteps)

        # Define the changepoint (midpoint of time steps)
        changepoint = num_timesteps // 2
        true_changepoints[subject_id] = changepoint

        # Generate time series dates for the subject
        start_date = datetime(2023, random.randint(1, 12), random.randint(1, 28))
        timestamps = [start_date + timedelta(days=2 * i) for i in range(num_timesteps)]

        # Initialize first values randomly
        bp = [random.choice([0, 1, 2])]  # blood_pressure
        pain = [random.choice([0, 1, 2])]
        mobility = [random.choice([0, 1])]
        hr = [random.choice([0, 1, 2])]
        ox = [random.choice([0, 1])]

        # Generate remaining values using CPTs
        for t in range(1, num_timesteps):
            bp.append(random.choice([0, 1, 2]))

            # Use CPTs depending on segment (before/after changepoint)
            if t < changepoint:
                pain_probs = pain_cpt_seg1[bp[t - 1]]
                mobility_probs = mobility_cpt_seg1[pain[t - 1]]
            else:
                pain_probs = pain_cpt_seg2[bp[t - 1]]
                mobility_probs = mobility_cpt_seg2[pain[t - 1]]

            # Sample next values using the CPTs
            pain.append(np.random.choice([0, 1, 2], p=pain_probs))
            mobility.append(np.random.choice([0, 1], p=mobility_probs))
            hr.append(random.choice([0, 1, 2]))   
            ox.append(random.choice([0, 1]))      

        # Collect all rows for this subject
        for t in range(num_timesteps):
            all_rows.append({
                'subject_id': subject_id,
                'timestamp': timestamps[t].date(),
                'blood_pressure': bp[t],
                'pain_level': pain[t],
                'mobility': mobility[t],
                'heart_rate': hr[t],
                'oxygen_level': ox[t],
            })

    # Create a DataFrame and sort for proper ordering
    df = pd.DataFrame(all_rows)
    df = df.sort_values(by=['subject_id', 'timestamp']).reset_index(drop=True)

    return df, true_changepoints

# Generate the dataset and print the head
df_health, ground_truth_cp = generate_dataset()
subject_lengths = df_health.groupby("subject_id").size().to_dict()
df_health.head()
# Out:
#    subject_id   timestamp  blood_pressure  pain_level  mobility  heart_rate  \
# 0           1  2023-10-03               2           2         0           2
# 1           1  2023-10-05               1           2         1           2
# 2           1  2023-10-07               2           1         1           1
# 3           1  2023-10-09               1           2         1           2
# 4           1  2023-10-11               1           1         1           0
#
#    oxygen_level
# 0             1
# 1             0
# 2             1
# 3             1
# 4             0

# %%
# Group by subject_id and count rows
subject_lengths = df_health.groupby("subject_id").size()
print("Number of rows per subject:")
for sid, length in subject_lengths.items():
    print(f"Subject {sid}: {length} time steps")
# Out:
# Number of rows per subject:
# Subject 1: 20 time steps
# Subject 2: 14 time steps
# Subject 3: 19 time steps
# Subject 4: 12 time steps
# Subject 5: 17 time steps
# Subject 6: 15 time steps
# Subject 7: 20 time steps
# Subject 8: 11 time steps
# Subject 9: 14 time steps
# Subject 10: 13 time steps

# %%
# Preprocessing Step: Add Lagged Variables and Encode Categories
# Function to create lagged (t-1) variables per subject
from sklearn.preprocessing import LabelEncoder
def create_lagged_df(df, id_col='subject_id', time_col='timestamp'):
    """
    For each subject:
    - Sorts data by timestamp
    - Adds lagged (t-1) versions of all feature columns
    - Returns a combined dataframe with current and lagged variables
    """
    all_lagged_rows = []

    for subject_id, group in df.groupby(id_col):
        group = group.sort_values(by=time_col).reset_index(drop=True)

        # Create lagged version (shift down by 1)
        lagged = group.shift(1)

        # Rename lagged columns to include "_t-1", except id and timestamp
        lagged.columns = [f"{col}_t-1" if col not in [id_col, time_col] else col for col in lagged.columns]

        # Combine original and lagged data side-by-side
        combined = pd.concat([group, lagged], axis=1).dropna().reset_index(drop=True)

        # Drop duplicate columns like subject_id and timestamp if they exist twice
        combined = combined.loc[:, ~combined.columns.duplicated()]

        all_lagged_rows.append(combined)

    return pd.concat(all_lagged_rows).reset_index(drop=True)

# Function to encode categorical columns using LabelEncoder

def encode_categorical_columns(df, exclude_cols=['subject_id', 'timestamp']):
    
    df_encoded = df.copy()
    encoders = {}

    for col in df.columns:
        if col in exclude_cols:
            continue
        le = LabelEncoder()
        df_encoded[col] = le.fit_transform(df[col])
        encoders[col] = le

    return df_encoded, encoders

# Run Preprocessing

df_lagged = create_lagged_df(df_health)
df_encoded, encoders = encode_categorical_columns(df_lagged)
print("Original (lagged) columns:", df_lagged.columns.tolist())
print("Encoded data sample:")
print(df_encoded.head())
# Out:
# Original (lagged) columns: ['subject_id', 'timestamp', 'blood_pressure', 'pain_level', 'mobility', 'heart_rate', 'oxygen_level', 'blood_pressure_t-1', 'pain_level_t-1', 'mobility_t-1', 'heart_rate_t-1', 'oxygen_level_t-1']
# Encoded data sample:
#    subject_id   timestamp  blood_pressure  pain_level  mobility  heart_rate  \
# 0           1  2023-10-05               1           2         1           2
# 1           1  2023-10-07               2           1         1           1
# 2           1  2023-10-09               1           2         1           2
# 3           1  2023-10-11               1           1         1           0
# 4           1  2023-10-13               0           1         1           1
#
#    oxygen_level  blood_pressure_t-1  pain_level_t-1  mobility_t-1  \
# 0             0                   2               2             0
# 1             1                   1               2             1
# 2             1                   2               1             1
# 3             0                   1               2             1
# 4             0                   1               1             1
#
#    heart_rate_t-1  oxygen_level_t-1
# 0               2                 1
# 1               2                 0
# 2               1                 1
# 3               2                 1
# 4               0                 0

# %%
# Step 3: BDe Score
from collections import defaultdict
from scipy.special import gammaln
import numpy as np

# Computes the BDe score for a single node (child variable)
# given its parent variables using the Dirichlet prior.
def compute_bde_score(df, child, parents, alpha=1.0):
    """
    Uses the exact BDe formula (log-marginal likelihood over Dirichlet prior)
    """
    r = df[child].nunique()  # Number of unique states for the child
    q = 1  # Number of parent configurations (defaults to 1 if no parents)

    if parents:
        # Compute number of total parent configurations (cardinality product)
        q = np.prod([df[p].nunique() for p in parents])
        grouped = df.groupby(parents)
    else:
        grouped = [((), df)]

    score = 0.0
    alpha_per_value = alpha / r  # Assume uniform Dirichlet prior

    for _, group in grouped:
        counts = group[child].value_counts().to_dict()
        Nij = sum(counts.values())
        term = gammaln(alpha) - gammaln(alpha + Nij)
        for k in range(r):
            Nijk = counts.get(k, 0)
            term += gammaln(alpha_per_value + Nijk) - gammaln(alpha_per_value)
        score += term
    return score

# Computes the total BDe score for a graph structure
def compute_bde_score_for_graph(df, graph, alpha=1.0):
    total_score = 0.0
    for child, parents in graph.items():
        total_score += compute_bde_score(df, child, parents, alpha)
    return total_score

graph_true = {
    'pain_level': ['blood_pressure_t-1'],    # true edge
    'mobility': ['pain_level_t-1'],          # true edge
    'blood_pressure': [],
    'heart_rate': [],
    'oxygen_level': [],
    'blood_pressure_t-1': [],
    'pain_level_t-1': [],
    'mobility_t-1': [],
    'heart_rate_t-1': [],
    'oxygen_level_t-1': []
}

score_true = compute_bde_score_for_graph(df_encoded, graph_true)
score_empty = compute_bde_score_for_graph(df_encoded, {
    node: [] for node in df_encoded.columns if node not in ['subject_id', 'timestamp']
})

print("BDe Score Comparison:")
print("Score with true graph:  ", score_true)
print("Score with empty graph: ", score_empty)
print("Difference (true - empty):", score_true - score_empty)
# Out:
# BDe Score Comparison:
# Score with true graph:   -1372.4736720260603
# Score with empty graph:  -1394.4686811783158
# Difference (true - empty): 21.995009152255534

# %%
# RJMCMC per subjec

import random
import copy
import numpy as np
import pandas as pd
from collections import defaultdict, Counter
from scipy.special import gammaln

# BDe Local Score
def compute_bde_score(df, child, parents, alpha=1.0):
    r = df[child].nunique()
    grouped = df.groupby(parents) if parents else [((), df)]

    score = 0.0
    alpha_per_value = alpha / r

    for _, group in grouped:
        counts = group[child].value_counts().to_dict()
        Nij = sum(counts.values())

        term = gammaln(alpha) - gammaln(alpha + Nij)
        for k in range(r):
            Nijk = counts.get(k, 0)
            term += gammaln(alpha_per_value + Nijk) - gammaln(alpha_per_value)
        score += term

    return score

#Graph Neighbors
def get_graph_neighbors(graph, nodes, max_parents=3):
    neighbors = []

    for child in nodes:
        current_parents = set(graph.get(child, []))

        for candidate in nodes:
            if candidate == child or candidate in current_parents:
                continue
            if len(current_parents) >= max_parents:
                continue
            if "_t-1" not in candidate:
                continue

            new_graph = copy.deepcopy(graph)
            new_graph[child] = list(current_parents | {candidate})
            neighbors.append(new_graph)

        for parent in current_parents:
            new_graph = copy.deepcopy(graph)
            new_graph[child] = list(current_parents - {parent})
            neighbors.append(new_graph)

    return neighbors

# Changepoint RJMCMC Support
def initialize_changepoints(df, variables):
    V = {}
    T = df.shape[0]
    for var in variables:
        V[var] = np.zeros(T, dtype=int)
    return V

def segment_data(df, Vn):
    segments = {}
    for seg_id in np.unique(Vn):
        idx = np.where(Vn == seg_id)[0]
        segments[seg_id] = df.iloc[idx]
    return segments

def score_segments_bde(df, Vn, child, parents, alpha=1.0):
    segments = segment_data(df, Vn)
    total_score = 0.0
    for seg_df in segments.values():
        if seg_df.shape[0] == 0:
            continue
        total_score += compute_bde_score(seg_df, child, parents, alpha)
    return total_score

def changepoint_log_prior(Vn, lam=1.0):
    num_cp = sum(Vn[i] != Vn[i - 1] for i in range(1, len(Vn)))
    return -lam * num_cp

def birth_move(Vn):
    T = len(Vn)
    valid_points = [t for t in range(1, T - 1) if Vn[t] == Vn[t - 1]]
    if not valid_points:
        return Vn, False

    new_cp = random.choice(valid_points)
    new_Vn = Vn.copy()
    curr_seg = Vn[new_cp]
    new_seg_id = max(Vn) + 1

    for t in range(new_cp, T):
        if Vn[t] == curr_seg:
            new_Vn[t] = new_seg_id
        else:
            break

    return new_Vn, True

def death_move(Vn):
    unique_segs, counts = np.unique(Vn, return_counts=True)
    if len(unique_segs) <= 1:
        return Vn, False

    merge_seg = random.choice(unique_segs[1:])
    prev_seg = merge_seg - 1

    new_Vn = Vn.copy()
    new_Vn[Vn == merge_seg] = prev_seg
    _, new_vals = np.unique(new_Vn, return_inverse=True)
    return new_vals, True

def reallocation_move(Vn):
    T = len(Vn)
    change_points = [t for t in range(1, T) if Vn[t] != Vn[t - 1]]
    if len(change_points) == 0:
        return Vn, False

    cp = random.choice(change_points)
    shift = random.choice([-1, 1])
    new_cp = cp + shift

    if new_cp <= 0 or new_cp >= T:
        return Vn, False

    new_Vn = Vn.copy()
    curr_seg = Vn[cp]
    prev_seg = Vn[cp - 1]

    if shift == -1:
        new_Vn[new_cp:cp] = curr_seg
        new_Vn[new_cp] = prev_seg
    else:
        new_Vn[cp:new_cp] = prev_seg
        new_Vn[cp] = curr_seg

    return new_Vn, True

# Run RJMCMC Per Subject with BMA
def run_rjmcmc_per_subject(df, nodes, **kwargs):
    full_best_V = {node: np.zeros(len(df), dtype=int) for node in nodes}
    edge_counts = Counter()
    total_graph_samples = 0

    for sid, group in df.groupby("subject_id"):
        print(f"RJMCMC for subject {sid}...")
        local_df = group.reset_index(drop=True)
        local_nodes = [col for col in local_df.columns if col not in ['subject_id', 'timestamp']]

        G = {node: [] for node in local_nodes}
        V = initialize_changepoints(local_df, local_nodes)

        def total_score(G, V):
            score = 0.0
            for n in local_nodes:
                score += score_segments_bde(local_df, V[n], n, G[n], kwargs['alpha'])
                score += changepoint_log_prior(V[n], lam=kwargs['lambda_cp'])
            return score

        current_score = total_score(G, V)
        best_V_local = copy.deepcopy(V)
        best_score = current_score

        for step in range(kwargs['num_iters']):
            print(f"  Step {step}...", end="")

            if random.random() < kwargs['p_structure']:
                neighbors = get_graph_neighbors(G, local_nodes, max_parents=kwargs['max_parents'])
                proposal_G = random.choice(neighbors)

                # Detect what changed
                changed_edge = None
                for child in local_nodes:
                    old_parents = set(G[child])
                    new_parents = set(proposal_G[child])
                    if old_parents != new_parents:
                        added = new_parents - old_parents
                        removed = old_parents - new_parents
                        if added:
                            changed_edge = f"Add edge: {list(added)[0]} → {child}"
                        elif removed:
                            changed_edge = f"Remove edge: {list(removed)[0]} → {child}"
                        break

                proposal_score = sum(
                    score_segments_bde(local_df, V[n], n, proposal_G[n], kwargs['alpha']) +
                    changepoint_log_prior(V[n], lam=kwargs['lambda_cp'])
                    for n in local_nodes
                )
                accept_prob = min(1.0, np.exp(proposal_score - current_score))

                print(f" Structure move | {changed_edge or 'Unknown change'} | Score Δ = {proposal_score - current_score:.2f} | Accept Prob = {accept_prob:.3f}")

                if random.random() < accept_prob:
                    G = proposal_G
                    current_score = proposal_score
                    if proposal_score > best_score:
                        print("New BEST graph structure found!")
                        best_score = proposal_score
                        best_V_local = copy.deepcopy(V)

            else:
                node = random.choice(local_nodes)
                move = random.choice(['birth', 'death', 'realloc'])

                if move == 'birth':
                    V_new, ok = birth_move(V[node])
                elif move == 'death':
                    V_new, ok = death_move(V[node])
                else:
                    V_new, ok = reallocation_move(V[node])

                if ok:
                    seg_score_new = score_segments_bde(local_df, V_new, node, G[node], kwargs['alpha'])
                    prior_new = changepoint_log_prior(V_new, lam=kwargs['lambda_cp'])
                    seg_score_old = score_segments_bde(local_df, V[node], node, G[node], kwargs['alpha'])
                    prior_old = changepoint_log_prior(V[node], lam=kwargs['lambda_cp'])

                    proposal_score = seg_score_new + prior_new
                    current_local_score = seg_score_old + prior_old
                    accept_prob = min(1.0, np.exp(proposal_score - current_local_score))

                    print(f"Changepoint move ({move}) on {node} | Δ = {proposal_score - current_local_score:.2f} | Accept Prob = {accept_prob:.3f}")

                    if random.random() < accept_prob:
                        V[node] = V_new
                        current_score = total_score(G, V)
                        if current_score > best_score:
                            print("New BEST changepoint config found!")
                            best_score = current_score
                            best_V_local = copy.deepcopy(V)

            if step % 50 == 0:
                for child, parents in G.items():
                    for parent in parents:
                        edge_counts[(child, parent)] += 1
                total_graph_samples += 1

        for node in local_nodes:
            full_best_V[node][group.index] = best_V_local[node]

        print(f" Done with subject {sid} | Best score: {best_score:.2f}")

    final_graph = defaultdict(list)
    for (child, parent), count in edge_counts.items():
        if count / total_graph_samples >= 0.3:
            final_graph[child].append(parent)

    return final_graph, full_best_V


#Example
columns = [col for col in df_encoded.columns if col not in ['subject_id', 'timestamp']]
best_graph, best_V = run_rjmcmc_per_subject(
    df_encoded,
    nodes=columns,
    num_iters=2000,
    alpha=1.0,
    lambda_cp=5.0,
    max_parents=3,
    p_structure=0.5
)

print("True connections: blood_pressure_t-1 → pain_level, pain_level_t-1 → mobility")
print("Best Graph Structure:")
for child, parents in best_graph.items():
    if parents:
        print(f"{child} <- {parents}")
# Out:
# Running RJMCMC for subject 1...
#   Step 0... Structure move | Add edge: pain_level_t-1 → heart_rate_t-1 | Score Δ = 5.21 | Accept Prob = 1.000
# New BEST graph structure found!
#   Step 1... Structure move | Add edge: mobility_t-1 → mobility | Score Δ = -0.85 | Accept Prob = 0.427
#   Step 2... Structure move | Add edge: mobility_t-1 → pain_level | Score Δ = -1.71 | Accept Prob = 0.182
#   Step 3... Structure move | Add edge: blood_pressure_t-1 → oxygen_level | Score Δ = -1.31 | Accept Prob = 0.270
#   Step 4...Changepoint move (birth) on blood_pressure_t-1 | Δ = -8.23 | Accept Prob = 0.000
#   Step 5...  Step 6...  Step 7... Structure move | Add edge: mobility_t-1 → heart_rate | Score Δ = 0.78 | Accept Prob = 1.000
#   Step 8...  Step 9...Changepoint move (birth) on mobility_t-1 | Δ = -3.93 | Accept Prob = 0.020
#   Step 10...Changepoint move (birth) on mobility | Δ = -4.96 | Accept Prob = 0.007
#   Step 11...  Step 12...  Step 13...  Step 14...Changepoint move (birth) on mobility | Δ = -4.69 | Accept Prob = 0.009
#   Step 15... Structure move | Add edge: pain_level_t-1 → heart_rate | Score Δ = 0.84 | Accept Prob = 1.000
#   Step 16... Structure move | Add edge: heart_rate_t-1 → mobility | Score Δ = 0.49 | Accept Prob = 1.000
#   Step 17...  Step 18... Structure move | Add edge: heart_rate_t-1 → oxygen_level_t-1 | Score Δ = -1.57 | Accept Prob = 0.207
#   Step 19...  Step 20...  Step 21... Structure move | Add edge: heart_rate_t-1 → heart_rate | Score Δ = 1.06 | Accept Prob = 1.000
# New BEST graph structure found!
#   Step 22...Changepoint move (birth) on pain_level | Δ = -4.79 | Accept Prob = 0.008
#   Step 23...  Step 24...Changepoint move (birth) on pain_level | Δ = -6.71 | Accept Prob = 0.001
#   Step 25... Structure move | Add edge: oxygen_level_t-1 → blood_pressure_t-1 | Score Δ = -1.78 | Accept Prob = 0.169
#   Step 26...Changepoint move (birth) on oxygen_level | Δ = -5.16 | Accept Prob = 0.006
#   Step 27... Structure move | Add edge: oxygen_level_t-1 → pain_level_t-1 | Score Δ = -1.77 | Accept Prob = 0.170
#   Step 28... Structure move | Add edge: heart_rate_t-1 → blood_pressure_t-1 | Score Δ = -2.11 | Accept Prob = 0.121
#   Step 29... Structure move | Add edge: heart_rate_t-1 → mobility_t-1 | Score Δ = -1.76 | Accept Prob = 0.172
#   Step 30... Structure move | Add edge: mobility_t-1 → pain_level_t-1 | Score Δ = -1.71 | Accept Prob = 0.182
#   Step 31...  Step 32...  Step 33... Structure move | Add edge: oxygen_level_t-1 → oxygen_level | Score Δ = 1.56 | Accept Prob = 1.000
#   Step 34... Structure move | Remove edge: mobility_t-1 → mobility | Score Δ = -0.55 | Accept Prob = 0.577
#   Step 35...Changepoint move (birth) on oxygen_level | Δ = -5.41 | Accept Prob = 0.004
#   Step 36...  Step 37...  Step 38...Changepoint move (birth) on oxygen_level_t-1 | Δ = -5.36 | Accept Prob = 0.005
#   Step 39...Changepoint move (birth) on oxygen_level | Δ = -4.56 | Accept Prob = 0.010
#   Step 40...Changepoint move (birth) on mobility | Δ = -2.84 | Accept Prob = 0.058
#   Step 41...  Step 42... Structure move | Add edge: heart_rate_t-1 → oxygen_level | Score Δ = 0.58 | Accept Prob = 1.000
# New BEST graph structure found!
#   Step 43...  Step 44...  Step 45... Structure move | Add edge: oxygen_level_t-1 → blood_pressure | Score Δ = 0.56 | Accept Prob = 1.000
# New BEST graph structure found!
#   Step 46... Structure move | Add edge: oxygen_level_t-1 → blood_pressure_t-1 | Score Δ = -1.78 | Accept Prob = 0.169
#   Step 47... Structure move | Add edge: pain_level_t-1 → mobility | Score Δ = 0.77 | Accept Prob = 1.000
# New BEST graph structure found!
#   Step 48...Changepoint move (birth) on blood_pressure_t-1 | Δ = -8.23 | Accept Prob = 0.000
#   Step 49... Structure move | Add edge: pain_level_t-1 → blood_pressure_t-1 | Score Δ = -1.94 | Accept Prob = 0.144
#   Step 50...  Step 51...Changepoint move (birth) on mobility | Δ = -2.35 | Accept Prob = 0.096
#   Step 52... Structure move | Add edge: pain_level_t-1 → blood_pressure_t-1 | Score Δ = -1.94 | Accept Prob = 0.144
#   Step 53...Changepoint move (birth) on mobility | Δ = -2.35 | Accept Prob = 0.096
#   Step 54... Structure move | Remove edge: mobility_t-1 → pain_level_t-1 | Score Δ = 1.71 | Accept Prob = 1.000
# New BEST graph structure found!
#   Step 55... Structure move | Add edge: mobility_t-1 → pain_level_t-1 | Score Δ = -1.71 | Accept Prob = 0.182
#   Step 56...  Step 57...  Step 58...  Step 59... Structure move | Add edge: heart_rate_t-1 → pain_level_t-1 | Score Δ = 5.19 | Accept Prob = 1.000
# New BEST graph structure found!
#   Step 60...  Step 61...  Step 62... Structure move | Add edge: heart_rate_t-1 → pain_level | Score Δ = -0.08 | Accept Prob = 0.923
#   Step 63... Structure move | Add edge: oxygen_level_t-1 → pain_level | Score Δ = 0.26 | Accept Prob = 1.000
# New BEST graph structure found!
#   Step 64... Structure move | Add edge: heart_rate_t-1 → pain_level | Score Δ = -0.42 | Accept Prob = 0.656
#   Step 65... Structure move | Add edge: oxygen_level_t-1 → pain_level_t-1 | Score Δ = -1.57 | Accept Prob = 0.207
#   Step 66...  Step 67...Changepoint move (birth) on heart_rate_t-1 | Δ = -2.31 | Accept Prob = 0.099
#   Step 68...  Step 69...  Step 70...  Step 71... Structure move | Remove edge: pain_level_t-1 → mobility | Score Δ = -0.77 | Accept Prob = 0.463
#   Step 72...  Step 73... Structure move | Remove edge: mobility_t-1 → heart_rate | Score Δ = -2.67 | Accept Prob = 0.069
#   Step 74... Structure move | Remove edge: oxygen_level_t-1 → oxygen_level | Score Δ = -1.13 | Accept Prob = 0.324
#   Step 75... Structure move | Remove edge: pain_level_t-1 → mobility | Score Δ = -0.77 | Accept Prob = 0.463
#   Step 76... Structure move | Add edge: heart_rate_t-1 → pain_level | Score Δ = -0.42 | Accept Prob = 0.656
#   Step 77... Structure move | Remove edge: oxygen_level_t-1 → blood_pressure | Score Δ = -0.56 | Accept Prob = 0.573
#   Step 78... Structure move | Add edge: oxygen_level_t-1 → blood_pressure_t-1 | Score Δ = -1.78 | Accept Prob = 0.169
#   Step 79... Structure move | Add edge: blood_pressure_t-1 → mobility_t-1 | Score Δ = -0.34 | Accept Prob = 0.711
#   Step 80... Structure move | Add edge: blood_pressure_t-1 → oxygen_level_t-1 | Score Δ = -1.31 | Accept Prob = 0.270
#   Step 81...  Step 82...  Step 83... Structure move | Add edge: blood_pressure_t-1 → pain_level | Score Δ = 2.13 | Accept Prob = 1.000
#   Step 84... Structure move | Add edge: heart_rate_t-1 → oxygen_level_t-1 | Score Δ = -0.60 | Accept Prob = 0.547
#   Step 85...Changepoint move (birth) on blood_pressure_t-1 | Δ = -13.18 | Accept Prob = 0.000
#   Step 86... Structure move | Add edge: oxygen_level_t-1 → mobility_t-1 | Score Δ = 0.46 | Accept Prob = 1.000
#   Step 87...Changepoint move (birth) on heart_rate | Δ = -4.93 | Accept Prob = 0.007
#   Step 88...  Step 89... Structure move | Remove edge: oxygen_level_t-1 → mobility_t-1 | Score Δ = -0.46 | Accept Prob = 0.632
#   Step 90... Structure move | Add edge: oxygen_level_t-1 → blood_pressure_t-1 | Score Δ = -1.78 | Accept Prob = 0.169
#   Step 91...  Step 92... Structure move | Add edge: blood_pressure_t-1 → heart_rate_t-1 | Score Δ = -1.98 | Accept Prob = 0.138
#   Step 93...Changepoint move (birth) on mobility | Δ = -4.82 | Accept Prob = 0.008
#   Step 94... Structure move | Remove edge: oxygen_level_t-1 → pain_level | Score Δ = 1.56 | Accept Prob = 1.000
#   Step 95... Structure move | Remove edge: pain_level_t-1 → heart_rate | Score Δ = -1.22 | Accept Prob = 0.296
#   Step 96... Structure move | Remove edge: oxygen_level_t-1 → blood_pressure | Score Δ = -0.56 | Accept Prob = 0.573
#   Step 97... Structure move | Remove edge: mobility_t-1 → heart_rate | Score Δ = -4.79 | Accept Prob = 0.008
#   Step 98...  Step 99...Changepoint move (birth) on heart_rate | Δ = -3.13 | Accept Prob = 0.044
#   Step 100...Changepoint move (birth) on blood_pressure_t-1 | Δ = -4.62 | Accept Prob = 0.010
#   Step 101...  Step 102...Changepoint move (birth) on oxygen_level | Δ = -5.66 | Accept Prob = 0.003
#   Step 103... Structure move | Remove edge: heart_rate_t-1 → pain_level_t-1 | Score Δ = -5.38 | Accept Prob = 0.005
#   Step 104...Changepoint move (birth) on blood_pressure_t-1 | Δ = -6.65 | Accept Prob = 0.001
#   Step 105... Structure move | Add edge: pain_level_t-1 → oxygen_level | Score Δ = 0.88 | Accept Prob = 1.000
#   Step 106... Structure move | Remove edge: heart_rate_t-1 → oxygen_level_t-1 | Score Δ = 0.60 | Accept Prob = 1.000
#   Step 107... Structure move | Add edge: mobility_t-1 → blood_pressure | Score Δ = -1.86 | Accept Prob = 0.156
#   Step 108...  Step 109... Structure move | Add edge: oxygen_level_t-1 → pain_level | Score Δ = -1.56 | Accept Prob = 0.211
#   Step 110... Structure move | Remove edge: heart_rate_t-1 → pain_level | Score Δ = 1.03 | Accept Prob = 1.000
#   Step 111... Structure move | Remove edge: blood_pressure_t-1 → pain_level | Score Δ = -4.55 | Accept Prob = 0.011
#   Step 112...  Step 113...Changepoint move (birth) on heart_rate | Δ = -4.19 | Accept Prob = 0.015
#   Step 114...  Step 115... Structure move | Remove edge: blood_pressure_t-1 → oxygen_level | Score Δ = -0.91 | Accept Prob = 0.402
#   Step 116... Structure move | Add edge: blood_pressure_t-1 → heart_rate | Score Δ = 1.57 | Accept Prob = 1.000
#   Step 117... Structure move | Add edge: oxygen_level_t-1 → mobility_t-1 | Score Δ = 0.46 | Accept Prob = 1.000
#   Step 118...Changepoint move (birth) on heart_rate_t-1 | Δ = -2.52 | Accept Prob = 0.081
#   Step 119...  Step 120... Structure move | Add edge: oxygen_level_t-1 → blood_pressure_t-1 | Score Δ = -1.78 | Accept Prob = 0.169
#   Step 121...  Step 122...Changepoint move (birth) on heart_rate | Δ = -2.68 | Accept Prob = 0.068
#   Step 123...Changepoint move (birth) on heart_rate_t-1 | Δ = -2.40 | Accept Prob = 0.091
#   Step 124... Structure move | Add edge: blood_pressure_t-1 → blood_pressure | Score Δ = -0.72 | Accept Prob = 0.488
#   Step 125...  Step 126...  Step 127... Structure move | Remove edge: mobility_t-1 → heart_rate | Score Δ = -3.02 | Accept Prob = 0.049
#   Step 128...  Step 129... Structure move | Remove edge: blood_pressure_t-1 → oxygen_level_t-1 | Score Δ = 1.31 | Accept Prob = 1.000
#   Step 130... Structure move | Remove edge: blood_pressure_t-1 → mobility_t-1 | Score Δ = -0.36 | Accept Prob = 0.695
#   Step 131...  Step 132... Structure move | Remove edge: pain_level_t-1 → heart_rate_t-1 | Score Δ = -4.68 | Accept Prob = 0.009
#   Step 133...  Step 134... Structure move | Add edge: mobility_t-1 → oxygen_level_t-1 | Score Δ = -0.21 | Accept Prob = 0.809
#   Step 135...Changepoint move (birth) on blood_pressure | Δ = 1.91 | Accept Prob = 1.000
#   Step 136...  Step 137...  Step 138...  Step 139... Structure move | Add edge: heart_rate_t-1 → oxygen_level_t-1 | Score Δ = -0.79 | Accept Prob = 0.456
#   Step 140...Changepoint move (death) on heart_rate_t-1 | Δ = 4.88 | Accept Prob = 1.000
#   Step 141... Structure move | Add edge: heart_rate_t-1 → mobility_t-1 | Score Δ = -0.99 | Accept Prob = 0.373
#   Step 142...  Step 143...  Step 144... Structure move | Add edge: blood_pressure_t-1 → pain_level_t-1 | Score Δ = -1.65 | Accept Prob = 0.193
#   Step 145...  Step 146... Structure move | Add edge: pain_level_t-1 → blood_pressure | Score Δ = -1.56 | Accept Prob = 0.211
#   Step 147...Changepoint move (birth) on heart_rate_t-1 | Δ = -6.87 | Accept Prob = 0.001
#   Step 148...  Step 149... Structure move | Add edge: pain_level_t-1 → blood_pressure | Score Δ = -1.56 | Accept Prob = 0.211
#   Step 150...  Step 151... Structure move | Add edge: mobility_t-1 → pain_level | Score Δ = -1.71 | Accept Prob = 0.182
#   Step 152... Structure move | Remove edge: heart_rate_t-1 → heart_rate | Score Δ = -1.86 | Accept Prob = 0.156
#   Step 153...Changepoint move (realloc) on heart_rate_t-1 | Δ = 0.00 | Accept Prob = 1.000
#   Step 154... Structure move | Add edge: heart_rate_t-1 → pain_level | Score Δ = 0.57 | Accept Prob = 1.000
#   Step 155...Changepoint move (birth) on mobility_t-1 | Δ = -4.31 | Accept Prob = 0.013
#   Step 156...  Step 157... Structure move | Add edge: pain_level_t-1 → blood_pressure | Score Δ = -1.56 | Accept Prob = 0.211
#   Step 158... Structure move | Add edge: mobility_t-1 → blood_pressure | Score Δ = -1.96 | Accept Prob = 0.141
#   Step 159... Structure move | Remove edge: blood_pressure_t-1 → heart_rate | Score Δ = -1.57 | Accept Prob = 0.207
#   Step 160...  Step 161... Structure move | Add edge: pain_level_t-1 → oxygen_level_t-1 | Score Δ = -1.70 | Accept Prob = 0.182
#   Step 162... Structure move | Remove edge: blood_pressure_t-1 → oxygen_level | Score Δ = -0.91 | Accept Prob = 0.402
#   Step 163... Structure move | Remove edge: oxygen_level_t-1 → pain_level_t-1 | Score Δ = 1.57 | Accept Prob = 1.000
#   Step 164... Structure move | Remove edge: pain_level_t-1 → mobility | Score Δ = -0.77 | Accept Prob = 0.463
#   Step 165... Structure move | Add edge: blood_pressure_t-1 → mobility | Score Δ = 2.85 | Accept Prob = 1.000
#   Step 166...Changepoint move (birth) on oxygen_level_t-1 | Δ = -5.34 | Accept Prob = 0.005
#   Step 167...  Step 168...Changepoint move (death) on blood_pressure | Δ = -1.91 | Accept Prob = 0.148
#   Step 169... Structure move | Add edge: blood_pressure_t-1 → oxygen_level_t-1 | Score Δ = 1.23 | Accept Prob = 1.000
#   Step 170... Structure move | Remove edge: mobility_t-1 → pain_level | Score Δ = 1.05 | Accept Prob = 1.000
#   Step 171... Structure move | Remove edge: mobility_t-1 → oxygen_level_t-1 | Score Δ = 0.34 | Accept Prob = 1.000
#   Step 172... Structure move | Add edge: blood_pressure_t-1 → pain_level | Score Δ = 3.60 | Accept Prob = 1.000
# New BEST graph structure found!
#   Step 173...  Step 174... Structure move | Remove edge: pain_level_t-1 → heart_rate_t-1 | Score Δ = -6.20 | Accept Prob = 0.002
#   Step 175...Changepoint move (birth) on mobility_t-1 | Δ = -5.97 | Accept Prob = 0.003
#   Step 176...  Step 177... Structure move | Add edge: heart_rate_t-1 → blood_pressure | Score Δ = 0.52 | Accept Prob = 1.000
# New BEST graph structure found!
#   Step 178...Changepoint move (birth) on pain_level_t-1 | Δ = -4.80 | Accept Prob = 0.008
#   Step 179... Structure move | Add edge: oxygen_level_t-1 → blood_pressure | Score Δ = -2.03 | Accept Prob = 0.132
#   Step 180...  Step 181...Changepoint move (birth) on oxygen_level | Δ = -3.43 | Accept Prob = 0.032
#   Step 182... Structure move | Add edge: mobility_t-1 → heart_rate_t-1 | Score Δ = -1.87 | Accept Prob = 0.154
#   Step 183... Structure move | Add edge: mobility_t-1 → oxygen_level | Score Δ = 0.29 | Accept Prob = 1.000
# New BEST graph structure found!
#   Step 184... Structure move | Add edge: pain_level_t-1 → blood_pressure | Score Δ = -2.50 | Accept Prob = 0.082
#   Step 185...Changepoint move (birth) on heart_rate | Δ = -3.90 | Accept Prob = 0.020
#   Step 186... Structure move | Add edge: mobility_t-1 → heart_rate_t-1 | Score Δ = -1.87 | Accept Prob = 0.154
#   Step 187... Structure move | Add edge: mobility_t-1 → pain_level_t-1 | Score Δ = 0.49 | Accept Prob = 1.000
# New BEST graph structure found!
#   Step 188... Structure move | Add edge: mobility_t-1 → oxygen_level_t-1 | Score Δ = -0.34 | Accept Prob = 0.711
#   Step 189...Changepoint move (birth) on blood_pressure_t-1 | Δ = -5.00 | Accept Prob = 0.007
#   Step 190...Changepoint move (birth) on mobility | Δ = -5.51 | Accept Prob = 0.004
#   Step 191...Changepoint move (birth) on oxygen_level | Δ = -6.32 | Accept Prob = 0.002
#   Step 192...Changepoint move (birth) on heart_rate_t-1 | Δ = -3.78 | Accept Prob = 0.023
#   Step 193...Changepoint move (birth) on mobility_t-1 | Δ = -5.27 | Accept Prob = 0.005
#   Step 194... Structure move | Remove edge: heart_rate_t-1 → blood_pressure | Score Δ = -0.52 | Accept Prob = 0.592
#   Step 195...  Step 196...  Step 197...  Step 198... Structure move | Remove edge: mobility_t-1 → mobility | Score Δ = -1.23 | Accept Prob = 0.292
#   Step 199... Structure move | Remove edge: blood_pressure_t-1 → pain_level | Score Δ = -3.60 | Accept Prob = 0.027
#   Step 200... Structure move | Remove edge: oxygen_level_t-1 → mobility_t-1 | Score Δ = -0.53 | Accept Prob = 0.589
#   Step 201... Structure move | Remove edge: pain_level_t-1 → oxygen_level_t-1 | Score Δ = 0.34 | Accept Prob = 1.000
#   Step 202...Changepoint move (realloc) on heart_rate_t-1 | Δ = 0.00 | Accept Prob = 1.000
#   Step 203...  Step 204... Structure move | Remove edge: blood_pressure_t-1 → heart_rate | Score Δ = -1.57 | Accept Prob = 0.207
#   Step 205... Structure move | Add edge: heart_rate_t-1 → blood_pressure_t-1 | Score Δ = -2.11 | Accept Prob = 0.121
#   Step 206...Changepoint move (death) on blood_pressure | Δ = -1.91 | Accept Prob = 0.148
#   Step 207...Changepoint move (death) on blood_pressure | Δ = -1.91 | Accept Prob = 0.148
#   Step 208... Structure move | Add edge: heart_rate_t-1 → blood_pressure_t-1 | Score Δ = -2.11 | Accept Prob = 0.121
#   Step 209... Structure move | Remove edge: mobility_t-1 → oxygen_level_t-1 | Score Δ = -0.97 | Accept Prob = 0.379
#   Step 210...  Step 211... Structure move | Remove edge: pain_level_t-1 → oxygen_level | Score Δ = -1.28 | Accept Prob = 0.278
#   Step 212... Structure move | Remove edge: heart_rate_t-1 → oxygen_level | Score Δ = -2.20 | Accept Prob = 0.111
#   Step 213...  Step 214...  Step 215... Structure move | Remove edge: heart_rate_t-1 → mobility_t-1 | Score Δ = 0.99 | Accept Prob = 1.000
#   Step 216...Changepoint move (birth) on blood_pressure_t-1 | Δ = -8.23 | Accept Prob = 0.000
#   Step 217... Structure move | Remove edge: pain_level_t-1 → oxygen_level | Score Δ = -1.28 | Accept Prob = 0.278
#   Step 218...  Step 219...  Step 220... Structure move | Add edge: blood_pressure_t-1 → pain_level_t-1 | Score Δ = -1.35 | Accept Prob = 0.260
#   Step 221...  Step 222... Structure move | Add edge: mobility_t-1 → pain_level | Score Δ = 0.25 | Accept Prob = 1.000
#   Step 223... Structure move | Add edge: heart_rate_t-1 → blood_pressure | Score Δ = 1.94 | Accept Prob = 1.000
#   Step 224...Changepoint move (birth) on mobility_t-1 | Δ = -5.26 | Accept Prob = 0.005
#   Step 225... Structure move | Remove edge: heart_rate_t-1 → blood_pressure | Score Δ = -1.94 | Accept Prob = 0.144
#   Step 226...  Step 227... Structure move | Add edge: blood_pressure_t-1 → pain_level_t-1 | Score Δ = -1.35 | Accept Prob = 0.260
#   Step 228... Structure move | Add edge: oxygen_level_t-1 → blood_pressure_t-1 | Score Δ = -1.78 | Accept Prob = 0.169
#   Step 229... Structure move | Remove edge: pain_level_t-1 → oxygen_level | Score Δ = -1.28 | Accept Prob = 0.278
#   Step 230... Structure move | Remove edge: blood_pressure_t-1 → blood_pressure | Score Δ = -3.34 | Accept Prob = 0.036
#   Step 231...  Step 232...  Step 233...  Step 234...  Step 235...  Step 236...Changepoint move (birth) on pain_level_t-1 | Δ = -4.05 | Accept Prob = 0.017
#   Step 237...  Step 238... Structure move | Remove edge: pain_level_t-1 → heart_rate_t-1 | Score Δ = -6.20 | Accept Prob = 0.002
#   Step 239...Changepoint move (birth) on pain_level_t-1 | Δ = -4.50 | Accept Prob = 0.011
#   Step 240... Structure move | Add edge: oxygen_level_t-1 → pain_level_t-1 | Score Δ = -1.82 | Accept Prob = 0.162
#   Step 241...Changepoint move (birth) on heart_rate_t-1 | Δ = -3.90 | Accept Prob = 0.020
#   Step 242... Structure move | Remove edge: mobility_t-1 → pain_level | Score Δ = -0.25 | Accept Prob = 0.778
#   Step 243...Changepoint move (birth) on mobility | Δ = -5.51 | Accept Prob = 0.004
#   Step 244...Changepoint move (birth) on heart_rate_t-1 | Δ = -4.19 | Accept Prob = 0.015
#   Step 245...  Step 246... Structure move | Remove edge: blood_pressure_t-1 → heart_rate_t-1 | Score Δ = -2.01 | Accept Prob = 0.134
#   Step 247...  Step 248...Changepoint move (death) on heart_rate_t-1 | Δ = 0.03 | Accept Prob = 1.000
#   Step 249...  Step 250...  Step 251... Structure move | Remove edge: mobility_t-1 → oxygen_level | Score Δ = -0.29 | Accept Prob = 0.750
#   Step 252... Structure move | Add edge: heart_rate_t-1 → blood_pressure_t-1 | Score Δ = -2.11 | Accept Prob = 0.121
#   Step 253...  Step 254... Structure move | Add edge: mobility_t-1 → blood_pressure_t-1 | Score Δ = -0.44 | Accept Prob = 0.646
#   Step 255... Structure move | Add edge: oxygen_level_t-1 → blood_pressure_t-1 | Score Δ = -0.66 | Accept Prob = 0.518
#   Step 256... Structure move | Add edge: pain_level_t-1 → oxygen_level_t-1 | Score Δ = -0.34 | Accept Prob = 0.711
#   Step 257... Structure move | Add edge: blood_pressure_t-1 → pain_level_t-1 | Score Δ = -1.35 | Accept Prob = 0.260
#   Step 258... Structure move | Remove edge: heart_rate_t-1 → blood_pressure | Score Δ = -1.94 | Accept Prob = 0.144
#   Step 259... Structure move | Remove edge: pain_level_t-1 → oxygen_level_t-1 | Score Δ = 0.34 | Accept Prob = 1.000
#   Step 260... Structure move | Remove edge: mobility_t-1 → blood_pressure_t-1 | Score Δ = -0.68 | Accept Prob = 0.506
#   Step 261...  Step 262... Structure move | Remove edge: heart_rate_t-1 → heart_rate | Score Δ = -0.69 | Accept Prob = 0.503
#   Step 263... Structure move | Add edge: blood_pressure_t-1 → heart_rate | Score Δ = 1.57 | Accept Prob = 1.000
#   Step 264...  Step 265...  Step 266...  Step 267...  Step 268... Structure move | Add edge: blood_pressure_t-1 → oxygen_level | Score Δ = 0.91 | Accept Prob = 1.000
#   Step 269... Structure move | Add edge: pain_level_t-1 → blood_pressure | Score Δ = -1.22 | Accept Prob = 0.297
#   Step 270... Structure move | Remove edge: heart_rate_t-1 → pain_level | Score Δ = 0.70 | Accept Prob = 1.000
#   Step 271...Changepoint move (birth) on oxygen_level_t-1 | Δ = -6.73 | Accept Prob = 0.001
#   Step 272... Structure move | Remove edge: mobility_t-1 → mobility | Score Δ = -1.23 | Accept Prob = 0.292
#   Step 273... Structure move | Add edge: heart_rate_t-1 → mobility_t-1 | Score Δ = -0.99 | Accept Prob = 0.373
#   Step 274...  Step 275...  Step 276...  Step 277... Structure move | Remove edge: heart_rate_t-1 → pain_level_t-1 | Score Δ = -5.55 | Accept Prob = 0.004
#   Step 278... Structure move | Remove edge: blood_pressure_t-1 → pain_level_t-1 | Score Δ = 1.35 | Accept Prob = 1.000
#   Step 279...  Step 280... Structure move | Remove edge: blood_pressure_t-1 → heart_rate_t-1 | Score Δ = 1.98 | Accept Prob = 1.000
# New BEST graph structure found!
#   Step 281...Changepoint move (birth) on heart_rate_t-1 | Δ = -5.25 | Accept Prob = 0.005
#   Step 282... Structure move | Add edge: pain_level_t-1 → blood_pressure_t-1 | Score Δ = -0.15 | Accept Prob = 0.861
#   Step 283... Structure move | Remove edge: pain_level_t-1 → heart_rate_t-1 | Score Δ = -5.21 | Accept Prob = 0.005
#   Step 284... Structure move | Remove edge: heart_rate_t-1 → heart_rate | Score Δ = -1.86 | Accept Prob = 0.156
#   Step 285... Structure move | Add edge: blood_pressure_t-1 → pain_level_t-1 | Score Δ = -1.35 | Accept Prob = 0.260
#   Step 286...Changepoint move (birth) on pain_level | Δ = -4.91 | Accept Prob = 0.007
#   Step 287...Changepoint move (birth) on heart_rate | Δ = -2.68 | Accept Prob = 0.068
#   Step 288...Changepoint move (birth) on blood_pressure | Δ = 0.98 | Accept Prob = 1.000
#   Step 289... Structure move | Remove edge: mobility_t-1 → blood_pressure_t-1 | Score Δ = 0.09 | Accept Prob = 1.000
#   Step 290... Structure move | Remove edge: blood_pressure_t-1 → pain_level | Score Δ = -6.18 | Accept Prob = 0.002
#   Step 291... Structure move | Add edge: pain_level_t-1 → mobility_t-1 | Score Δ = -1.78 | Accept Prob = 0.168
#   Step 292...  Step 293...  Step 294... Structure move | Remove edge: mobility_t-1 → heart_rate | Score Δ = -3.02 | Accept Prob = 0.049
#   Step 295... Structure move | Remove edge: heart_rate_t-1 → mobility | Score Δ = -2.95 | Accept Prob = 0.052
#   Step 296...Changepoint move (birth) on oxygen_level | Δ = -5.74 | Accept Prob = 0.003
#   Step 297... Structure move | Remove edge: heart_rate_t-1 → mobility | Score Δ = -2.95 | Accept Prob = 0.052
#   Step 298...  Step 299...  Step 300... Structure move | Add edge: heart_rate_t-1 → mobility_t-1 | Score Δ = -0.99 | Accept Prob = 0.373
#   Step 301... Structure move | Add edge: mobility_t-1 → heart_rate_t-1 | Score Δ = 0.27 | Accept Prob = 1.000
#   Step 302... Structure move | Remove edge: heart_rate_t-1 → heart_rate | Score Δ = -1.86 | Accept Prob = 0.156
#   Step 303...  Step 304... Structure move | Remove edge: mobility_t-1 → pain_level | Score Δ = 0.07 | Accept Prob = 1.000
#   Step 305...Changepoint move (birth) on heart_rate_t-1 | Δ = -3.95 | Accept Prob = 0.019
#   Step 306...Changepoint move (realloc) on blood_pressure | Δ = 0.00 | Accept Prob = 1.000
#   Step 307... Structure move | Remove edge: mobility_t-1 → pain_level_t-1 | Score Δ = -1.02 | Accept Prob = 0.361
#   Step 308...Changepoint move (birth) on heart_rate | Δ = -5.98 | Accept Prob = 0.003
#   Step 309... Structure move | Remove edge: pain_level_t-1 → heart_rate_t-1 | Score Δ = -7.54 | Accept Prob = 0.001
#   Step 310... Structure move | Remove edge: blood_pressure_t-1 → heart_rate | Score Δ = -1.57 | Accept Prob = 0.207
#   Step 311... Structure move | Add edge: heart_rate_t-1 → pain_level | Score Δ = -1.03 | Accept Prob = 0.357
#   Step 312...Changepoint move (birth) on heart_rate | Δ = -3.13 | Accept Prob = 0.044
#   Step 313... Structure move | Add edge: pain_level_t-1 → mobility_t-1 | Score Δ = -1.78 | Accept Prob = 0.168
#   Step 314...  Step 315... Structure move | Remove edge: blood_pressure_t-1 → pain_level_t-1 | Score Δ = 1.87 | Accept Prob = 1.000
#   Step 316... Structure move | Add edge: blood_pressure_t-1 → heart_rate_t-1 | Score Δ = -2.04 | Accept Prob = 0.130
#   Step 317... Structure move | Add edge: oxygen_level_t-1 → pain_level_t-1 | Score Δ = -1.57 | Accept Prob = 0.207
#   Step 318...Changepoint move (birth) on pain_level | Δ = -4.51 | Accept Prob = 0.011
#   Step 319... Structure move | Add edge: blood_pressure_t-1 → mobility_t-1 | Score Δ = 1.11 | Accept Prob = 1.000
#   Step 320... Structure move | Add edge: pain_level_t-1 → pain_level | Score Δ = -3.53 | Accept Prob = 0.029
#   Step 321... Structure move | Add edge: pain_level_t-1 → heart_rate | Score Δ = 1.22 | Accept Prob = 1.000
#   Step 322... Structure move | Remove edge: blood_pressure_t-1 → oxygen_level_t-1 | Score Δ = 0.13 | Accept Prob = 1.000
#   Step 323... Structure move | Remove edge: blood_pressure_t-1 → pain_level | Score Δ = -4.55 | Accept Prob = 0.011
#   Step 324...  Step 325...Changepoint move (birth) on heart_rate | Δ = -3.78 | Accept Prob = 0.023
#   Step 326... Structure move | Add edge: pain_level_t-1 → oxygen_level_t-1 | Score Δ = -1.70 | Accept Prob = 0.182
#   Step 327...Changepoint move (birth) on oxygen_level | Δ = -5.56 | Accept Prob = 0.004
#   Step 328... Structure move | Remove edge: mobility_t-1 → heart_rate_t-1 | Score Δ = -0.27 | Accept Prob = 0.762
#   Step 329... Structure move | Remove edge: blood_pressure_t-1 → pain_level | Score Δ = -4.55 | Accept Prob = 0.011
#   Step 330... Structure move | Add edge: heart_rate_t-1 → blood_pressure_t-1 | Score Δ = -2.01 | Accept Prob = 0.134
#   Step 331...  Step 332... Structure move | Remove edge: oxygen_level_t-1 → blood_pressure_t-1 | Score Δ = -0.78 | Accept Prob = 0.459
#   Step 333... Structure move | Add edge: mobility_t-1 → pain_level | Score Δ = -0.07 | Accept Prob = 0.928
#   Step 334...  Step 335... Structure move | Add edge: pain_level_t-1 → pain_level | Score Δ = -1.24 | Accept Prob = 0.288
#   Step 336...  Step 337...Changepoint move (birth) on pain_level_t-1 | Δ = -4.49 | Accept Prob = 0.011
#   Step 338...  Step 339... Structure move | Remove edge: pain_level_t-1 → blood_pressure_t-1 | Score Δ = -0.62 | Accept Prob = 0.539
#   Step 340...  Step 341...  Step 342...  Step 343...  Step 344...  Step 345...  Step 346... Structure move | Remove edge: blood_pressure_t-1 → pain_level | Score Δ = -4.21 | Accept Prob = 0.015
#   Step 347...  Step 348...  Step 349... Structure move | Add edge: heart_rate_t-1 → oxygen_level_t-1 | Score Δ = 1.10 | Accept Prob = 1.000
#   Step 350... Structure move | Remove edge: mobility_t-1 → mobility | Score Δ = -1.23 | Accept Prob = 0.292
#   Step 351...  Step 352...  Step 353...  Step 354... Structure move | Remove edge: mobility_t-1 → heart_rate | Score Δ = -2.67 | Accept Prob = 0.069
#   Step 355...  Step 356... Structure move | Remove edge: pain_level_t-1 → oxygen_level_t-1 | Score Δ = -0.18 | Accept Prob = 0.833
#   Step 357... Structure move | Remove edge: pain_level_t-1 → pain_level | Score Δ = 1.24 | Accept Prob = 1.000
#   Step 358...Changepoint move (birth) on oxygen_level_t-1 | Δ = -5.56 | Accept Prob = 0.004
#   Step 359... Structure move | Remove edge: mobility_t-1 → heart_rate_t-1 | Score Δ = -0.27 | Accept Prob = 0.762
#   Step 360... Structure move | Add edge: oxygen_level_t-1 → pain_level_t-1 | Score Δ = -1.57 | Accept Prob = 0.207
#   Step 361... Structure move | Add edge: oxygen_level_t-1 → pain_level | Score Δ = -0.33 | Accept Prob = 0.721
#   Step 362... Structure move | Remove edge: oxygen_level_t-1 → blood_pressure_t-1 | Score Δ = -0.78 | Accept Prob = 0.459
#   Step 363... Structure move | Remove edge: pain_level_t-1 → mobility_t-1 | Score Δ = 1.03 | Accept Prob = 1.000
#   Step 364... Structure move | Add edge: mobility_t-1 → pain_level_t-1 | Score Δ = 0.49 | Accept Prob = 1.000
#   Step 365...Changepoint move (birth) on mobility | Δ = -5.92 | Accept Prob = 0.003
#   Step 366...  Step 367...Changepoint move (birth) on heart_rate | Δ = -6.03 | Accept Prob = 0.002
#   Step 368... Structure move | Remove edge: heart_rate_t-1 → blood_pressure | Score Δ = -3.18 | Accept Prob = 0.042
#   Step 369...Changepoint move (birth) on heart_rate | Δ = -2.55 | Accept Prob = 0.078
#   Step 370...  Step 371...  Step 372... Structure move | Add edge: mobility_t-1 → blood_pressure_t-1 | Score Δ = 0.82 | Accept Prob = 1.000
# New BEST graph structure found!
#   Step 373... Structure move | Remove edge: heart_rate_t-1 → heart_rate | Score Δ = -1.06 | Accept Prob = 0.346
#   Step 374...  Step 375... Structure move | Remove edge: heart_rate_t-1 → heart_rate | Score Δ = -1.06 | Accept Prob = 0.346
#   Step 376...  Step 377...  Step 378... Structure move | Remove edge: blood_pressure_t-1 → mobility_t-1 | Score Δ = -0.36 | Accept Prob = 0.695
#   Step 379...Changepoint move (birth) on blood_pressure | Δ = -3.21 | Accept Prob = 0.040
#   Step 380...Changepoint move (birth) on heart_rate | Δ = -2.55 | Accept Prob = 0.078
#   Step 381...  Step 382... Structure move | Remove edge: oxygen_level_t-1 → mobility_t-1 | Score Δ = 0.25 | Accept Prob = 1.000
#   Step 383...  Step 384...Changepoint move (birth) on pain_level | Δ = -3.31 | Accept Prob = 0.036
#   Step 385... Structure move | Remove edge: pain_level_t-1 → heart_rate_t-1 | Score Δ = -5.21 | Accept Prob = 0.005
#   Step 386...Changepoint move (death) on blood_pressure | Δ = -0.98 | Accept Prob = 0.375
#   Step 387... Structure move | Add edge: mobility_t-1 → heart_rate_t-1 | Score Δ = 0.27 | Accept Prob = 1.000
# New BEST graph structure found!
#   Step 388... Structure move | Add edge: oxygen_level_t-1 → pain_level_t-1 | Score Δ = -1.82 | Accept Prob = 0.162
#   Step 389...Changepoint move (birth) on mobility | Δ = -3.55 | Accept Prob = 0.029
#   Step 390... Structure move | Remove edge: blood_pressure_t-1 → oxygen_level | Score Δ = -0.91 | Accept Prob = 0.402
#   Step 391... Structure move | Remove edge: oxygen_level_t-1 → pain_level | Score Δ = 0.33 | Accept Prob = 1.000
# New BEST graph structure found!
#   Step 392... Structure move | Add edge: pain_level_t-1 → pain_level | Score Δ = -1.24 | Accept Prob = 0.288
#   Step 393...  Step 394...  Step 395... Structure move | Add edge: oxygen_level_t-1 → mobility_t-1 | Score Δ = -0.25 | Accept Prob = 0.783
#   Step 396... Structure move | Remove edge: blood_pressure_t-1 → pain_level | Score Δ = -6.18 | Accept Prob = 0.002
#   Step 397...  Step 398... Structure move | Remove edge: heart_rate_t-1 → blood_pressure | Score Δ = -3.18 | Accept Prob = 0.042
#   Step 399... Structure move | Add edge: oxygen_level_t-1 → pain_level | Score Δ = -0.33 | Accept Prob = 0.721
#   Step 400... Structure move | Remove edge: pain_level_t-1 → blood_pressure_t-1 | Score Δ = 0.69 | Accept Prob = 1.000
# New BEST graph structure found!
#   Step 401...Changepoint move (birth) on blood_pressure | Δ = -4.31 | Accept Prob = 0.013
#   Step 402... Structure move | Remove edge: mobility_t-1 → oxygen_level_t-1 | Score Δ = -0.88 | Accept Prob = 0.417
#   Step 403...Changepoint move (birth) on oxygen_level_t-1 | Δ = -2.92 | Accept Prob = 0.054
#   Step 404...  Step 405...  Step 406...  Step 407...Changepoint move (birth) on heart_rate_t-1 | Δ = -4.50 | Accept Prob = 0.011
#   Step 408... Structure move | Remove edge: blood_pressure_t-1 → pain_level | Score Δ = -3.98 | Accept Prob = 0.019
#   Step 409... Structure move | Remove edge: mobility_t-1 → pain_level_t-1 | Score Δ = -0.49 | Accept Prob = 0.610
#   Step 410...  Step 411...Changepoint move (realloc) on blood_pressure | Δ = 0.00 | Accept Prob = 1.000
#   Step 412...  Step 413...Changepoint move (birth) on blood_pressure_t-1 | Δ = -3.99 | Accept Prob = 0.019
#   Step 414...  Step 415... Structure move | Remove edge: pain_level_t-1 → blood_pressure | Score Δ = -3.18 | Accept Prob = 0.042
#   Step 416... Structure move | Remove edge: pain_level_t-1 → heart_rate_t-1 | Score Δ = -7.54 | Accept Prob = 0.001
#   Step 417...  Step 418... Structure move | Remove edge: mobility_t-1 → pain_level_t-1 | Score Δ = -0.49 | Accept Prob = 0.610
#   Step 419...  Step 420... Structure move | Remove edge: mobility_t-1 → heart_rate_t-1 | Score Δ = -0.27 | Accept Prob = 0.762
#   Step 421...  Step 422...  Step 423...  Step 424...Changepoint move (death) on blood_pressure | Δ = -0.98 | Accept Prob = 0.375
#   Step 425... Structure move | Remove edge: blood_pressure_t-1 → mobility | Score Δ = -2.85 | Accept Prob = 0.058
#   Step 426... Structure move | Add edge: oxygen_level_t-1 → mobility_t-1 | Score Δ = -0.25 | Accept Prob = 0.783
#   Step 427... Structure move | Remove edge: mobility_t-1 → heart_rate | Score Δ = -2.67 | Accept Prob = 0.069
#   Step 428...Changepoint move (birth) on heart_rate | Δ = -5.15 | Accept Prob = 0.006
#   Step 429...Changepoint move (birth) on mobility | Δ = -5.51 | Accept Prob = 0.004
#   Step 430...  Step 431... Structure move | Add edge: pain_level_t-1 → blood_pressure_t-1 | Score Δ = -0.69 | Accept Prob = 0.504
#   Step 432... Structure move | Remove edge: mobility_t-1 → blood_pressure_t-1 | Score Δ = -0.82 | Accept Prob = 0.442
#   Step 433...  Step 434...  Step 435... Structure move | Add edge: blood_pressure_t-1 → heart_rate | Score Δ = 3.30 | Accept Prob = 1.000
#   Step 436... Structure move | Remove edge: blood_pressure_t-1 → mobility | Score Δ = -2.85 | Accept Prob = 0.058
#   Step 437...  Step 438... Structure move | Add edge: blood_pressure_t-1 → heart_rate_t-1 | Score Δ = -1.98 | Accept Prob = 0.138
#   Step 439...Changepoint move (birth) on mobility | Δ = -5.51 | Accept Prob = 0.004
#   Step 440... Structure move | Remove edge: heart_rate_t-1 → oxygen_level | Score Δ = -0.06 | Accept Prob = 0.938
#   Step 441...Changepoint move (birth) on pain_level_t-1 | Δ = -2.33 | Accept Prob = 0.097
#   Step 442...Changepoint move (birth) on heart_rate | Δ = -3.50 | Accept Prob = 0.030
#   Step 443...  Step 444... Structure move | Add edge: oxygen_level_t-1 → pain_level_t-1 | Score Δ = -1.57 | Accept Prob = 0.207
#   Step 445...  Step 446... Structure move | Remove edge: pain_level_t-1 → oxygen_level | Score Δ = -0.88 | Accept Prob = 0.417
#   Step 447...  Step 448... Structure move | Remove edge: pain_level_t-1 → blood_pressure_t-1 | Score Δ = 0.69 | Accept Prob = 1.000
#   Step 449...Changepoint move (birth) on pain_level | Δ = -3.72 | Accept Prob = 0.024
#   Step 450... Structure move | Remove edge: pain_level_t-1 → oxygen_level_t-1 | Score Δ = 0.12 | Accept Prob = 1.000
#   Step 451...  Step 452... Structure move | Remove edge: heart_rate_t-1 → pain_level_t-1 | Score Δ = -5.38 | Accept Prob = 0.005
#   Step 453...  Step 454... Structure move | Add edge: oxygen_level_t-1 → mobility_t-1 | Score Δ = -0.25 | Accept Prob = 0.783
#   Step 455...  Step 456...  Step 457... Structure move | Add edge: blood_pressure_t-1 → pain_level_t-1 | Score Δ = -1.65 | Accept Prob = 0.193
#   Step 458... Structure move | Add edge: heart_rate_t-1 → blood_pressure_t-1 | Score Δ = -2.23 | Accept Prob = 0.108
#   Step 459...  Step 460...  Step 461...Changepoint move (birth) on blood_pressure | Δ = 0.98 | Accept Prob = 1.000
#   Step 462... Structure move | Remove edge: heart_rate_t-1 → pain_level_t-1 | Score Δ = -5.38 | Accept Prob = 0.005
#   Step 463...Changepoint move (birth) on oxygen_level_t-1 | Δ = -5.97 | Accept Prob = 0.003
#   Step 464... Structure move | Add edge: oxygen_level_t-1 → heart_rate_t-1 | Score Δ = -2.16 | Accept Prob = 0.115
#   Step 465...Changepoint move (birth) on pain_level_t-1 | Δ = -2.99 | Accept Prob = 0.051
#   Step 466...  Step 467... Structure move | Remove edge: heart_rate_t-1 → oxygen_level | Score Δ = -0.06 | Accept Prob = 0.938
#   Step 468...  Step 469... Structure move | Add edge: pain_level_t-1 → mobility_t-1 | Score Δ = -1.78 | Accept Prob = 0.168
#   Step 470... Structure move | Remove edge: pain_level_t-1 → heart_rate | Score Δ = -3.30 | Accept Prob = 0.037
#   Step 471...  Step 472... Structure move | Remove edge: pain_level_t-1 → heart_rate | Score Δ = -3.30 | Accept Prob = 0.037
#   Step 473...  Step 474...  Step 475...  Step 476... Structure move | Remove edge: heart_rate_t-1 → mobility | Score Δ = -2.95 | Accept Prob = 0.052
#   Step 477...  Step 478...  Step 479...  Step 480... Structure move | Remove edge: blood_pressure_t-1 → heart_rate | Score Δ = -3.30 | Accept Prob = 0.037
#   Step 481... Structure move | Remove edge: pain_level_t-1 → mobility_t-1 | Score Δ = 1.78 | Accept Prob = 1.000
#   Step 482...  Step 483...  Step 484...Changepoint move (birth) on pain_level | Δ = -6.90 | Accept Prob = 0.001
#   Step 485...  Step 486...  Step 487...  Step 488... Structure move | Remove edge: blood_pressure_t-1 → mobility | Score Δ = -2.85 | Accept Prob = 0.058
#   Step 489...Changepoint move (birth) on mobility_t-1 | Δ = -5.67 | Accept Prob = 0.003
#   Step 490... Structure move | Remove edge: blood_pressure_t-1 → heart_rate_t-1 | Score Δ = 1.98 | Accept Prob = 1.000
#   Step 491...Changepoint move (birth) on blood_pressure | Δ = -2.11 | Accept Prob = 0.121
#   Step 492... Structure move | Remove edge: blood_pressure_t-1 → blood_pressure | Score Δ = -2.89 | Accept Prob = 0.056
#   Step 493... Structure move | Remove edge: blood_pressure_t-1 → pain_level | Score Δ = -3.98 | Accept Prob = 0.019
#   Step 494... Structure move | Add edge: blood_pressure_t-1 → mobility_t-1 | Score Δ = 0.36 | Accept Prob = 1.000
#   Step 495...  Step 496... Structure move | Add edge: blood_pressure_t-1 → heart_rate_t-1 | Score Δ = -1.98 | Accept Prob = 0.138
#   Step 497...  Step 498...  Step 499... Structure move | Add edge: oxygen_level_t-1 → blood_pressure_t-1 | Score Δ = -0.66 | Accept Prob = 0.518
#   Step 500... Structure move | Remove edge: heart_rate_t-1 → blood_pressure | Score Δ = -3.18 | Accept Prob = 0.042
#   Step 501... Structure move | Remove edge: blood_pressure_t-1 → oxygen_level | Score Δ = -0.91 | Accept Prob = 0.402
#   Step 502...Changepoint move (birth) on heart_rate | Δ = -5.69 | Accept Prob = 0.003
#   Step 503... Structure move | Remove edge: heart_rate_t-1 → oxygen_level | Score Δ = -0.90 | Accept Prob = 0.405
#   Step 504... Structure move | Add edge: heart_rate_t-1 → blood_pressure_t-1 | Score Δ = 0.00 | Accept Prob = 1.000
#   Step 505... Structure move | Remove edge: blood_pressure_t-1 → blood_pressure | Score Δ = -2.89 | Accept Prob = 0.056
#   Step 506... Structure move | Remove edge: heart_rate_t-1 → oxygen_level_t-1 | Score Δ = 1.57 | Accept Prob = 1.000
#   Step 507... Structure move | Add edge: mobility_t-1 → oxygen_level | Score Δ = -1.01 | Accept Prob = 0.366
#   Step 508...  Step 509... Structure move | Add edge: mobility_t-1 → oxygen_level_t-1 | Score Δ = -0.21 | Accept Prob = 0.809
#   Step 510...Changepoint move (birth) on pain_level | Δ = -6.90 | Accept Prob = 0.001
#   Step 511... Structure move | Add edge: mobility_t-1 → oxygen_level | Score Δ = -1.01 | Accept Prob = 0.366
#   Step 512... Structure move | Add edge: oxygen_level_t-1 → heart_rate_t-1 | Score Δ = -1.68 | Accept Prob = 0.186
#   Step 513...  Step 514...Changepoint move (birth) on oxygen_level_t-1 | Δ = -6.01 | Accept Prob = 0.002
#   Step 515...Changepoint move (realloc) on blood_pressure | Δ = 0.00 | Accept Prob = 1.000
#   Step 516... Structure move | Remove edge: mobility_t-1 → pain_level | Score Δ = -0.52 | Accept Prob = 0.594
#   Step 517...Changepoint move (birth) on mobility | Δ = -5.51 | Accept Prob = 0.004
#   Step 518...  Step 519...Changepoint move (birth) on blood_pressure_t-1 | Δ = -2.96 | Accept Prob = 0.052
#   Step 520...Changepoint move (birth) on oxygen_level_t-1 | Δ = -5.35 | Accept Prob = 0.005
#   Step 521... Structure move | Remove edge: blood_pressure_t-1 → blood_pressure | Score Δ = -2.89 | Accept Prob = 0.056
#   Step 522... Structure move | Remove edge: pain_level_t-1 → heart_rate_t-1 | Score Δ = -5.21 | Accept Prob = 0.005
#   Step 523...  Step 524...Changepoint move (death) on blood_pressure_t-1 | Δ = 2.96 | Accept Prob = 1.000
#   Step 525...Changepoint move (birth) on oxygen_level | Δ = -4.31 | Accept Prob = 0.013
#   Step 526...  Step 527... Structure move | Remove edge: oxygen_level_t-1 → mobility_t-1 | Score Δ = -0.46 | Accept Prob = 0.632
#   Step 528...  Step 529... Structure move | Add edge: oxygen_level_t-1 → oxygen_level | Score Δ = 2.79 | Accept Prob = 1.000
#   Step 530... Structure move | Add edge: mobility_t-1 → oxygen_level_t-1 | Score Δ = -0.21 | Accept Prob = 0.809
#   Step 531...Changepoint move (birth) on pain_level | Δ = -4.48 | Accept Prob = 0.011
#   Step 532...  Step 533...  Step 534...  Step 535...  Step 536... Structure move | Remove edge: heart_rate_t-1 → mobility | Score Δ = -2.95 | Accept Prob = 0.052
#   Step 537... Structure move | Remove edge: oxygen_level_t-1 → pain_level_t-1 | Score Δ = 1.57 | Accept Prob = 1.000
#   Step 538... Structure move | Remove edge: mobility_t-1 → mobility | Score Δ = -1.23 | Accept Prob = 0.292
#   Step 539... Structure move | Add edge: pain_level_t-1 → mobility | Score Δ = -1.07 | Accept Prob = 0.343
#   Step 540...  Step 541...Changepoint move (birth) on blood_pressure_t-1 | Δ = 3.46 | Accept Prob = 1.000
# New BEST changepoint config found!
#   Step 542...  Step 543...  Step 544...  Step 545... Structure move | Remove edge: pain_level_t-1 → oxygen_level | Score Δ = 0.13 | Accept Prob = 1.000
# New BEST graph structure found!
#   Step 546...Changepoint move (birth) on mobility | Δ = -1.81 | Accept Prob = 0.164
#   Step 547... Structure move | Remove edge: mobility_t-1 → pain_level | Score Δ = -0.52 | Accept Prob = 0.594
#   Step 548... Structure move | Remove edge: blood_pressure_t-1 → heart_rate | Score Δ = -3.30 | Accept Prob = 0.037
#   Step 549...  Step 550... Structure move | Remove edge: blood_pressure_t-1 → blood_pressure | Score Δ = -2.89 | Accept Prob = 0.056
#   Step 551... Structure move | Add edge: mobility_t-1 → pain_level | Score Δ = 0.52 | Accept Prob = 1.000
#   Step 552...  Step 553... Structure move | Remove edge: mobility_t-1 → blood_pressure_t-1 | Score Δ = -1.10 | Accept Prob = 0.333
#   Step 554... Structure move | Remove edge: heart_rate_t-1 → blood_pressure_t-1 | Score Δ = -6.24 | Accept Prob = 0.002
#   Step 555...Changepoint move (birth) on oxygen_level | Δ = -2.05 | Accept Prob = 0.128
#   Step 556...  Step 557...Changepoint move (birth) on pain_level | Δ = -4.41 | Accept Prob = 0.012
#   Step 558...  Step 559...Changepoint move (death) on blood_pressure | Δ = -0.77 | Accept Prob = 0.465
#   Step 560...Changepoint move (birth) on pain_level_t-1 | Δ = -2.78 | Accept Prob = 0.062
#   Step 561... Structure move | Remove edge: heart_rate_t-1 → blood_pressure | Score Δ = 0.73 | Accept Prob = 1.000
#   Step 562...  Step 563... Structure move | Add edge: blood_pressure_t-1 → pain_level_t-1 | Score Δ = -1.87 | Accept Prob = 0.154
#   Step 564...Changepoint move (birth) on pain_level_t-1 | Δ = -3.25 | Accept Prob = 0.039
#   Step 565...Changepoint move (birth) on oxygen_level | Δ = -2.34 | Accept Prob = 0.096
#   Step 566...Changepoint move (birth) on mobility | Δ = -3.48 | Accept Prob = 0.031
#   Step 567... Structure move | Remove edge: pain_level_t-1 → heart_rate | Score Δ = -3.30 | Accept Prob = 0.037
#   Step 568...Changepoint move (death) on oxygen_level | Δ = 2.34 | Accept Prob = 1.000
#   Step 569...  Step 570... Structure move | Remove edge: blood_pressure_t-1 → mobility_t-1 | Score Δ = -0.36 | Accept Prob = 0.695
#   Step 571... Structure move | Add edge: pain_level_t-1 → mobility | Score Δ = -1.07 | Accept Prob = 0.343
#   Step 572... Structure move | Add edge: mobility_t-1 → blood_pressure_t-1 | Score Δ = 1.10 | Accept Prob = 1.000
#   Step 573...  Step 574... Structure move | Remove edge: oxygen_level_t-1 → mobility_t-1 | Score Δ = 0.25 | Accept Prob = 1.000
#   Step 575...Changepoint move (birth) on oxygen_level_t-1 | Δ = -5.33 | Accept Prob = 0.005
#   Step 576...  Step 577...  Step 578... Structure move | Add edge: pain_level_t-1 → oxygen_level_t-1 | Score Δ = -1.70 | Accept Prob = 0.182
#   Step 579...  Step 580...Changepoint move (realloc) on blood_pressure_t-1 | Δ = 0.00 | Accept Prob = 1.000
#   Step 581...  Step 582... Structure move | Add edge: oxygen_level_t-1 → heart_rate_t-1 | Score Δ = -1.68 | Accept Prob = 0.186
#   Step 583... Structure move | Add edge: pain_level_t-1 → oxygen_level_t-1 | Score Δ = -1.70 | Accept Prob = 0.182
#   Step 584... Structure move | Add edge: heart_rate_t-1 → mobility_t-1 | Score Δ = -1.76 | Accept Prob = 0.172
#   Step 585... Structure move | Remove edge: oxygen_level_t-1 → heart_rate_t-1 | Score Δ = 1.68 | Accept Prob = 1.000
#   Step 586...  Step 587...  Step 588...Changepoint move (birth) on oxygen_level | Δ = -2.05 | Accept Prob = 0.128
#   Step 589... Structure move | Remove edge: blood_pressure_t-1 → heart_rate | Score Δ = -3.30 | Accept Prob = 0.037
#   Step 590...  Step 591... Structure move | Add edge: oxygen_level_t-1 → pain_level_t-1 | Score Δ = -1.57 | Accept Prob = 0.207
#   Step 592...  Step 593...  Step 594...  Step 595... Structure move | Add edge: heart_rate_t-1 → oxygen_level_t-1 | Score Δ = -0.79 | Accept Prob = 0.456
#   Step 596...  Step 597... Structure move | Add edge: blood_pressure_t-1 → oxygen_level_t-1 | Score Δ = 1.93 | Accept Prob = 1.000
#   Step 598... Structure move | Remove edge: mobility_t-1 → oxygen_level_t-1 | Score Δ = -2.84 | Accept Prob = 0.058
#   Step 599...Changepoint move (birth) on heart_rate_t-1 | Δ = -4.67 | Accept Prob = 0.009
#   Step 600...  Step 601...  Step 602... Structure move | Remove edge: blood_pressure_t-1 → oxygen_level_t-1 | Score Δ = -1.93 | Accept Prob = 0.146
#   Step 603... Structure move | Add edge: blood_pressure_t-1 → blood_pressure | Score Δ = 1.49 | Accept Prob = 1.000
#   Step 604... Structure move | Add edge: oxygen_level_t-1 → blood_pressure | Score Δ = 0.05 | Accept Prob = 1.000
#   Step 605...  Step 606...Changepoint move (birth) on blood_pressure_t-1 | Δ = -1.99 | Accept Prob = 0.136
#   Step 607...  Step 608...  Step 609...  Step 610...Changepoint move (birth) on mobility_t-1 | Δ = -5.56 | Accept Prob = 0.004
#   Step 611...Changepoint move (birth) on mobility | Δ = -4.64 | Accept Prob = 0.010
#   Step 612...Changepoint move (birth) on heart_rate | Δ = -5.69 | Accept Prob = 0.003
#   Step 613... Structure move | Add edge: mobility_t-1 → heart_rate_t-1 | Score Δ = 0.27 | Accept Prob = 1.000
#   Step 614...  Step 615... Structure move | Remove edge: mobility_t-1 → pain_level | Score Δ = -0.52 | Accept Prob = 0.594
#   Step 616... Structure move | Add edge: mobility_t-1 → pain_level_t-1 | Score Δ = 0.49 | Accept Prob = 1.000
#   Step 617...  Step 618...  Step 619...  Step 620...  Step 621... Structure move | Remove edge: pain_level_t-1 → blood_pressure | Score Δ = 0.08 | Accept Prob = 1.000
#   Step 622... Structure move | Remove edge: heart_rate_t-1 → heart_rate | Score Δ = -0.46 | Accept Prob = 0.632
#   Step 623... Structure move | Add edge: heart_rate_t-1 → mobility_t-1 | Score Δ = -1.76 | Accept Prob = 0.172
#   Step 624...  Step 625...Changepoint move (birth) on mobility | Δ = -3.48 | Accept Prob = 0.031
#   Step 626...  Step 627...Changepoint move (birth) on heart_rate | Δ = -5.08 | Accept Prob = 0.006
#   Step 628... Structure move | Remove edge: mobility_t-1 → blood_pressure_t-1 | Score Δ = -1.10 | Accept Prob = 0.333
# ...
#   Step 1808...  Step 1809...  Step 1810... Structure move | Remove edge: mobility_t-1 → pain_level | Score Δ = -2.04 | Accept Prob = 0.130
#   Step 1811... Structure move | Add edge: heart_rate_t-1 → mobility | Score Δ = -1.03 | Accept Prob = 0.356
#   Step 1812...Changepoint move (birth) on pain_level_t-1 | Δ = -5.29 | Accept Prob = 0.005
#   Step 1813... Structure move | Remove edge: pain_level_t-1 → blood_pressure_t-1 | Score Δ = -0.66 | Accept Prob = 0.519
#   Step 1814... Structure move | Add edge: oxygen_level_t-1 → mobility_t-1 | Score Δ = -0.16 | Accept Prob = 0.853
#   Step 1815...  Step 1816...Changepoint move (birth) on oxygen_level | Δ = -4.71 | Accept Prob = 0.009
#   Step 1817...  Step 1818...Changepoint move (birth) on oxygen_level | Δ = -5.81 | Accept Prob = 0.003
#   Step 1819...  Step 1820...  Step 1821... Structure move | Add edge: pain_level_t-1 → blood_pressure | Score Δ = -0.01 | Accept Prob = 0.995
#   Step 1822... Structure move | Remove edge: pain_level_t-1 → mobility | Score Δ = -2.33 | Accept Prob = 0.097
#   Step 1823... Structure move | Remove edge: mobility_t-1 → oxygen_level | Score Δ = -0.72 | Accept Prob = 0.486
#   Step 1824...  Step 1825... Structure move | Remove edge: heart_rate_t-1 → heart_rate | Score Δ = -1.91 | Accept Prob = 0.148
#   Step 1826... Structure move | Remove edge: oxygen_level_t-1 → blood_pressure_t-1 | Score Δ = -1.39 | Accept Prob = 0.250
#   Step 1827...  Step 1828...  Step 1829...Changepoint move (birth) on blood_pressure_t-1 | Δ = -5.15 | Accept Prob = 0.006
#   Step 1830... Structure move | Add edge: mobility_t-1 → blood_pressure | Score Δ = -0.35 | Accept Prob = 0.703
#   Step 1831...  Step 1832... Structure move | Add edge: pain_level_t-1 → mobility | Score Δ = 2.33 | Accept Prob = 1.000
#   Step 1833...  Step 1834...  Step 1835... Structure move | Remove edge: oxygen_level_t-1 → pain_level | Score Δ = -1.10 | Accept Prob = 0.333
#   Step 1836... Structure move | Remove edge: heart_rate_t-1 → heart_rate | Score Δ = -1.91 | Accept Prob = 0.148
#   Step 1837...  Step 1838... Structure move | Add edge: blood_pressure_t-1 → heart_rate | Score Δ = 2.60 | Accept Prob = 1.000
#   Step 1839... Structure move | Remove edge: mobility_t-1 → blood_pressure | Score Δ = 0.35 | Accept Prob = 1.000
#   Step 1840... Structure move | Add edge: oxygen_level_t-1 → pain_level | Score Δ = 1.10 | Accept Prob = 1.000
#   Step 1841... Structure move | Add edge: pain_level_t-1 → mobility_t-1 | Score Δ = 0.69 | Accept Prob = 1.000
#   Step 1842...  Step 1843... Structure move | Remove edge: oxygen_level_t-1 → heart_rate_t-1 | Score Δ = -2.48 | Accept Prob = 0.083
#   Step 1844...  Step 1845... Structure move | Remove edge: heart_rate_t-1 → oxygen_level_t-1 | Score Δ = -0.65 | Accept Prob = 0.521
#   Step 1846... Structure move | Add edge: oxygen_level_t-1 → oxygen_level | Score Δ = -0.12 | Accept Prob = 0.889
#   Step 1847... Structure move | Remove edge: pain_level_t-1 → heart_rate_t-1 | Score Δ = 0.04 | Accept Prob = 1.000
#   Step 1848... Structure move | Remove edge: blood_pressure_t-1 → heart_rate | Score Δ = -2.60 | Accept Prob = 0.074
#   Step 1849... Structure move | Remove edge: blood_pressure_t-1 → pain_level_t-1 | Score Δ = -1.50 | Accept Prob = 0.222
#   Step 1850... Structure move | Remove edge: heart_rate_t-1 → blood_pressure_t-1 | Score Δ = -1.04 | Accept Prob = 0.354
#   Step 1851... Structure move | Add edge: heart_rate_t-1 → blood_pressure | Score Δ = 0.75 | Accept Prob = 1.000
#   Step 1852...  Step 1853... Structure move | Add edge: mobility_t-1 → heart_rate_t-1 | Score Δ = -0.04 | Accept Prob = 0.964
#   Step 1854... Structure move | Remove edge: pain_level_t-1 → mobility | Score Δ = -2.33 | Accept Prob = 0.097
#   Step 1855...  Step 1856...Changepoint move (birth) on mobility | Δ = -5.22 | Accept Prob = 0.005
#   Step 1857...  Step 1858...  Step 1859...Changepoint move (birth) on oxygen_level_t-1 | Δ = -4.02 | Accept Prob = 0.018
#   Step 1860...  Step 1861...  Step 1862... Structure move | Add edge: heart_rate_t-1 → oxygen_level_t-1 | Score Δ = 0.65 | Accept Prob = 1.000
#   Step 1863... Structure move | Add edge: blood_pressure_t-1 → oxygen_level_t-1 | Score Δ = 0.29 | Accept Prob = 1.000
#   Step 1864...  Step 1865...  Step 1866... Structure move | Remove edge: blood_pressure_t-1 → heart_rate | Score Δ = -2.60 | Accept Prob = 0.074
#   Step 1867...  Step 1868...  Step 1869... Structure move | Remove edge: heart_rate_t-1 → pain_level_t-1 | Score Δ = -0.12 | Accept Prob = 0.889
#   Step 1870...  Step 1871... Structure move | Remove edge: pain_level_t-1 → heart_rate | Score Δ = -3.30 | Accept Prob = 0.037
#   Step 1872... Structure move | Remove edge: heart_rate_t-1 → oxygen_level_t-1 | Score Δ = -1.67 | Accept Prob = 0.188
#   Step 1873...  Step 1874... Structure move | Remove edge: pain_level_t-1 → pain_level | Score Δ = -2.04 | Accept Prob = 0.130
#   Step 1875... Structure move | Add edge: oxygen_level_t-1 → blood_pressure | Score Δ = 0.69 | Accept Prob = 1.000
#   Step 1876... Structure move | Add edge: oxygen_level_t-1 → mobility | Score Δ = -0.22 | Accept Prob = 0.800
#   Step 1877... Structure move | Remove edge: mobility_t-1 → heart_rate_t-1 | Score Δ = 0.04 | Accept Prob = 1.000
#   Step 1878... Structure move | Remove edge: oxygen_level_t-1 → blood_pressure | Score Δ = -0.69 | Accept Prob = 0.500
#   Step 1879... Structure move | Remove edge: mobility_t-1 → pain_level | Score Δ = -0.99 | Accept Prob = 0.371
#   Step 1880...Changepoint move (birth) on pain_level_t-1 | Δ = -5.86 | Accept Prob = 0.003
#   Step 1881... Structure move | Add edge: heart_rate_t-1 → pain_level | Score Δ = 1.12 | Accept Prob = 1.000
#   Step 1882...  Step 1883...  Step 1884...  Step 1885...  Step 1886... Structure move | Remove edge: blood_pressure_t-1 → oxygen_level | Score Δ = -1.57 | Accept Prob = 0.208
#   Step 1887... Structure move | Remove edge: oxygen_level_t-1 → oxygen_level | Score Δ = 0.12 | Accept Prob = 1.000
#   Step 1888... Structure move | Add edge: pain_level_t-1 → oxygen_level | Score Δ = 0.17 | Accept Prob = 1.000
#   Step 1889...  Step 1890...  Step 1891... Structure move | Remove edge: mobility_t-1 → oxygen_level | Score Δ = -0.06 | Accept Prob = 0.937
#   Step 1892...Changepoint move (birth) on heart_rate_t-1 | Δ = -3.65 | Accept Prob = 0.026
#   Step 1893... Structure move | Remove edge: heart_rate_t-1 → blood_pressure_t-1 | Score Δ = -1.04 | Accept Prob = 0.354
#   Step 1894... Structure move | Add edge: heart_rate_t-1 → oxygen_level | Score Δ = 0.06 | Accept Prob = 1.000
#   Step 1895...  Step 1896... Structure move | Add edge: oxygen_level_t-1 → blood_pressure_t-1 | Score Δ = -0.23 | Accept Prob = 0.792
#   Step 1897... Structure move | Remove edge: heart_rate_t-1 → blood_pressure | Score Δ = -1.91 | Accept Prob = 0.148
#   Step 1898...  Step 1899... Structure move | Remove edge: heart_rate_t-1 → mobility_t-1 | Score Δ = -1.39 | Accept Prob = 0.250
#   Step 1900...Changepoint move (birth) on mobility_t-1 | Δ = -1.53 | Accept Prob = 0.216
#   Step 1901...  Step 1902...Changepoint move (birth) on pain_level | Δ = -3.78 | Accept Prob = 0.023
#   Step 1903... Structure move | Add edge: mobility_t-1 → pain_level | Score Δ = -0.86 | Accept Prob = 0.422
#   Step 1904...  Step 1905... Structure move | Add edge: heart_rate_t-1 → pain_level_t-1 | Score Δ = 0.12 | Accept Prob = 1.000
#   Step 1906... Structure move | Remove edge: blood_pressure_t-1 → oxygen_level | Score Δ = -0.29 | Accept Prob = 0.750
#   Step 1907... Structure move | Remove edge: oxygen_level_t-1 → heart_rate_t-1 | Score Δ = -1.39 | Accept Prob = 0.250
#   Step 1908...  Step 1909...  Step 1910...Changepoint move (birth) on oxygen_level | Δ = -5.00 | Accept Prob = 0.007
#   Step 1911...  Step 1912... Structure move | Remove edge: oxygen_level_t-1 → pain_level | Score Δ = -0.12 | Accept Prob = 0.889
#   Step 1913...  Step 1914...  Step 1915... Structure move | Remove edge: oxygen_level_t-1 → pain_level_t-1 | Score Δ = -1.39 | Accept Prob = 0.250
#   Step 1916...  Step 1917...  Step 1918... Structure move | Remove edge: oxygen_level_t-1 → heart_rate | Score Δ = -2.48 | Accept Prob = 0.083
#   Step 1919...  Step 1920... Structure move | Remove edge: oxygen_level_t-1 → heart_rate | Score Δ = -2.48 | Accept Prob = 0.083
#   Step 1921...Changepoint move (birth) on pain_level_t-1 | Δ = -2.80 | Accept Prob = 0.061
#   Step 1922... Structure move | Remove edge: mobility_t-1 → pain_level | Score Δ = 0.15 | Accept Prob = 1.000
#   Step 1923... Structure move | Add edge: mobility_t-1 → heart_rate_t-1 | Score Δ = -0.04 | Accept Prob = 0.964
#   Step 1924... Structure move | Remove edge: pain_level_t-1 → oxygen_level | Score Δ = -2.04 | Accept Prob = 0.130
#   Step 1925... Structure move | Remove edge: heart_rate_t-1 → mobility_t-1 | Score Δ = -1.39 | Accept Prob = 0.250
#   Step 1926... Structure move | Remove edge: blood_pressure_t-1 → oxygen_level_t-1 | Score Δ = -0.29 | Accept Prob = 0.750
#   Step 1927... Structure move | Add edge: pain_level_t-1 → pain_level | Score Δ = -0.04 | Accept Prob = 0.964
#   Step 1928...Changepoint move (birth) on pain_level_t-1 | Δ = -5.29 | Accept Prob = 0.005
#   Step 1929...Changepoint move (birth) on blood_pressure | Δ = -2.40 | Accept Prob = 0.091
#   Step 1930... Structure move | Remove edge: heart_rate_t-1 → oxygen_level_t-1 | Score Δ = -1.67 | Accept Prob = 0.188
#   Step 1931... Structure move | Add edge: oxygen_level_t-1 → oxygen_level | Score Δ = -0.41 | Accept Prob = 0.667
#   Step 1932... Structure move | Remove edge: blood_pressure_t-1 → pain_level_t-1 | Score Δ = -1.50 | Accept Prob = 0.222
#   Step 1933...Changepoint move (birth) on pain_level_t-1 | Δ = -0.20 | Accept Prob = 0.819
#   Step 1934...Changepoint move (birth) on heart_rate_t-1 | Δ = -4.75 | Accept Prob = 0.009
#   Step 1935... Structure move | Remove edge: pain_level_t-1 → oxygen_level_t-1 | Score Δ = -0.47 | Accept Prob = 0.625
#   Step 1936... Structure move | Remove edge: heart_rate_t-1 → pain_level | Score Δ = -0.19 | Accept Prob = 0.830
#   Step 1937...  Step 1938... Structure move | Add edge: blood_pressure_t-1 → oxygen_level | Score Δ = 0.29 | Accept Prob = 1.000
#   Step 1939...  Step 1940...  Step 1941...  Step 1942... Structure move | Add edge: oxygen_level_t-1 → blood_pressure_t-1 | Score Δ = -0.23 | Accept Prob = 0.792
#   Step 1943...Changepoint move (birth) on pain_level_t-1 | Δ = -3.09 | Accept Prob = 0.045
#   Step 1944...  Step 1945...  Step 1946... Structure move | Add edge: heart_rate_t-1 → pain_level | Score Δ = 0.19 | Accept Prob = 1.000
#   Step 1947... Structure move | Remove edge: oxygen_level_t-1 → blood_pressure | Score Δ = -0.69 | Accept Prob = 0.500
#   Step 1948... Structure move | Remove edge: blood_pressure_t-1 → heart_rate_t-1 | Score Δ = -2.66 | Accept Prob = 0.070
#   Step 1949... Structure move | Remove edge: oxygen_level_t-1 → blood_pressure_t-1 | Score Δ = 0.23 | Accept Prob = 1.000
#   Step 1950...  Step 1951... Structure move | Remove edge: pain_level_t-1 → pain_level | Score Δ = 0.04 | Accept Prob = 1.000
#   Step 1952...  Step 1953...  Step 1954... Structure move | Remove edge: mobility_t-1 → mobility | Score Δ = -0.18 | Accept Prob = 0.833
#   Step 1955...  Step 1956... Structure move | Remove edge: heart_rate_t-1 → oxygen_level | Score Δ = -0.06 | Accept Prob = 0.937
#   Step 1957...  Step 1958... Structure move | Remove edge: oxygen_level_t-1 → blood_pressure | Score Δ = -0.69 | Accept Prob = 0.500
#   Step 1959... Structure move | Add edge: oxygen_level_t-1 → oxygen_level | Score Δ = -0.22 | Accept Prob = 0.800
#   Step 1960... Structure move | Add edge: blood_pressure_t-1 → pain_level | Score Δ = 0.94 | Accept Prob = 1.000
#   Step 1961...  Step 1962... Structure move | Add edge: mobility_t-1 → heart_rate_t-1 | Score Δ = -0.04 | Accept Prob = 0.964
#   Step 1963... Structure move | Remove edge: pain_level_t-1 → mobility | Score Δ = -2.08 | Accept Prob = 0.125
#   Step 1964...Changepoint move (birth) on pain_level | Δ = -3.26 | Accept Prob = 0.038
#   Step 1965... Structure move | Remove edge: oxygen_level_t-1 → heart_rate | Score Δ = -2.48 | Accept Prob = 0.083
#   Step 1966...  Step 1967... Structure move | Add edge: mobility_t-1 → blood_pressure_t-1 | Score Δ = -1.76 | Accept Prob = 0.172
#   Step 1968...  Step 1969...  Step 1970...Changepoint move (birth) on heart_rate | Δ = -3.50 | Accept Prob = 0.030
#   Step 1971... Structure move | Add edge: blood_pressure_t-1 → pain_level_t-1 | Score Δ = 0.41 | Accept Prob = 1.000
#   Step 1972...Changepoint move (birth) on mobility | Δ = -4.53 | Accept Prob = 0.011
#   Step 1973...Changepoint move (birth) on heart_rate | Δ = -3.50 | Accept Prob = 0.030
#   Step 1974... Structure move | Remove edge: pain_level_t-1 → mobility_t-1 | Score Δ = -0.69 | Accept Prob = 0.500
#   Step 1975... Structure move | Remove edge: heart_rate_t-1 → blood_pressure | Score Δ = -1.91 | Accept Prob = 0.148
#   Step 1976...Changepoint move (birth) on pain_level | Δ = -2.68 | Accept Prob = 0.068
#   Step 1977... Structure move | Add edge: heart_rate_t-1 → blood_pressure_t-1 | Score Δ = 1.04 | Accept Prob = 1.000
#   Step 1978...  Step 1979... Structure move | Remove edge: pain_level_t-1 → blood_pressure | Score Δ = -2.60 | Accept Prob = 0.074
#   Step 1980... Structure move | Remove edge: oxygen_level_t-1 → oxygen_level | Score Δ = 0.22 | Accept Prob = 1.000
#   Step 1981... Structure move | Remove edge: heart_rate_t-1 → mobility_t-1 | Score Δ = -1.39 | Accept Prob = 0.250
#   Step 1982...  Step 1983...Changepoint move (birth) on pain_level_t-1 | Δ = -5.69 | Accept Prob = 0.003
#   Step 1984... Structure move | Remove edge: blood_pressure_t-1 → pain_level | Score Δ = -0.94 | Accept Prob = 0.389
#   Step 1985... Structure move | Remove edge: pain_level_t-1 → blood_pressure | Score Δ = -2.60 | Accept Prob = 0.074
#   Step 1986...Changepoint move (birth) on heart_rate_t-1 | Δ = -3.61 | Accept Prob = 0.027
#   Step 1987... Structure move | Add edge: mobility_t-1 → pain_level | Score Δ = 1.10 | Accept Prob = 1.000
#   Step 1988...  Step 1989... Structure move | Remove edge: heart_rate_t-1 → blood_pressure | Score Δ = -1.91 | Accept Prob = 0.148
#   Step 1990...Changepoint move (birth) on mobility_t-1 | Δ = -4.31 | Accept Prob = 0.013
#   Step 1991... Structure move | Remove edge: oxygen_level_t-1 → mobility | Score Δ = 0.97 | Accept Prob = 1.000
#   Step 1992... Structure move | Remove edge: blood_pressure_t-1 → oxygen_level | Score Δ = -1.64 | Accept Prob = 0.194
#   Step 1993...  Step 1994... Structure move | Remove edge: blood_pressure_t-1 → oxygen_level_t-1 | Score Δ = -0.29 | Accept Prob = 0.750
#   Step 1995... Structure move | Add edge: mobility_t-1 → blood_pressure_t-1 | Score Δ = -0.15 | Accept Prob = 0.857
#   Step 1996...  Step 1997... Structure move | Remove edge: heart_rate_t-1 → pain_level_t-1 | Score Δ = -0.41 | Accept Prob = 0.667
#   Step 1998... Structure move | Add edge: oxygen_level_t-1 → mobility | Score Δ = -0.97 | Accept Prob = 0.381
#   Step 1999... Done with subject 10 | Best score: -113.90
#
# True connections: blood_pressure_t-1 → pain_level, pain_level_t-1 → mobility
#
# Best Graph Structure:
# heart_rate_t-1 <- ['pain_level_t-1', 'blood_pressure_t-1', 'mobility_t-1', 'oxygen_level_t-1']
# mobility <- ['heart_rate_t-1', 'mobility_t-1', 'pain_level_t-1', 'blood_pressure_t-1', 'oxygen_level_t-1']
# heart_rate <- ['heart_rate_t-1', 'mobility_t-1', 'pain_level_t-1', 'blood_pressure_t-1', 'oxygen_level_t-1']
# oxygen_level <- ['blood_pressure_t-1', 'heart_rate_t-1', 'oxygen_level_t-1', 'pain_level_t-1', 'mobility_t-1']
# pain_level_t-1 <- ['mobility_t-1', 'heart_rate_t-1', 'oxygen_level_t-1', 'blood_pressure_t-1']
# pain_level <- ['blood_pressure_t-1', 'heart_rate_t-1', 'mobility_t-1', 'pain_level_t-1', 'oxygen_level_t-1']
# mobility_t-1 <- ['blood_pressure_t-1', 'heart_rate_t-1', 'oxygen_level_t-1', 'pain_level_t-1']
# oxygen_level_t-1 <- ['blood_pressure_t-1', 'heart_rate_t-1', 'mobility_t-1', 'pain_level_t-1']
# blood_pressure <- ['blood_pressure_t-1', 'heart_rate_t-1', 'pain_level_t-1', 'mobility_t-1']
# blood_pressure_t-1 <- ['oxygen_level_t-1', 'pain_level_t-1', 'mobility_t-1', 'heart_rate_t-1']

# %%
def summarize_changepoints(V, df):
    print("Changepoint Summary:")
    for var, Vn in V.items():
        change_locs = [i for i in range(1, len(Vn)) if Vn[i] != Vn[i - 1]]
        timestamps = df.iloc[change_locs]['timestamp'].values if 'timestamp' in df.columns else change_locs
        print(f"- {var}: {len(set(Vn))} segments, {len(change_locs)} changepoints")
        if change_locs:
            print(f"  → Change indices: {change_locs}")
            print(f"  → Change times: {list(timestamps)}")

summarize_changepoints(best_V, df_encoded)
# Out:
# 🔍 Changepoint Summary:
# - blood_pressure: 2 segments, 2 changepoints
#   → Change indices: [5, 19]
#   → Change times: [datetime.date(2023, 10, 15), datetime.date(2023, 12, 9)]
# - pain_level: 2 segments, 4 changepoints
#   → Change indices: [24, 32, 125, 133]
#   → Change times: [datetime.date(2023, 12, 19), datetime.date(2023, 1, 10), datetime.date(2023, 7, 29), datetime.date(2023, 11, 19)]
# - mobility: 1 segments, 0 changepoints
# - heart_rate: 3 segments, 11 changepoints
#   → Change indices: [14, 19, 39, 50, 59, 61, 101, 104, 110, 115, 120]
#   → Change times: [datetime.date(2023, 11, 2), datetime.date(2023, 12, 9), datetime.date(2023, 1, 24), datetime.date(2023, 12, 14), datetime.date(2024, 1, 1), datetime.date(2023, 9, 28), datetime.date(2023, 3, 7), datetime.date(2023, 3, 13), datetime.date(2023, 4, 10), datetime.date(2023, 4, 20), datetime.date(2023, 7, 19)]
# - oxygen_level: 1 segments, 0 changepoints
# - blood_pressure_t-1: 2 segments, 2 changepoints
#   → Change indices: [5, 19]
#   → Change times: [datetime.date(2023, 10, 15), datetime.date(2023, 12, 9)]
# - pain_level_t-1: 1 segments, 0 changepoints
# - mobility_t-1: 1 segments, 0 changepoints
# - heart_rate_t-1: 2 segments, 2 changepoints
#   → Change indices: [38, 50]
#   → Change times: [datetime.date(2023, 1, 22), datetime.date(2023, 12, 14)]
# - oxygen_level_t-1: 1 segments, 0 changepoints

# %%
def truth_changepoints(df, ground_truth_cp):
    print("Ground Truth Changepoints (timestamps per subject):")
    for sid, cp in ground_truth_cp.items():
        ts = df[df['subject_id'] == sid]['timestamp'].reset_index(drop=True)
        if cp < len(ts):
            print(f"Subject {sid}: changepoint at index {cp}, timestamp = {ts[cp]}")

truth_changepoints(df_health, ground_truth_cp)
# Out:
# Ground Truth Changepoints (timestamps per subject):
# Subject 1: changepoint at index 10, timestamp = 2023-10-23
# Subject 2: changepoint at index 7, timestamp = 2023-12-21
# Subject 3: changepoint at index 9, timestamp = 2023-01-26
# Subject 4: changepoint at index 6, timestamp = 2023-12-24
# Subject 5: changepoint at index 8, timestamp = 2023-10-12
# Subject 6: changepoint at index 7, timestamp = 2023-09-11
# Subject 7: changepoint at index 10, timestamp = 2023-03-05
# Subject 8: changepoint at index 5, timestamp = 2023-04-18
# Subject 9: changepoint at index 7, timestamp = 2023-07-31
# Subject 10: changepoint at index 6, timestamp = 2023-11-29
